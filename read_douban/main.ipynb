# %%
import pandas
import requests

L=[]
for page in range(1,20):

    headers = {
        'Accept': 'application/json',
        'Accept-Language': 'zh-CN,zh;q=0.9,en-US;q=0.8,en;q=0.7',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive',
        # Already added when you pass json=
        # 'Content-Type': 'application/json',
        # Requests sorts cookies= alphabetically
        # 'Cookie': 'll="118254"; bid=p0MbXH3C560; douban-fav-remind=1; viewed="1019568"; uaid="463930cab3ef9f57c6561d57780f661f443b7eff"; _ga=GA1.1.68034132.1711168608; _ga_RXNMP372GL=GS1.1.1711168608.1.1.1711169564.60.0.0',
        'Origin': 'https://read.douban.com',
        'Pragma': 'no-cache',
        'Referer': 'https://read.douban.com/category/103',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36 Edg/122.0.0.0',
        'X-CSRF-Token': '.eJwFwQkBACEIBMAuJpBdPCCOPPaPcDPLtKPAi7Mb8opftEyF9hjrEK5TWbLx_JCwsGuO7EZ4EusHTOIRbQ.Zf5gGw.CvDpwPt4iy898t03ZYlXNuWU5LA',
        'X-Requested-With': 'XMLHttpRequest',
        'sec-ch-ua': '"Chromium";v="122", "Not(A:Brand";v="24", "Microsoft Edge";v="122"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    json_data = {
        'sort': 'hot',
        'page': page,
        'kind': 103,
        'query': '\n    query getFilterWorksList($works_ids: [ID!]) {\n      worksList(worksIds: $works_ids) {\n        \n    id\n    isOrigin\n    isEssay\n    \n    title\n    cover(useSmall: false)\n    url\n    isBundle\n    coverLabel(preferVip: true)\n  \n    \n  url\n  title\n\n    \n  author {\n    name\n    url\n  }\n  origAuthor {\n    name\n    url\n  }\n  translator {\n    name\n    url\n  }\n\n    \n  abstract\n  authorHighlight\n  editorHighlight\n\n    \n    isOrigin\n    kinds {\n      \n    name @skip(if: true)\n    shortName @include(if: true)\n    id\n  \n    }\n    ... on WorksBase @include(if: true) {\n      wordCount\n      wordCountUnit\n    }\n    ... on WorksBase @include(if: false) {\n      inLibraryCount\n    }\n    ... on WorksBase @include(if: false) {\n      \n    isEssay\n    \n    ... on EssayWorks {\n      favorCount\n    }\n  \n    \n    \n    averageRating\n    ratingCount\n    url\n    isColumn\n    isFinished\n  \n  \n  \n    }\n    ... on EbookWorks @include(if: false) {\n      \n    ... on EbookWorks {\n      book {\n        url\n        averageRating\n        ratingCount\n      }\n    }\n  \n    }\n    ... on WorksBase @include(if: false) {\n      isColumn\n      isEssay\n      onSaleTime\n      ... on ColumnWorks {\n        updateTime\n      }\n    }\n    ... on WorksBase @include(if: true) {\n      isColumn\n      ... on ColumnWorks {\n        isFinished\n      }\n    }\n    ... on EssayWorks {\n      essayActivityData {\n        \n    title\n    uri\n    tag {\n      name\n      color\n      background\n      icon2x\n      icon3x\n      iconSize {\n        height\n      }\n      iconPosition {\n        x y\n      }\n    }\n  \n      }\n    }\n    highlightTags {\n      name\n    }\n    ... on WorksBase @include(if: false) {\n      fanfiction {\n        tags {\n          id\n          name\n          url\n        }\n      }\n    }\n  \n    \n  ... on WorksBase {\n    copyrightInfo {\n      newlyAdapted\n      newlyPublished\n      adaptedName\n      publishedName\n    }\n  }\n\n    isInLibrary\n    ... on WorksBase @include(if: false) {\n      \n    fixedPrice\n    salesPrice\n    isRebate\n  \n    }\n    ... on EbookWorks {\n      \n    fixedPrice\n    salesPrice\n    isRebate\n  \n    }\n    ... on WorksBase @include(if: true) {\n      ... on EbookWorks {\n        id\n        isPurchased\n        isInWishlist\n      }\n    }\n    ... on WorksBase @include(if: false) {\n      fanfiction {\n        fandoms {\n          title\n          url\n        }\n      }\n    }\n    ... on WorksBase @include(if: false) {\n      fanfiction {\n        kudoCount\n      }\n    }\n  \n      }\n    }\n  ',
        'variables': {},
    }

    response = requests.post('https://read.douban.com/j/kind/',  headers=headers, json=json_data)
    for i in response.json()['list']:
        title=i['title']
        try:
            origAuthor=i['origAuthor'][0]['name']
        except:
            origAuthor=i['author'][0]['name']
        abstract=i['abstract']
        url=i['id']
        print([title,origAuthor,abstract[0:10]+'...',url])
        L.append([title,origAuthor,abstract,url])
# Out:
# ['纳瓦尔宝典', '[美] 埃里克·乔根森', '致富不仅仅靠运气，幸...', '393639927']
# ['埃隆·马斯克传', '[美] 沃尔特·艾萨克森', '著名传记作家艾萨克森...', '450837265']
# ['置身事内', '兰小欢', '“在成功的经济体中，...', '327631159']
# ['金钱心理学', '[美] 摩根·豪泽尔（Morgan Housel）', '人们总把投资理财当作...', '438087934']
# ['周期', '[美] 霍华德·马克斯', '每个投资人都想弄清楚...', '108437540']
# ['思考，快与慢', '[美] 丹尼尔· 卡尼曼', '人类究竟有多理性？\r...', '537213']
# ['反脆弱', '[美] 纳西姆·尼古拉斯·塔勒布', '尼采有句名言：“杀不...', '2810274']
# ['价值', '张磊', '高瓴创始人兼首席执行...', '158519375']
# ['穷查理宝典（全新增订本）', '[美] 彼得·考夫曼', '本书是迄今为止全面介...', '330997671']
# ['原则', '[美] 瑞·达利欧（Ray Dalio）', '※ 华尔街投资大神、...', '44533523']
# ['财政中国三千年', '刘守刚', '维持中华帝国长期发展...', '159400101']
# ['底层逻辑', '刘润', '“底层逻辑”来源于不...', '344982968']
# ['领导梯队', '[美] 拉姆·查兰（Ram Charan）', '能力与岗位的匹配，特...', '10086160']
# ['卓有成效的管理者', '[美] 彼得·德鲁克（Peter F.Drucker）', '德鲁克以卓越的睿智告...', '110808408']
# ['一人企业', '[美] 保罗·贾维斯', '一人企业是一种新颖的...', '174124252']
# ['大分流', '[美] 彭慕兰', '★费正清奖得主彭慕兰...', '320196283']
# ['FIRE：通往财务自由之路', '[美] 斯科特·里肯斯', '这是一本写给普通读者...', '456476101']
# ['黑天鹅', '[美] 纳西姆·尼古拉斯·塔勒布', '在发现澳大利亚的黑天...', '2010442']
# ['被追赶的经济体', '[美] 辜朝明', '经济学家辜朝明在本书...', '453967153']
# ['芯片战争', '[美] 克里斯·米勒', '一部芯片的发展史与竞...', '437411510']
# ['把时间当作朋友', '李笑来', '为什么你总是说“没有...', '1283450']
# ['巴菲特投资之道', '[美] 沃伦·巴菲特', '一本书读懂价值投资的...', '409004899']
# ['哈佛商学院最受欢迎的领导课', '[美] 罗伯特·史蒂文·卡普兰（Robert Steven Kaplan）', '领导力与你的企业规模...', '124593004']
# ['富甲美国：沃尔玛创始人山姆·沃尔顿自传', '[美] 山姆·沃尔顿', '一本被刘强东、雷军、...', '12354837']
# ['有钱人和你想的不一样（新版）', '[美] 哈维·艾克（T.Harv Eker）', '富翁也有可能输掉万贯...', '161950757']
# ['制造消费者', '[法] 安东尼·加卢佐', '万有引力社会议题书系...', '426696027']
# ['贫穷的本质', '[印度] 阿比吉特·班纳吉', '他们曾被说成是白人的...', '2851155']
# ['影响力（经典版）', '[美] 罗伯特·B.西奥迪尼（Robert B.Cialdini）', '自出版以来，《影响力...', '29224826']
# ['周期、估值与人性', '凌鹏', '复盘A股20年行情演...', '450240882']
# ['时间贫困', '[英] 凯茜·霍姆斯', '我们总以为，一个人的...', '451820608']
# ['贡赋体制与市场：明清社会经济史论稿', '刘志伟', '《汉书食货志》曰：“...', '128774221']
# ['精益创业', '[美] 埃里克·莱斯', '我们正处在一个空前的...', '484790']
# ['影响力（全新升级版）', '[美] 罗伯特·西奥迪尼', '自出版以来，《影响力...', '332668277']
# ['认知觉醒', '[英] 保罗·斯隆', '在解决生活、职场中的...', '453354624']
# ['投资最重要的事', '[美] 霍华德·马克斯', '《投资最重要的事（顶...', '539667']
# ['重来', '[美] 贾森·弗里德', '大多数的企业管理的书...', '570599']
# ['棉花帝国', '[美] 斯文·贝克特', '☆2015年班克罗夫...', '110825582']
# ['关键绩效指标', '[美] 戴维·帕门特（David Parmenter）', '本书是现代企业人力资...', '39070819']
# ['分析与思考', '黄奇帆', '本书是黄奇帆教授在复...', '435240887']
# ['原则：应对变化中的世界秩序', '[美] 瑞·达利欧', '达利欧一贯善于综合宏...', '338192334']
# ['从0到1', '[美] 蒂尔', '在传统时代，成功企业...', '8937101']
# ['从偶然到必然', '夏忠毅 编著', '《从偶然到必然》是一...', '127495710']
# ['货币战争', '[美] 詹姆斯·里卡兹（James Rickards）', '1971年8月15日...', '57010715']
# ['驱动力（经典版）', '[美] 丹尼尔·平克 (Daniel H.Pink)', '“全球50位具影响力...', '53653083']
# ['第四次工业革命', '克劳斯·施瓦布', '蒸汽机的发明驱动了第...', '22977664']
# ['高分经理人：如何成为专业的管理者', '张烈生', '本书从基础概念讲起，...', '427386426']
# ['小而美：持续盈利的经营法则', '[美] 萨希尔·拉文吉亚', '不是每个企业都能成为...', '420622524']
# ['随机漫步的傻瓜', '[美] 纳西姆·尼古拉斯·塔勒布', '塔勒布在《随机漫步的...', '10299013']
# ['成为解决问题的高手：从被动应对到主动创新', '[美] 阿特·斯莫利Art Smalley', '本书的内容和观点多源...', '318153982']
# ['资本论', '[德] 卡尔·马克思 ', '《资本论》是马克思主...', '320749234']
# ['增长黑客', '[美] 肖恩·埃利斯 （Sean Ellis) ', '脸谱网如何从默默无闻...', '50261370']
# ['结构思考力', '李忠秋', '本书的核心理念源自芭...', '35649097']
# ['平台经济：创新、治理与繁荣', '北京大学平台经济创新与治理课题组 著', '野蛮生长的时代已经过...', '418587179']
# ['数智革新：中国企业的转型升级', '杨国安 著', '“数智革新杨五环”与...', '381099498']
# ['股票魔法师Ⅱ', '[美] Mark Minervini', '像冠军一样思考和交易...', '59654711']
# ['非凡的成功', '[美] 大卫·F.史文森（David F. Swensen）', '大卫·F.史文森是畅...', '329077628']
# ['数字化转型路线图', '[美] 托尼·萨尔德哈（Tony Saldanha）', '数字化转型失败率高达...', '319986277']
# ['业务为本', '襄阳郭丹', '任正非说，华为的成功...', '398662228']
# ['巴菲特之道', '[美] 罗伯特·哈格斯特朗', '向巴菲特致敬的一本书...', '8862364']
# ['破局乡村振兴', '陈高威', '本书收录了温铁军在各...', '448054818']
# ['半小时漫画股票实战法', '财经杂质', '任何一个可以在股市稳...', '139832326']
# ['人口大逆转', '[英] 查尔斯·古德哈特（Charles Goodhart）', '保护主义、民族主义、...', '336468254']
# ['一人公司', '[美] 卡丽·莱恩', '一个人能否揪着自己的...', '453910073']
# ['股权战略', '张凯智，马英', '在全民创业浪潮下，很...', '323706413']
# ['像高手一样解决问题', '[法] 伯纳德·加雷特', '掌握解决复杂问题并推...', '327819363']
# ['公司控制权（第2版）', '卢庆华', '有人持股0.02%就...', '318380237']
# ['公共关系管理', '陈丽清', '浙江理工大学经济管理...', '53973796']
# ['SaaS攻略：入门、实战与进阶', '胡文语', '这是一本能带领你零基...', '337108639']
# ['理解中国产业政策', '江飞涛 等', '随着改革开放的不断深...', '322233632']
# ['邻家的百万富翁', '[美] 托马斯·斯坦利', '《邻家的百万富翁》是...', '446185348']
# ['投资中最简单的事', '邱国鹭', '●投资本身是一件很复...', '31196858']
# ['21世纪资本论', '[法] 托马斯·皮凯蒂', '法国经济学家、巴黎经...', '9254833']
# ['专业投机原理（典藏版）', '[美] 维克托·斯波朗迪（Victor Sperandeo）', '本书自出版以来，已使...', '110808848']
# ['OKR工作法', '[美] 克里斯蒂娜·沃特克', '《OKR工作法》讲述...', '43491349']
# ['组织的力量', '张丽俊', '小企业经营业务，大企...', '345135324']
# ['良性增长：盈利性增长的底层逻辑', '[美] 拉姆·查兰（Ram Charan）', '为什么你的企业不再增...', '136983325']
# ['合伙人裂变与股权密码', '王美江', '在国家大力倡导创业创...', '167788079']
# ['制内市场', '郑永年', '本书从中西比较的视野...', '314440003']
# ['就业、利息和货币通论', '[英] 约翰·梅纳德·凯恩斯（John Maynard Keynes）', '《就业、利息和货币通...', '119057309']
# ['底层逻辑2', '刘润', '“底层逻辑”来源于不...', '416733872']
# ['打开量化投资的黑箱（原书第2版）', '[美] 里什·纳兰', '无论是量化、算法，还...', '21840212']
# ['贫穷的本质（修订版·2019年诺贝尔经济学奖得主作品）', '[印] 阿比吉特·班纳吉', '他们曾被说成是白人的...', '108382260']
# ['HR财务思维', '王美江', 'HR作为企业领导者的...', '318405197']
# ['金融风险管理（第二版）', '高晓燕 主编', '随着金融自由化、全球...', '125875425']
# ['ESG投资', '[美] 马克·墨比尔斯', '气候变暖、海上漂浮的...', '340915865']
# ['褚时健传（修订版）', '周桦', '褚时健数万字亲述，作...', '389376638']
# ['芒格之道', '[美] 查理·芒格 著', '本书收录了查理·芒格...', '437782807']
# ['营销笔记', '小马宋', '这是一本一开始阅读就...', '403137742']
# ['创新与企业家精神', '[美] 彼得·德鲁克 ', '人人都知道创新的重要...', '847087']
# ['闪电式扩张', '[美] 里德 · 霍夫曼（Reid Hoffman）', 'LinkedIn领英...', '123120342']
# ['茅台传', '吴晓波', '在茅台酒的配料表上，...', '454607751']
# ['数字上的中国', '黄奇帆 陈春花 吴声 等', '今天，数字科技正在深...', '380963649']
# ['创新者的窘境（全新修订版）', '[美] 克莱顿·克里斯坦森', '全球商业领域中，许多...', '124592829']
# ['产业区块链', '汤道生', '区块链已经上升至国家...', '144783110']
# ['褚时健传', '周桦', '褚时健，这是一个在中...', '19679182']
# ['极简市场营销', '胡超', '《极简市场营销》被定...', '172441118']
# ['气候经济与人类未来', '[美] 比尔·盖茨', '比尔·盖茨花了十年时...', '304215395']
# ['马克思主义政治经济学在当代中国的新发展', '邱海平', '马克思主义政治经济学...', '108393803']
# ['国家干预经济与中日近代化（修订本）', '朱荫贵', '本书以19世纪中后期...', '55681993']
# ['多重约束下的货币政策传导机制', '张晓慧 等', '张晓慧，中国金融四十...', '331265142']
# ['AI 3.0', '[美] 梅拉妮·米歇尔（Melanie Mitchell）', '人工智能现在正深刻地...', '171212511']
# ['期货多空逻辑', 'Jerry Ma', '市场上关于期货技术分...', '171585021']
# ['横渡孟加拉湾', '[印度] 苏尼尔·阿姆瑞斯', '孟加拉湾曾经是全球化...', '154727741']
# ['打造第二大脑', '[美] 蒂亚戈·福特', '诺贝尔物理学奖得主理...', '454628422']
# ['1%的精进', '[英] 苏珊·索洛维奇', '推特广受欢迎的中小企...', '452276844']
# ['交易之路', '陈凯', '怎么稳定盈利？怎么把...', '131110942']
# ['定位：争夺用户心智的战争', '[美] 艾·里斯（Al Ries）', '2001年，美国营销...', '166107397']
# ['中国经济的前景', '林毅夫', '中国为什么会成为领跑...', '381099870']
# ['日本蜡烛图技术（第2版）', '[美] 史蒂夫·尼森（Steve Nison）', '畅销30年、全球销量...', '150934449']
# ['突破现实的困境', '[澳] 克里斯·布拉德利（Chris Bradley）', '本书讲述了如何采取重...', '58132555']
# ['半小时漫画经济学：生活常识篇', '陈磊', '在大多数读者的心目中...', '123605774']
# ['聚焦：决定你企业的未来', '[美] 艾·里斯（Al Ries）', '在本书中，艾·里斯以...', '32449978']
# ['金线', '冯唐', '这是一本管理书，是冯...', '416007860']
# ['房债', '[美] 阿蒂夫·迈恩', '始于2007年的金融...', '418404461']
# ['基业长青（珍藏版）', '[美] 吉姆·柯林斯', '《基业长青(珍藏版)...', '50196229']
# ['债务危机', '[美] 瑞·达利欧', '在2008年金融危机...', '109344022']
# ['重新理解企业家精神', '张维迎', '“企业家”是张维迎教...', '406380714']
# ['经济学原理', '[英] 马歇尔', '《经济学原理》是英国...', '772114']
# ['期货交易实战', '杨峻', '本书是一部描述期货从...', '59654934']
# ['组织革新', '杨国安（Arthur Yeung）', '市场变化莫测，而你的...', '126235433']
# ['信托的逻辑：中国信托公司做什么', '王道远', '这本书着眼于中国信托...', '126235146']
# ['贫困的终结', '李小云', '本书书以平实通俗的语...', '315282335']
# ['人口版图', '[英] 保罗·莫兰', '人口规模庞大与人口负...', '423914730']
# ['定投十年财务自由', '银行螺丝钉', '你是否也有这样的苦恼...', '125970614']
# ['将才：企业如何招才选将', '李践', '从“人”到“企业”，...', '159319012']
# ['品类管理实战（第四版）', '程莉', '随着互联网线上线下的...', '171831893']
# ['被掩盖的原罪：奴隶制与美国资本主义的崛起', '[美] 爱德华.巴普蒂斯特', '揭露美国商业的肮脏秘...', '129565433']
# ['从菜鸟到专家：人力资源管理实战笔记', '李远婷', '《从菜鸟到专家：人力...', '119057611']
# ['财富、贫穷与政治', '[美] 托马斯·索维尔', '☆《经济学的思维方式...', '382079836']
# ['交易的世界', '[英] 哈维尔·布拉斯（Javier Blas）', '这是一部引人入胜的大...', '406469956']
# ['权力的转移', '[美 ] 阿尔文·托夫勒', '《权力的转移》是“未...', '54959923']
# ['飞轮效应', '[美] 吉姆·柯林斯（Jim Collins）', '在《从优秀到卓越》中...', '144783412']
# ['《就业、利息和货币通论》导读', '高鸿业', '约翰·梅纳德·凯恩斯...', '158696938']
# ['华为饱和攻击营销法', '孟庆祥', '华为是研究中国企业的...', '321426958']
# ['营销管理（第16版）', '[美] 菲利普·科特勒', '《营销管理》（第16...', '410474014']
# ['市场给不了的自由', '[美] 迈克·孔恰尔', '★从历史的细微处理解...', '454705832']
# ['创新公司：皮克斯的启示', '[美] 艾德·卡特姆', '你可以从本书中读到《...', '19890267']
# ['文明、现代化、价值投资与中国', '李录', '本书是喜马拉雅资本创...', '132148399']
# ['创客', '[美] 克里斯·安德森', '在本书里，《连线》杂...', '407627']
# ['经营最重要的事', '[美] 梅纳德·韦伯（Maynard Webb）', '市场低迷，你如何赢得...', '129506993']
# ['金钱博弈', '单伟建', '近年来，私市股权投资...', '395874183']
# ['第五项修炼', '[美] 彼得·圣吉', '《第五项修炼：学习型...', '579282']
# ['贝佐斯致股东的信', '[英] 史蒂夫·安德森', '浓缩21封贝佐斯致股...', '319005496']
# ['远见', '[美] 史蒂文·约翰逊（Steven Johnson）', '你是不是常常后悔做过...', '125973718']
# ['新镀金时代', '[英] 詹姆斯·克拉布特里', '14亿人口大国，30...', '454911476']
# ['大转折', '[英] 马克·莱文森', '第二次世界大战后的2...', '384066207']
# ['硅谷钢铁侠：埃隆·马斯克的冒险人生', '[美] 阿什利·万斯', '作者用荡气回肠的写作...', '20908325']
# ['双循环：构建“十四五”新发展格局', '樊纲', '当今世界正经历百年未...', '169187533']
# ['精益企业：高效能组织如何规模化创新', '[英] Jez Humble', '本书是企业应对不断变...', '31793596']
# ['明智转向', '[英] 奥马尔·阿布什（Omar Abbosh）', '纵观全球领先企业，面...', '128930416']
# ['创始人精神', '[美] 克里斯·祖克（Chris Zook）', '为什么获得盈利增长如...', '28703451']
# ['团队协作的五大障碍（全新修订版）', '[美] 帕特里克·兰西奥尼', '这是一本让头疼的团队...', '40161394']
# ['资本论', '[德] 马克思', '经济每时每刻都影响和...', '757729']
# ['常识工作法', '[丹] 马丁·林斯特龙', '马丁·林斯特龙是全球...', '333748935']
# ['通胀，还是通缩：全球经济迷思', '[日] 渡边努', '这是一本研究当前全球...', '453336840']
# ['长期投资', '[西] 弗朗西斯科·加西亚·帕拉梅斯', '一位传奇投资者的价值...', '135022411']
# ['经济发展理论', '[美] 约瑟夫·熊彼特', '本书是美国经济学家约...', '153128624']
# ['借势：以弱胜强的128条黄金法则', '金枪大叔', '本书是广告鬼才金枪大...', '402630852']
# ['读懂碳中和', '中国长期低碳发展战略与转型路径研究课题组', '气候变化已成为全球面...', '335324798']
# ['领导梯队（原书第2版）', '[美] 拉姆·查兰（Ram Charan）', '企业要想获得成功，就...', '30943229']
# ['长期主义', '[美] 高德威', '在充满挑战的时代，真...', '340978907']
# ['平衡计分卡战略实践', '[美] 罗伯特·S.卡普兰（Robert S. Kaplan）', '本书是卡普兰教授和诺...', '380290417']
# ['元宇宙改变一切', '[加] 马修·鲍尔', '2021年被誉为“元...', '408134734']
# ['卖货真相', '小马宋', '在如今的商业环境里，...', '446792827']
# ['乐山城记：一座古城的生命史', '邱顾', '本书通过对乐山城市历...', '139141942']
# ['人才盘点完全应用手册', '北森人才管理研究院', '随着经济环境的不确定...', '121015515']
# ['大国治理', '陆铭', '大国治理，核心是城乡...', '327631525']
# ['小马白话期权3', '小马', '随着更多商品期权品种...', '333176393']
# ['土地制度与中国发展（增订本）', '刘守英', '中国过去四十多年经济...', '402331226']
# ['中国经济：内生增长', '黄奇帆', '逆全球化时代的经济形...', '335584843']
# ['决胜B端：驱动数字化转型的产品经理（第2版）', '杨堃', '本书试图提炼了互联网...', '455104036']
# ['永恒的活火', '张瑞敏', '《永恒的活火》是海尔...', '453894135']
# ['质量免费', '[美] 菲利普·克劳士比', '《质量免费》是管理学...', '31824166']
# ['张一鸣管理日志', '林军', '2012年，在一家小...', '392210763']
# ['百万富翁快车道', '[美] MJ·德马科', '《百万富翁快车道》破...', '161660200']
# ['从优秀到卓越', '[美] 吉姆·柯林斯', '《从优秀到卓越》描绘...', '18877375']
# ['数字解读中国', '贺耀敏', '改革开放以来，特别是...', '310782308']
# ['深圳奇迹', '张思平', '2018年是中国改革...', '120270415']
# ['阿里巴巴基本动作：管理者必须修炼的24个基本动作', '王建和', '收齐日报很难，收到合...', '165423743']
# ['无限投资', '[美] 托比·马西斯', '你是否感觉每日辛苦奔...', '442798444']
# ['债：5000年债务史', '[美] 大卫·格雷伯（David Graeber）', '这是一本由人类学家回...', '174659602']
# ['产品开发项目管理', '尹义法', '本书融合了多项国际项...', '338449749']
# ['绝佳体验', '[美] 布鲁斯·莱夫勒 （Bruce Loeffler）', '根据对500多家企业...', '57217522']
# ['联盟：互联网时代的人才变革', '[美] 里德·霍夫曼', '在充满变化的世界，联...', '317243582']
# ['长期的力量', '梁宇峰', '本书为普通投资者，提...', '131281433']
# ['大国产业链', '中金公司研究部', '党的二十大报告指出，...', '426651853']
# ['中国城市大变局', '凯风', '世界之变、历史之变、...', '442532044']
# ['中国融资租赁行业2018年度报告', '中国融资租赁三十人论坛', '本书是融资租赁行业每...', '116501380']
# ['银行授信产品手册与应用', '孙建林', '这是一本全面介绍商业...', '318885704']
# ['如何成为优秀的人力资源总监', '曹子祥', '本书结合大量案例，从...', '35818744']
# ['利益相关者', '[德] 克劳斯·施瓦布', '新冠肺炎疫情的全球大...', '323434525']
# ['成为独角兽', '[美] 阿尔·拉马丹', '创造、发展和主宰提供...', '39979468']
# ['跨越鸿沟：颠覆性产品营销指南（原书第3版）', '[美] 杰弗里·摩尔', '“如果你现在还不了解...', '422691148']
# ['国内大循环', '贾根良', '中美经济战和新冠疫情...', '161346438']
# ['资本论', '[德] 卡尔·马克思', '本书是马克思主义的创...', '405912001']
# ['商业模式新生代', '[瑞士] 亚历山大·奥斯特瓦德（Alexander Osterwalder）', '当你愉快的看完第一章...', '279014609']
# ['人民币国际化报告2023', '中国人民大学国际货币研究所', '《人民币国际化报告》...', '441550955']
# ['高管路径', '[美] 拉姆·查兰（Ram Charan）', '互联网时代高管失败的...', '30911802']
# ['13+1体系', '黄旭', '本书为企业核心管理层...', '169014350']
# ['人口负增长时代', '蔡昉', '人口发展事关长远，事...', '423762048']
# ['企业生命周期', '伊查克.爱迪思', '爱迪思博士在研究辅导...', '43119178']
# ['硅谷增长黑客实战笔记', '曲卉', '增长黑客这个词源于硅...', '417887674']
# ['超越好奇', '周鸿祎', '它讲述了出身平凡、背...', '437427448']
# ['普林斯顿经济学研究指南', '[美] 迈克尔·S.魏斯巴赫', '学术工作者所做的学科...', '443812076']
# ['说谎者的扑克牌', '[美] 迈克尔·刘易斯', '“说谎者的扑克牌”是...', '437359']
# ['共同基金常识（10周年纪念版）', '[美] 约翰·博格', '《共同基金常识》是指...', '41296853']
# ['人口战略', '梁建章', '本书分析了人口规模和...', '431362187']
# ['重新定义公司：谷歌是如何运营的', '[美] 埃里克·施密特', '官方出品，重装升级版...', '119542045']
# ['规模', '[英] 杰弗里·韦斯特 (Geoffrey West)', '生命体、城市、公司，...', '53958984']
# ['投资中最简单的事（更新版）', '邱国鹭', '投资本身是一件很复杂...', '145151305']
# ['产业集群互动机制研究', '范纯增', '《产业集群互动机制研...', '22805294']
# ['长期主义', '[美] 杰夫·贝佐斯', '【放眼长期】衡量公司...', '403726314']
# ['从1到N：企业数字化生存指南', '[德]尤尔根·梅菲特', '随着新技术的发展成熟...', '51579203']
# ['穿越寒冬', '[美] 史蒂文·霍夫曼（Steven S. Hoffman）', '当创业环境好的时候，...', '128929817']
# ['决策的艺术', '[美] 哈蒙德（Hammond,J.S.）', '上大学该学什么专业？...', '317370492']
# ['企业数字化转型', '李彤', '《企业数字化转型》为...', '322888296']
# ['战略解码', '吕守升', '本书论述了“让战略规...', '172817248']
# ['中国崛起不可承受之错', '郑永年', '《中国崛起不可承受之...', '23761814']
# ['中国经济增长十年展望（2020—2029）：战疫增长模式', '刘世锦 主编', '2019年，中国经济...', '156886390']
# ['股权激励实操一本通', '向凌云', '股权激励是近年来上市...', '53711962']
# ['股权激励实操一本通', '向凌云', '股权激励是近年来上市...', '53711962']
# ['噪声', '[以色列] 丹尼尔·卡尼曼', '诺贝尔经济学奖得主、...', '329083511']
# ['创造：用非传统方式做有价值的事', '[美] 托尼·法德尔', '做有价值的事，虽不容...', '415539180']
# ['上瘾', '[美] 尼尔·埃亚尔', '·为什么我们会习惯性...', '34357709']
# ['中国新经济', '韩秀云', '中国未来经济增长靠什...', '314197819']
# ['产业数字化', '沈建光 金天 龚谨 等', '疫情凸显出数字经济的...', '168748833']
# ['量化投资策略', '周佰成', '随着我国资本市场的迅...', '128973107']
# ['企业资金管理', '董博欣', '企业经营管理中，管理...', '134473876']
# ['信贷的逻辑与常识', '刘元庆', '本书专注于探讨微观层...', '34345930']
# ['繁荣与衰退', '[美] 艾伦·格林斯潘（Alan Greenspan）', '这是一部史诗级的美国...', '119981755']
# ['大数据时代：生活、工作与思维的大变革', '[英] 维克托·迈尔·舍恩伯格（Viktor Mayer-Schönberger）', '国外大数据研究的先河...', '29224686']
# ['敏捷团队绩效考核', '管婷婷', '本书介绍了敏捷团队绩...', '171839259']
# ['管理百年（珍藏版）', '[美] 斯图尔特·克雷纳', '过去的100年，管理...', '129622544']
# ['资本与商业模式顶层设计', '郑翔洲', '本书通过实例的形式，...', '12097495']
# ['战略罗盘', '王成', '企业经营正面临着一个...', '53236880']
# ['非理性繁荣与金融危机（第二版）', '[美] 罗伯特·席勒', '本书是诺贝尔经济学奖...', '156885951']
# ['论中国经济：挑战、底气与后劲', '林毅夫', '中国已进入十八大提出...', '313783373']
# ['创业融资2.0：实战与工具', '吴伟', '本书手把手教创业者融...', '48979293']
# ['关乎天下：中小企业赢的秘诀', '关明生', '一家企业如何才能活得...', '405891963']
# ['重读哈耶克', '韦森', '弗里德里希·奥古斯都...', '388757463']
# ['华为战略管理法：DSTE实战体系', '谢宁', '华为是一家持续成功的...', '403465567']
# ['斯坦福商学院最负盛名的企业家培养课', '李方正', '《斯坦福商学院最负盛...', '11143171']
# ['轻松主义', '[英] 格雷戈·麦吉沃恩', '你是否觉得自己：\r\n...', '384051973']
# ['商业的本质', '[美] 杰克·韦尔奇', '2005年全球畅销书...', '19890030']
# ['科学分钱', '卞志汉', '主要是三大部分：\r\n...', '322209598']
# ['美国四百年', '[美] 布·斯里尼瓦桑', '★一部创业者书写的美...', '382832566']
# ['人生破局的关键思维', '[美]  德雷克·劳德米尔克', '各工作领域随着时代不...', '454066472']
# ['市场的真相', '[英] 约翰·凯伊', '本书是一本通俗经济学...', '46753181']
# ['人为制造的脆弱性', '[美] 查尔斯·凯罗米里斯', '为什么有的国家银行体...', '45478011']
# ['大变局中的机遇', '郑永年', '当世界迎来大变局，中...', '326211000']
# ['涨停接力', '均线上的舞者', '炒股如同打猎。打猎首...', '133699122']
# ['公司治理', '闫长乐 编', '“公司治理”是一门实...', '40926710']
# ['翻盘', '萧文鹏', '《翻盘：互联网时代的...', '30284390']
# ['必要的革命③', '[美] 彼得·圣吉（Peter M.Senge）', '面对生态系统的衰退、...', '53960286']
# ['宏观经济学通识课', '谢丹阳', '宏观因素，是影响整个...', '151888222']
# ['传播政治经济学', '[加拿大] 文森特·莫斯可（Vincent Mosco）', '《传播政治经济学》一...', '319340342']
# ['私域电商', '吴晓波频道 主编', '以阿里、京东为代表的...', '321724352']
# ['动荡时代', '[日] 白川方明', '日本经济曾因其活力和...', '335013365']
# ['伟大的中国工业革命', '文一', '中国崛起无疑是人类历...', '40450685']
# ['引爆微信群：10000小时微信群一线运营精髓', '老壹', '本书总体来说分12章...', '51219271']
# ['金钱的未来：数字革命如何改变货币和金融', '[美] 埃斯瓦尔·S.普拉萨德', '从现金的结束到加密货...', '407452727']
# ['涌现', '[美] 约翰·霍兰德', '一粒小小的种子为何能...', '383186074']
# ['华为铁三角工作法', '范厚华', '“让听见炮声的人来决...', '340978450']
# ['商业设计', '[加] 罗杰·马丁 (Roger Martin)', '《商业设计：通过设计...', '335325951']
# ['便利店经营从入门到精通', '过自己的日子', '本书围绕便利店经营的...', '130847789']
# ['日美博弈战', '[日] 鹫尾友春', '在20世纪80年代中...', '333375846']
# ['大变局与新动力', '厉以宁', '《大变局与新动力：中...', '43496242']
# ['端到端流程：为客户创造真正的价值', '[美] 迈克尔·哈默（Michael Hammer）', '现有的企业组织和运行...', '121448908']
# ['超级用户增长', '晏涛', '流量红利几乎殆尽的当...', '164817056']
# ['换道赛车', '苗圩', '本书系工业和信息化部...', '452337815']
# ['金融的谜题', '张晓朴', '本书是近20年来国内...', '322783816']
# ['向模式要利润：商业模式颠覆、创新与重构', '周祺林', '本书解读当前经济政策...', '15391146']
# ['变革的力量', '[美] 约翰·P.科特（John P.Kotter）', '如何打造变革时代的新...', '120056854']
# ['货币从哪里来？', '[英] 乔希·瑞安-柯林斯', '货币体系的运行对普通...', '417866652']
# ['华为团队工作法', '吴建国', '华为是中国率先将人才...', '127318532']
# ['干法', '[日] 稻盛和夫', '这是稻盛和夫以78岁...', '9854420']
# ['中国式现代化', '蔡昉 等', '新时代新征程的使命任...', '417758600']
# ['卓越基因', '[美] 吉姆·柯林斯', '本书的初版创作于19...', '393640946']
# ['重新定义公司：谷歌是如何运营的', '[美] 埃里克·施密特', '《重新定义公司：谷歌...', '46366039']
# ['10W+新媒体文案炼成记', '文能载商', '本书是一本新媒体文案...', '109029413']
# ['财富的起源', '[英] 埃里克·拜因霍克（Eric D.Beinhocker）', '市场是一个不断演化并...', '125877276']
# ['破局：中国经济如何于变局中开新局', '黄益平', '当前，世界正在经历百...', '166075929']
# ['华为目标管理法', '郭楚凡', '华为有着明确的发展目...', '59775171']
# ['私域资产', '肖逸群', '“私域肖厂长”肖逸群...', '380195387']
# ['无条件增长：必然增长的十大规律', '李践', '近年来，创业已经逐渐...', '57218843']
# ['富国陷阱：发达国家为何踢开梯子？', '[英] 张夏准', '本书指出，当今的发达...', '149689884']
# ['投资者的未来（典藏版）', '[美] 杰里米J·西格尔（Jeremy J. Siegel）', '本书视角独特、结论有...', '318373067']
# ['如何提出一个好问题', '[英] 沃伦·贝格尔', '生活和工作中总是会出...', '384052201']
# ['华为执行力（第2版）', '钟金', '本书按照提升组织执行...', '59770471']
# ['管理3.0：培养和提升敏捷领导力', '[荷] Jurgen Appelo', '本书以科学为基础，结...', '407081986']
# ['人才测评：方法与应用（第4版）', '刘远我', '本书第4版在保持第3...', '174117798']
# ['领导变革（珍藏版）', '[美] 约翰 P. 科特', '“在过去20年里，所...', '335325788']
# ['企业数据化管理变革', '赵兴峰', '很多企业热衷于谈论大...', '53979720']
# ['中国金融开放的下半场', '《 径山报告》课题组', '《中国金融开放的下半...', '108170337']
# ['腾讯公关法', '黄洪波', '公关文化是企业文化的...', '54461507']
# ['生长：从战略到执行', '语嫣', '制定战略是CEO的事...', '380290236']
# ['华为全球化', '陈攀峰', '亚布力中国企业家论坛...', '141896320']
# ['逆向思维', '[美] 琳达·贝尔纳迪', '在物联网的背景下，产...', '418672565']
# ['战略思维', '[美] 大卫·B.尤费', '《战略思维》披露：苹...', '135022349']
# ['AI3.0：人工智能落地的商业逻辑', '王晓梅', '现在，已经无须再像几...', '161712436']
# ['趋势的力量', '李迅雷', '所谓趋势，就是市场运...', '333749816']
# ['成就', '[美] 埃里克·施密特（Eric Schmidt）', '谷歌前CEO、《重新...', '136249913']
# ['新加坡产业发展解读：产业体系构筑与现代园区建设', '阮庆文', '本书是作者基于多年规...', '19104587']
# ['看准', '饭爷', '本书深入解析诸多经济...', '382706932']
# ['峰值体验：影响用户决策的关键时刻', '汪志谦', '用户接触品牌或产品的...', '169928124']
# ['资本5000年：资本秩序如何塑造人类文明', '彭兴庭', '从公元前3000年到...', '169701936']
# ['大萧条时期的中国', '[日] 城山智子', '1930年代的经济大...', '420552346']
# ['时势：周期波动下的国家、社会和个人', '小Lin', '为什么不论什么人，都...', '452249566']
# ['海龟交易法则（第4版）', '[美] 柯蒂斯·费思', '在金融界，流传着这样...', '381099006']
# ['疯狗浪：如何应对突如其来的剧变', '[美] 乔纳森·布里尔', '这是一本指导你如何在...', '393594377']
# ['巴菲特致股东的信（原书第4版）', '[美] 沃伦E.巴菲特', '关于沃伦·巴菲特的书...', '49027327']
# ['被遗忘的萧条：经济危机与应对之策', '[美] 詹姆斯·格兰特（James Grant）', '重温1918年大流感...', '315444412']
# ['农村电商', '魏延安', '农村电商包括下行的电...', '36031751']
# ['爆红', '廖恒', '本书是实战派营销人、...', '53219715']
# ['刚性泡沫（增订版）', '朱宁', '本书是一部深入剖析中...', '454628148']
# ['专业服务公司的管理（经典重译版）', '[美] 大卫·梅斯特（David H. Maister）', '全球销量50万册！专...', '110056007']
# ['亚马逊逆向工作法', '[美] 柯林·布里亚（Colin Bryar）', '柯林·布里亚和比尔·...', '380215461']
# ['探路之役：1978～1992年的中国经济改革', '萧冬连', '本书把1978~19...', '415457630']
# ['企业专利战略中的竞争情报机制与运用', '李德升', '《企业专利战略中的竞...', '15396686']
# ['习惯的力量', '[美] 查尔斯·都希格（Charles Duhigg）', '如果你能发现自己的“...', '1936113']
# ['我是微商6：用服务营销引爆成交', '殷中军', '本书是畅销书“我是微...', '124173709']
# ['精益创业2.0', '[美] 埃里克·莱斯（Eric Ries）', '《精益创业》自出版以...', '155224399']
# ['格鲁夫给经理人的第一课', '[美] 安迪·格鲁夫', '管理早餐店的生产线与...', '40020786']
# ['从报表看企业', '张新民', '本书从管理的视角出发...', '175152112']
# ['繁荣的悖论', '[美] 克莱顿·克里斯坦森（Clayton M. Christensen）', '全球贫困是全世界最棘...', '157560359']
# ['搞定I：无压工作的艺术（最新版）', '[美] 戴维·艾伦', '本书是时间管理经典著...', '28899718']
# ['高效的无效', '[美] 拉瑟·海耶·佩德森', '本书描述了对冲基金的...', '324255260']
# ['崩盘：全球金融危机如何重塑世界', '[英] 亚当·图兹', '《崩盘》是关于全球化...', '323697525']
# ['临界变革', '[美] 戴蒙·森托拉（Damon Centola）', '临界变革理论探讨了商...', '455984427']
# ['暨创原理一二三：基于商业原理的创业规律', '张耀辉', '《暨创原理一二三》一...', '341669927']
# ['创业维艰', '[美] 本·霍洛维茨', '《创业维艰：如何完成...', '9545901']
# ['数字创新', '魏江', '这是一本数字创新实操...', '163647640']
# ['定价即经营', '[日] 千贺秀信', '日本经营之圣稻盛和夫...', '334783997']
# ['向服务要利润——华为客户服务中的经营哲学', '周庆', '提起“为客户服务”，...', '110034002']
# ['国企改革新思路', '卫祥云', '作为中国改革开放的重...', '2872162']
# ['远见', '[加] 布赖恩·费瑟斯通豪', '什么是成功的职业生涯...', '45185282']
# ['第3选择', '[美] 史蒂芬·柯维', '每件事都存在第3选择...', '1271600']
# ['华为增长法', '胡赛雄', '自1987年创立以来...', '151888317']
# ['州县官的银两', '[美] 曾小萍（Madeleine Zelin）', '本书写的是“西方到来...', '160094503']
# ['重塑制造业', '[美] 苏珊娜·伯杰（Suzanne Berger）', '2010年，面对美国...', '57504322']
# ['离经叛道', '[美] 亚当·格兰特（Adam Grant）', '如果当初为数不多的那...', '52529111']
# ['小趋势²', '[美] 马克·佩恩', '未来十年，能够再次影...', '106948095']
# ['克鲁格曼的经济学讲义', '[美] 保罗·克鲁格曼', '保罗·克鲁格曼，20...', '165423230']
# ['从零开始学开公司（图解版）', '任昱衡 编著', '在商业蓬勃发展的今天...', '169386135']
# ['投资的方法', '[加] 陈思进', '本书是一本由华尔街金...', '352240357']
# ['从0开始学创业：注册财税+运营管理+现金流管控', '黄剑锋', '在如今愈加开放的市场...', '403161536']
# ['一路向前', '[美] 霍华德·舒尔茨', '这是一个关于动荡、迷...', '582435']
# ['菜场经济学', '财上海', '自2009年以来，京...', '25901603']
# ['效率红利', '谢春霖', '这个世界缺的从来都不...', '389602568']
# ['团队协作的五大障碍（20周年纪念版）', '[美] 帕特里克·兰西奥尼,', '这是一本经典的管理寓...', '401076797']
# ['人人时代：无组织的组织力量', '[美] 克莱·舍基（Clay Shirky）', '一而再，再而三出现的...', '29261029']
# ['酒店行业卓越绩效管理', '熊浩', '国内酒店行业绩效管理...', '33505988']
# ['有效激励而不失控制权是怎样实现的', '郑指梁', '《合伙人制度》综合应...', '53915811']
# ['人才池：人才培育的靶心战略', '熊启明', '本书站在经营者的视角...', '157918944']
# ['影响力思维', '[英] 西蒙·泰勒', '“我的激情在哪里？”...', '126371378']
# ['全媒体运营师', '赵溪', '“全媒体运营师”是2...', '329981192']
# ['见证重大改革决策', '中国经济体制改革研究会', '本书的口述资料几乎涉...', '135762486']
# ['总经理（珍藏版）', '[美] 约翰 P.科特（John P.Kotter）', '本书是迄今为止为数不...', '120749861']
# ['逆向盈利3.0：新商业时代的八大硬核模式', '周导', '当下企业的盈利模式正...', '160336700']
# ['创新与企业家精神', '[美 ] 彼得·德鲁克（Peter F.Drucker）', '创新是企业家的标志，...', '59399678']
# ['创造共享价值', '汪若菡', '中国大多数消费者对于...', '52668995']
# ['OKR使用手册', '姚琼', '作为《这就是OKR》...', '114706662']
# ['中国式财富管理', '金李', '中国的财富管理市场在...', '50258568']
# ['卓有成效的管理者（精装版）', '[美] 彼得·德鲁克', '本书主要面向企业管理...', '446724488']
# ['小米创业思考', '雷军 口述', '雷军首部作品，完整解...', '406826458']
# ['情绪流龙头战法', '杨楠', '本书是关于龙头战法最...', '397240552']
# ['交换之物', '[美] 柯浩德（Harold J. Cook）', '本书是作者潜心研究2...', '388757014']
# ['企业文化与绩效', '[美] 约翰·P.科特', '约翰·P.科特对企业...', '120007630']
# ['高效能人士的影响力法则', '[美] 史蒂芬·柯维（STEPHEN R.COVEY）', '美国学界“思想巨匠”...', '131302846']
# ['爆款内容方法论', '休斯', '什么样的定位能够脱颖...', '439853820']
# ['资本与共谋', '[美] 希尔顿·L.鲁特', '在过去的半个多世纪，...', '46310023']
# ['95后的第一本理财书', '洪佳彪', '初入职场的95后看似...', '153576277']
# ['赢利：未来10年的经营能力', '李践', '创业容易守业难，中国...', '322975403']
# ['注册会计师全国统一考试习题集·会计', '注册会计师全国统一考试命题研究中心 主编', '本书以新版《注册会计...', '46915561']
# ['强势谈判', '[美] 克里斯·沃斯', '这是一本引人注目、不...', '37939692']
# ['中国经济增长十年展望（2019—2028）：建设高标准市场经济', '刘世锦  主编', '党的十九大报告指出，...', '120185214']
# ['公共资源的未来', '[美] 埃莉诺·奥斯特罗姆（Elinor Ostrom） ', '本书为2009年诺贝...', '38832911']
# ['世界前沿技术发展报告2020', '国务院发展研究中心国际技术经济研究所', '本书于2020年年初...', '160113607']
# ['创新', '[美] 威廉·鲍莫尔（William J. Baumol）', '绝大多数学者一直将价...', '28773736']
# ['滕泰透视通胀', '滕泰', '近两年，通胀已经成为...', '31944409']

# %%
headers = {
    'Accept': 'application/json',
    'Accept-Language': 'zh-CN,zh;q=0.9,en-US;q=0.8,en;q=0.7',
    'Cache-Control': 'no-cache',
    'Connection': 'keep-alive',
    # Already added when you pass json=
    # 'Content-Type': 'application/json',
    # Requests sorts cookies= alphabetically
    # 'Cookie': 'll="118254"; bid=p0MbXH3C560; douban-fav-remind=1; viewed="1019568"; uaid="463930cab3ef9f57c6561d57780f661f443b7eff"; _ga=GA1.1.68034132.1711168608; _ga_RXNMP372GL=GS1.1.1711168608.1.1.1711169564.60.0.0',
    'Origin': 'https://read.douban.com',
    'Pragma': 'no-cache',
    'Referer': 'https://read.douban.com/category/103',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36 Edg/122.0.0.0',
    'X-CSRF-Token': '.eJwFwQkBACEIBMAuJpBdPCCOPPaPcDPLtKPAi7Mb8opftEyF9hjrEK5TWbLx_JCwsGuO7EZ4EusHTOIRbQ.Zf5gGw.CvDpwPt4iy898t03ZYlXNuWU5LA',
    'X-Requested-With': 'XMLHttpRequest',
    'sec-ch-ua': '"Chromium";v="122", "Not(A:Brand";v="24", "Microsoft Edge";v="122"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

for i in range(len(L)):
    book = L[i][3]

    json_data = {
        'operationName': 'getWorksComment',
        'query': '\n    query getWorksComment($worksId: ID!, $limit: Int) {\n      works: works(worksId: $worksId) {\n        worksType\n        ... on ColumnWorks {\n          columnId\n        }\n        \n    ... on WorksBase {\n      comments: mixedComments(limit: $limit) {\n        \n  ... on CommentBase {\n    id\n    isHidden\n    \n    \n  ... on CommentBase {\n    id\n    works {\n      agent {\n        id\n      }\n      \n  title\n  url\n  isChapter\n  isOnSale\n  hasOwned\n  agent {\n    id\n  }\n\n    }\n    user {\n      id\n      avatar: picture(size: MEDIUM)\n      avatarFrame\n      name\n      url\n      ... on Agent {\n        agentName\n        hasMedal\n        agentId\n      }\n    }\n    createTime\n    commentType\n    ... on Review {\n      url\n    }\n    \n  ... on Review {\n    badge {\n      url\n      image\n      title\n      color\n      label\n    }\n  }\n\n    ... on Annotation {\n      url\n      isPublic\n      isNote\n    }\n    \n  ... on WorksRecommend {\n    score\n    isEditorChoice\n  }\n\n  }\n  \n  ... on CommentBase {\n    works {\n      agent {\n        id\n      }\n    }\n    user {\n      id\n      isVip\n    }\n    hasPurchasedAllBadge\n  }\n  ... on Discussion {\n    donation {\n      amount\n    }\n  }\n\n\n    \n  ... on CommentBase {\n    id\n    content\n    commentType\n    works {\n      agent {\n        id\n      }\n    }\n    user {\n      id\n      ... on Agent {\n        agentName\n      }\n    }\n    ... on Discussion {\n      refComment {\n        id\n        user {\n          id\n          name\n          url\n          ... on Agent {\n            agentName\n            agentId\n          }\n        }\n        \n        createTime\n        content\n      }\n    }\n    ... on Review {\n      title\n    }\n    \n  ... on Review {\n    badge {\n      url\n      image\n      title\n      color\n      label\n    }\n  }\n\n    ... on Annotation {\n      \n  ... on Annotation {\n    originContent {\n      rawTexts {\n        text\n        type\n      }\n      startOffset\n      endOffset\n    }\n  }\n\n    }\n    ... on WorksRecommend {\n      title\n    }\n    ... on ReviewComment {\n      refComment {\n        id\n        content\n        createTime\n        \n        user {\n          id\n          name\n          ... on Agent {\n            agentName\n            agentId\n          }\n        }\n      }\n    }\n    ... on AnnotationComment {\n      refComment {\n        id\n        content\n        createTime\n        \n        user {\n          id\n          name\n          ... on Agent {\n            agentName\n            agentId\n          }\n        }\n      }\n    }\n    ... on WorksRecommendComment {\n      refComment {\n        id\n        content\n        createTime\n        \n        user {\n          id\n          name\n          ... on Agent {\n            agentName\n            agentId\n          }\n        }\n      }\n    }\n  }\n\n    \n  ... on CommentBase {\n    id\n    commentType\n    isHidden\n    \n    content\n    user {\n      id\n      name\n      isBlocked\n      ... on Agent {\n        agentName\n      }\n    }\n    works {\n      id\n      cover(useSmall: true)\n      title\n      \n  title\n  url\n  isChapter\n  isOnSale\n  hasOwned\n  agent {\n    id\n  }\n\n      agent {\n        id\n      }\n    }\n    \n    ... on Review {\n      url\n      upvoted\n      upvoteCount\n      commentCount\n      works {\n        isFanfiction\n        markAsFinished\n      }\n    }\n    ... on Annotation {\n      url\n      upvoted\n      upvoteCount\n      commentCount\n      isPublic\n      isNote\n      \n  ... on Annotation {\n    originContent {\n      rawTexts {\n        text\n        type\n      }\n      startOffset\n      endOffset\n    }\n  }\n\n    }\n    ... on Discussion {\n      targetId\n      upvoted\n      upvoteCount\n      works {\n        title\n        url\n      }\n    }\n    ... on WorksRecommend {\n      url\n      upvoted\n      upvoteCount\n      commentCount\n    }\n    ... on ReviewComment {\n      targetId\n      upvoted\n      upvoteCount\n    }\n    ... on AnnotationComment {\n      targetId\n      upvoted\n      upvoteCount\n    }\n    ... on WorksRecommendComment {\n      targetId\n      upvoted\n      upvoteCount\n    }\n  }\n\n    \n  ... on WorksRecommend {\n    id\n    works {\n      id\n      \n    title\n    cover(useSmall: true)\n    url\n    isBundle\n    coverLabel(preferVip: true)\n  \n      \n  url\n  title\n\n      \n  author {\n    name\n    url\n  }\n  origAuthor {\n    name\n    url\n  }\n  translator {\n    name\n    url\n  }\n\n      isColumn\n      isFinished\n      wordCount\n      wordCountUnit\n      isInLibrary\n    }\n  }\n\n    \n  ... on CommentBase {\n    id\n    commentType\n    content\n    works {\n      id\n      title\n    }\n    user {\n      id\n      name\n      isBlocked\n      ... on Agent {\n        agentName\n      }\n    }\n    isHidden\n    \n    \n    ... on Review {\n      title\n      rating\n      upvoted\n      upvoteCount\n      commentCount\n      works {\n        isFanfiction\n      }\n    }\n    ... on Annotation {\n      upvoted\n      upvoteCount\n      commentCount\n    }\n    ... on WorksRecommend {\n      upvoted\n      upvoteCount\n      commentCount\n    }\n    ... on Discussion {\n      targetId\n    }\n    ... on ReviewComment {\n      targetId\n    }\n    ... on AnnotationComment {\n      targetId\n    }\n    ... on WorksRecommendComment {\n      targetId\n    }\n  }\n  \n  ... on CommentBase {\n    id\n    commentType\n    content\n    works {\n      id\n    }\n    user {\n      id\n      name\n      ... on Agent {\n        agentName\n      }\n    }\n  }\n\n  \n  ... on CommentBase {\n    id\n    commentType\n  }\n\n\n  }\n\n      }\n      commentTotal: mixedCommentCount\n    }\n  \n\n  ... on WorksBase {\n    id\n    title\n    isFanfiction\n    markAsFinished\n    isColumn\n    isFinished\n    isOnSale\n    review {\n      id\n      content\n      ... on Review {\n        title\n        url\n        rating\n      }\n    }\n  }\n  ... on WorksBase @include(if: false) {\n    rating {\n      rating\n    }\n  }\n\n      }\n    }\n  ',
        'variables': {'worksId': book, 'limit': 10},
    }
    resposn_book = requests.post(url='https://read.douban.com/j/graphql?name=getWorksComment', headers=headers, json=json_data)
    for comment in resposn_book.json()['data']['works']['comments']:
        print(comment['content'])
        c = L[i]
        c.append(comment['content'])
    L[i] = c
# Out:
# 不要赚钱了就想着提高自己的生活水准。尽可能衣食住行简单，轻松。
# 打破他人期待。
# 要将好喜欢加入习惯。
# 感觉好有道理，从小就被灌输了太多应该，应该怎么样，应该怎么样，很多时候根本不是自己想要做的。
# 幸福就是内心的安宁与平静。
# 心随我动
# 避免刷手机，沉迷于网络游戏同样这个道理。
# 有道理哈哈哈
# 独特的见解。哈哈哈
# 认同，需要利用起来这些新时代的杠杆。
# 1
# 1
#
# ⭐重点：马斯克工作理论
# ⭐重点：马斯克五步工作法
# 敢于承担责任，勇于担当，真正的领导者。
# 一天时间就能调和心态并作出如此反应，的确异于常人。
# 人有的时候就要夸大其词，特别是在生意场和需要博弈的场合。
# 哈哈哈哈哈哈哈哈
# funny
# 太疯狂了
# 值得一读！
# 垄断市场
# 约等于东风（二汽）
# 说白了就是包税人。
# 为何我国政府的债务总额居然没有一个明数呢？？
# 胡焕庸线
#
# “黑河——腾冲”线
# 这么多。。
# 我们
# 今天
# 我
# 多尝试，多试错，用量变去撬动质变，瞎猫总会遇到死耗子
# 想起资本运作选秀的，大量签合同，最后能出来一两个就赚了
# 宰相肚里能撑船
# 致富和守富
# 致富就是自己什么都没有，就一条憨憨的命，所以敢打敢拼
# 守富就是自己拥有了，所以要小心翼翼，如履薄冰
# 至于多少算拥有，那就要看自己是否有知足的心
# 不要去攀比
# 我期待一碗大米饭，你还给了我一碟泡菜，艾玛好幸福
# 说了又好像没说
# 诀窍是：别把鸡蛋放在一个篮子里
# 其实就是合理的止盈
# 至少为自己卖命，而不是工作和title
# 永远看清且理解这两个阶段，并在此过程中坚持“正确的做法”，是能够在投资中长赢的关键。非常庆幸，在我开始投资之路的第一年就面临下行的市场，并且在此时，我可以笑对他了。
# 哈哈哈
# 哈哈哈
# 指的是2015年股灾。禁止场外配资。
# 心压激增
# 在人生旅程中重要的伴侣关系处理上，何尝不是如此，女友选择了离开，纠缠颇多，最强烈反应就是以下:被忽视，被忽略，轻视，无视，藐视，疏忽，不关注，不注意，不在乎，不考虑，不理不睬，装聋作哑，放弃，躲避，否认，拒绝。
# 解读信息和认知信息差异，形成判断也存在差异
# 1.确认信息完整性
# 2.分析信息内在逻辑和蕴含深层信息
# 均值回归
# 均值回归
# 按我理解，不可复返性应该是指对一件事情不太可能从陌生到熟悉再到陌生，一般来说，见到之后就会变得熟悉，只有从陌生到熟悉这个过程
# 我是卖掉亏钱的基金，保留赚钱的基金啊。
# 预期原理是指在人们的经济决策中，未来的不确定性对行为产生重要影响的理论。
#
# 预期原理在不同领域有着不同的应用和含义，在经济学中尤其是凯恩斯经济学里，预期被分为短期和长期两种。具体来说：
#
# 短期预期：关注价格变动，这会影响厂商的产量和就业量。
# 长期预期：涉及资本流动偏好，即投资者在持有货币和投资证券之间的选择。
# 此外，由卡尼曼和特维斯基提出的预期理论（也称作前景理论），解释了人们在面临决策时对潜在收益和损失的不同态度。该理论提出几个关键概念：
#
# 确定效应：处于收益状态时，人们倾向于选择确定的收益而非冒险可能带来更高收益的选择。
# 反射效应：处于损失状态时，人们更愿意冒险避免确定的损失。
# 损失规避：人们对等量损失的痛苦感受大于对等量收益的快乐感受。
# 综上所述，预期原理强调了未来不确定性对个人和企业经济行为的影响，而预期理论则更深入地探讨了在面临风险决策时个体的心理行为模式。
# 小鸟球难度更高啊，比标准球少一杆，成功率不自然少一些吗？
# 这个和前面说的“规划谬误”是否矛盾？
# 想起之前参与的项目，规划的时间和经费也是同样的问题：），规划得太乐观了。
# 我们并不是经济学家以为的那样理性人。我们常常不理性：）凭感性行事。
# 这个作者亲身经历的例子令人印象深刻
# 大家都容易犯的一个错误，不怎么听外部意见，估计是对自己比较自信。不信通常的情况，而是相信自己的判断。我自己也是这样，连写这本书的作者都犯这个错误呢，误以为自己可以很快完成这本书。
# 为啥我对于自己就是这种感受。自认为掌握了很多知识，但是现实却给我深深一击：）
# 这不答案之书？
# “chaos is a ladder”
# 1
# 根据过度补偿的来源可以将过度补偿分为主动的过度补偿和被动的过度补偿。主动的过度补偿是指个体意识到自己某方面存在缺陷，通过自身不断努力，克服缺陷，达到超出常人的水平 。主动的过度补偿是个体主动意识到自身不足而主动进行的过度补偿。而被动的过度补偿是指个体没有主动要求过度补偿，而是他人将过度补偿加于个体身上，以完成他人的愿望或弥补他人的缺陷。这种补偿最常见于家庭教育中。例如父母小时候由于条件限制没有接受教育，于是迫切希望自己的孩子能够不重蹈自己的覆辙，让孩子接受教育。
# 根据过度补偿的结果，可以将过度补偿分为成功的过度补偿和失败的过度补偿。所谓成功的过度补偿是指过度补偿的结果是积极的。这种过度补偿建立在个体对自己、对他人的正确认识的基础上。成功的过度补偿的例子很多，例如许多儿童自身存在某种生理缺陷，如左撇子，他们的右手不适合书写、绘画，但是他们并不放弃，在不懈努力后，不仅实现了用左手书写、绘画，而且工作比正常人更加出色。失败的过度补偿是指，个体没有对自己、对人生形成正确的认识，形成了一种不正常的过度补偿心理。他们无法正视自己的缺陷，不能以积极的心态去解决问题，最终只有通过侵害他人、牺牲他们的方式来超越自卑感。他们为了实现自己的优越感，不惜损害他人和社会的利益，最终非但不能实现正常的补偿，还会给社会带来危害。许多杀人犯都是因为不正常的过度补偿心理，不能正视自己的缺陷，转而用伤害他人的方式来获得自尊和优越感。
# 事实是该领域的学术研究能力高不代表在该领域的实操能力也会高，这点在文科专业尤其明显。个人认为不用过于嘲讽实操能力不强但在该学科领域职称高的人，毕竟学术职称考核的标准众多。
# 结构力学
# curious
# 机器 vs 生物
# YQ
# cool
# 沉得住气也很重要
# 但现在看来这些观点却很超前
# 哈哈哈哈。不愧是合格的投资人
# 驻马店这座城市的名称就是由此而来的吧，古代这里的驿站，是为南来北往的人和马匹提供休息的场所。
# 想到董宇辉说的，书是随身携带的避难所。的确是这样的。
# 比得到结果更为重要的是理清事物本身的前提。
# 有道理！
#
# 投资者要放大格局，不要只想着短期股价的涨跌，而是以创意者的坚韧，以长远的眼光发展的眼光，来看的企业级的格局，商业模式，环境的变化，从而看到企业长远的价值。
# 我们要理解所投公司是通过什么途径来赚钱的，有没有持续性和护城河。
# 痕迹学
# 品德高尚
# 通过阅读名人传记和文章，与他们思想交流碰撞，是个很美好的事情，会让人终身受益
# 士大夫文明
# 早到，看书看报
# 内在品质比时机、能力更重要
# 客观
# 嗯…但知道一家公司的实际价值又是很难的事情了。
# 值得一读
# 哈哈
# ？現實意義？
# 我不了解政治，以及考公这件事，却经常提出我的观点。
# 如何养成习惯，养成什么样的习惯，把吸收的原则嵌入自己的习惯中
# 当听到与自己意见不同时，本能反映是证明自己的正确性，再往深层次想是需求与恐惧，害怕丢脸，例如内心希望被认可的需求，在与别人沟通的时候是不是可以反过来应用这个原则，想给别人提出不同意见的时候可以先考虑到每个人的需求，措辞上可以认可态度、立场等内容取得听者的共鸣，然后再提出不同的观点，生硬提出观点会很容易激发防卫机制，沟通无效。
# 我总是喜欢定很高的目标，导致自己对自己的期待值很高，而又害怕达不到目标，导致自己甚至都没开始去做这件事，或者是中途而废。我有完美主义，一件事情我总是希望能够完成的很好，不接受瑕疵，导致效率低，并且得不到反馈。我总是对某一件事三分钟热度，导致未能完全掌握。
# 为啥我没看懂
# 当我有愿望时，先评估自己所处的事实环境
# 这个对于我来说非常重要。
#
# 愈发感受到延迟性的回报比短期就能获得的利益能让人学到更多东西。这个道理是我自己慢慢悟出来的。
#
# 很多时候我庆幸自己没有太看重短期内的物质利益，比如在学校里的活动分，在单位中的工资。我看过身边无数人因为太过于重视这种利益而丢掉了后期能够获得的某些机会。比如，在最开始就特别精于算计做一件事情能够得到多少分或多少钱，一旦这份差事的报价低于他们的心理预期，他们就选择不干。我在做一件事情的时候，让我决定做与不做的因素只有这件事我是否喜欢。如果我感觉做这件事我能得到快乐，我就会非常上心。这样的过程持续了一段时间后，我发现在这个过程中我所学到的东西，认识的人，得到的机会，是那些在最开始衡量了短期利益而选择放弃的人得不到的。
#
# 如果现在问我什么是财富，我会说财富是在这样一个过程中慢慢累积得到的知识、人脉与机会，而不是物质利益，物质利益只是这个过程中的附加利益。在这个过程结束之后，我可以用知识去换取物质利益，我会因为知识水平的提高而结识水平更高的人，他们会给我更多的机会。而这个过程不会停止，因为这个过程是自发的，在最开始我就是因为对某件事感兴趣而开始的这个过程，所以只要我对这件事或其他事一直都感兴趣，这个过程就会形成一个正向循环。这些感悟在我开始这个过程的时候我并不知道，而当我慢慢的得到了比别人多得多的机会之后我开始反思这件事。这就是我最开始说的那句话，这样的模式能让我学到更多的东西。如果我在开始做某件事之前，因为短期内的物质利益低于我的心理预期，而放弃去做这件事的话，我就放弃了后面更多的财富。不过也说明，这件事对于我来说是不够有吸引力的。
#
# 要获得这样的财富需要有长远的眼光，因为这个过程是漫长的，短期内很可能什么都得不到。而获得物质利益之需要短期的思维，那就是在我完成这份差事之后我能拿到多少钱。短期，可能内注重短期利益的人会比有长远眼光的人更有钱。我知道在我毕业后，那些已经找好稳定工作的人在三五年内会比我有钱的多，但是我也知道，我的财富总会到来，只要我保持对感兴趣的事物的好奇心。
#
# 所以这也让我思考，知识是什么，工作的意义是什么，财富又是什么？身边的人都毫不犹豫选择考研或者是工作，而我总是对这些事提不起兴趣，干到一半就选择放弃。我现在明白了，是我还没有弄明白这两件事情对我的意义，导致我不坚定。我总是比别人慢一点，复读，考研只考一半。可是我并不认为我学到的东西比其他人少。在这个过程中我不是被洪流推着走的，至少在洪流中，我能够原地漂一会儿，去思考一下我到底该去哪。
# 我们向往某事物时，情绪投入越多，第一次接触到此事物时情感体验也越为强烈，但是，第二次接触时，会淡一些，第三次，会更淡……以此发展，我们接触该事物的次数越多，我们的情感体验也越为淡漠，一步步趋向乏味。这种效应，在经济学和社会学中同样有效，在经济学中叫“边际效益递减率”，在社会学中叫“剥夺与满足命题”，是由霍曼斯提出来的，用标准的学术语言说就是：“某人在近期内重复获得相同报酬的次数越多，那么，这一报酬的追加部分对他的价值就越小。”[2]
# 目标是通过理性思考选择的东西，而欲望是本能的，如何控制欲望或者让欲望为自己的目标而服务是人生修炼的重要内容。
# 生活中遇到不幸遭遇，有这个心态容易释怀
# 羊吃人差不多也是这样一个过程
# 家
# 兵者，不祥之器，圣人不得已而用之。
# 顺应人性的政策治理成本才会降低
# 公权力
# 学会使用这套话术
# “公共需要”是本书的核心概念之一，然而却非常含糊。在此处似乎指“公共用途”。然而即便是公共用途，这也是很模糊的。
# “公共需要”这个概念是虚化的，必须要与具体的制度结合才有意义
# 思考下自己现在的工作里有没有踩刹车，目前看没有系统的工作方法和工作技巧，耗费了大量时间，来做本可以简化的工作。
# 量变引起质变，事物的增减是可以调控的，可以实现自己所要求存量效果。
# 日常按照一定的规律和秩序处理工作，长此以往，就会失去思考事物本质的能力。
# 理解一个观点是理解事物的一面
# 辨证的看待一件事物在不同前提下的结论，在个人分析问题是，灵活应对，对症下药，不应该照本宣科，一概而论。
# 如何帮助不优秀的人，找到他们自己的驱动力
# 公平背后是效率的考量
# 销售价格决定成本「同时更决定品质」
# 很好
# 我
# 任何一个组织的发展有三个最重要的引擎驱动。第一个，企业要想很好的发展，首先依靠的第一个驱动力，是市场的驱动力。什么是市场的驱动力？就是真正优秀的领导者，需要去善于发掘用户的需求，甚至要超出市场的欲望，或者是需求。
#
# 市场究竟他想要什么？用户最关注的究竟是什么？所以说不管是什么样的思维，互联网思维也罢，数字化思维也罢，它的本质是不变的，其实就是用户思维，谁发现了用户的需求，谁满足了用户的需求，用户就愿意把钱塞到谁的包里。这就是在企业的发展过程当中的第一个最重要的驱动力，市场的驱动力。
#
# 以前有人口的红利，人口的红利少了之后，我们找到了流量的红利，现在流量的红利也越来越少了。在这种情况下，其实最主要的因素就是用户的需求正在发生着改变。这样的情况下，企业在发现用户需求方面，企业该怎么做比较好呢？
#
# 企业在发现用户的需求或者客户需求的时候，一定要做到一种场景化的思考。什么叫做场景化的思考？就是企业要去思考我们的用户在什么样的场景下使用我们的产品，这样的话你的产品就能和其他企业的产品形成一个非常重要的差异化。
#
# 企业发展的第二个驱动侧重的是什么？叫创新驱动。当整个赛道变得竞争越来越激烈的时候，你发现你企业有的产品或者你企业有的一种特色，你的竞争对手也有。这个时候企业就该去思考，我们如何把我们的产品或者我们的服务做到新奇特新。在这种情况下，企业就需要第二个最重要的驱动力，创新的驱动力。
#
# 企业发展的第三个最重要的引擎叫做领导力驱动。什么叫做领导力驱动？优秀的领导者能否通过领导力把大家的热情，把大家的潜能，把大家的才华充分的给激发出来，或者释放出来，这就是领导力的驱动。
# 通用电气前首席执行官杰克·韦尔奇说：“领导者的作用不是控制人们或掌控一切，而是引导、激励和激发他人。
# 教会下属如何正确的做事
# 满足感或者成就感 是一个人做好的动力
# 这应该就是字节和阿里的差别～在阿里每一层级的ld都会被要求培养一个backup，这样会使得不同层级的ld 完成领导梯队的建立
# 经济下行，大厂裁员的当今，感觉这个问题是管理者普遍存在的问题，不论哪一级的领导者
# 除开部门的隔阂，从整体的利益出发
# 第五阶段能力
# 可惜我学习得太晚了，还在梯队底部
# 不要生气，不要教别人道理
# 机关单位，非营利组织（包含事业单位），企业
# 希望自己在践行中为卓有成效的管理者。
# 很早以前就有老师推荐这本书最近也终于看了这本书学到了好多东西，就比如如何成为一个卓有成效的管理者，阅读就是提升我们自身能力和领导力的重要途径，书中还介绍了战略执行的关键要素和实践方法，包括管理者将战略转化为行动，并实现组织目标。就需要包括建立战略地图，管理者需要制作清晰的战略地图明确组织的愿景，使命，价值主张和战略目标书中也为我们提供了一系列的管理实践和策略，帮助管理者建立和维护高效率组织，提高团队的效能和创新能力就包括了，建立明确的目标和愿景，管理者需要与员工分享组织的愿景和目标，并确保员工理解和认同。建立有效的沟通和反馈机制，管理者需要建立有效的沟通和反馈机制，包括定期开展员工会议，收集员工反馈和建议等。
# 这本书还讨论了创新的本质和成功的关键要素，帮助管理者在不确定和竞争激烈的环境中推动创新和实现持续增长，这本书也通过故事的形式，来揭示了团队中常见的问题和障碍，并提出解决这些问题的实用方法，帮助管理者建立高效的团队和良好的团队文化，以上是我对这本书的读书笔记，以及这本书对我的启发与影响。
# 「管理者」
# 这和理解别人的话语的能力有很重要的关联，需要倾听的能力，逻辑分析能力以及表达能力
# 我的有效性偏弱
# 那我之前确实是工作狂了属于
# 「协助」
# 学笨
# 有贡献工作才有效
# 创业的欲望很多人都有，但是创业前需要思考清楚哪些东西，并不是很多人知道。作者从自身创业经历出发，讲述清楚了这个问题。对徘徊在创业边缘的人来说，很有启发。
# 灵魂拷问
# 太多的本末倒置
# 需要一定的mindset的转变，有更长远和健康发展的眼光。
# 例如要克服稀缺、急功近利的心态。
# 红烧牛肉面
# 这两个因素有一个前提：金钱或者精力上要有一定的余量
# 996显然不是。
# 另外第二点也预示着要审慎的做决定：单纯的逃离（无论是不是热情驱动）未必会更好
# 精准
# 注意商业模式的特殊性
# 即使是在技术行业
# 需要同时具备远见和号召力。
# 消费型市场
# 真是掰开了揉碎了讲，为什么欧洲和东亚会分道扬镳。
# 海外扩张是欧洲能够重塑世界格局的根本条件。
# 要钱还是要生活
# 沉没成本误区
#
# 我最喜欢这句话“金钱等于自由和机会”
# 物以类聚，人以群分
# 通篇乱七八糟东拼西凑的网文感，不知道为什么出版了。别打开别上当……
# 在中国，大家的钱都是各花各的，很少会放一起花
# 感觉作者脱离了普罗大众，指的是特定的一个阶层
# 其实有车，吃到好吃的就是会让人感到幸福，这是物质上的快乐，没有什么不好意思的
# 不论践行哪种生活方式，成功的关键都在于要保持目标和过程相一致，而时间既是最重要的资源，同时也产生最大的复利。
# 哈哈哈，我奇怪的笑点呀
# 厉害
# 真知灼见，十年前预测的新冠😬
# 关于黑天鹅事件的书，以前从来没有，现在只有一本，难道只因此而读？ 是的，因“唯一”而读，这个理由就足够了。 你不认可的话，那你的理由是什么？
# 社会中存在着因我们无知而受到伤害的图，为知识的脆弱性设定了系统的限制。
# 人总愿意筛选符合自己想法的信息
# 2022年俄乌冲突的时间，可能会比我们所有人想象的都要长
# 同意
# 本能的会赋予逻辑
# 如：昨天阳阳给我看的白俄罗斯女性养家为主的现状，我就建立了因为苏联导致苏联时代各国男女比例失衡，从而因为供需关系，形成这种特殊的社会现象。
#
# 虽然我不认为我的逻辑有问题，但是确实我本能的在为他赋予逻辑
# 否定的答案只需要一个就可以证明某些事情，而正确的穷举却很难
# 说明就不应该由政府主导这件事，最好和最差结果一样，都没办法达到想要的水平
# 这个比喻太贴切了，13亿人出不来11个能踢球的就说明了基数大也有没办法做到的事情
# 制造最先进工艺的半导体过于昂贵。是什么原因导致成本居高不下。
# 中国依靠自己的力量能够生产稳定的满足要求的激光器吗？
# 中国大规模、全产业链的生产能力真的是不可替代的吗？某科技博主一直鼓吹这个观点，但没有给出有力的证据。
# 吉安·金泰尔（Gian Gentile）、M.苏尔金、A. T.伊万斯（A. T. Evans）、米歇尔·格蕾丝（Michelle Grise）、马克·维达（Mark Hvizda）和丽贝卡·金森（Rebecca Jensen），《第三次抵消的历史，2014—2018年》（A History of the Third Off set，2014-2018），兰德公司，2021年。《副部长关于第三次抵消战略的讲话》（Remarksby Deputy Secretary Work on Third Off set Strategy），美国国防部，2016年4月28日。
# 败也萧何，但成也萧何。
# 所有人都认为风险过大、壁垒过高的时候，只要能够跨过壁垒，那别人的壁垒就会变成自己最坚实的防护罩，不过是看谁更愿意付出代价、承担风险。
# 芯片是所有电器、机械、热武器的核心，日本、韩国、中国台湾、中国香港、新加坡都从芯片技术转移获益，并跻身发达国家或地区，有一阵日本甚至挑战美国，苏联、俄罗斯的失利也因芯片技术。中国那一章居然还提到了武汉芯片诈骗，用假台积电的名义。有点好奇没有写细一点的荷兰、英国、芬兰的，还有苹果的自研芯片。
# 😯
# 源于战争的终将归于战争，芯片产生与发展的脉络写得很清晰但是我怎么怀疑最后两章译者有地方没有直译？总之，不惮用最坏的打算预测未来，有些事终归无法避免。
# 测试一下
# 测试一下
# 29
# 28
# 27
# 26
# 25
# 23
# 22
# 21
# when need back to a question
# 什么是关键问题
# 以德鲁克《有效管理者》的基础上进行的发挥。
# 对领导力的Review，从（愿景/要务；时间管理；反馈；接班人计划…）几件事入手梳理领导力的关键，适合做回顾要点的框架。
# 在东方哲学里显然有更好的说法，可以避免“利己主义”被滥用。
# 一如洛克菲勒当年的标准石油的遭遇
# 哈哈哈哈
# 大品牌好的企业有定价权有底气
# 不能既要又要，任何事都要抓重点
# 了解他人真正的需求很重要
# 很好的商业模式
# 会议纪要的核心目的
# 信息共享
# 勇于尝试
# 还不错，讲了有钱人的思维方式和习惯，印象比较深的是要财务自由赚大钱就必须自己创业或者投资，要学会积累原始资本。开源节流！不断学习，学习，学习理财，投资。
# 要有自己的事业。而不是拿固定工资！
# 有钱人会承担更大的风险，而不是每个月有稳定的薪水。
# 牢记
# 收藏为读书清单
# 学以致用才是正道，习惯了不作为也是一种习惯。
# 由于个人认知的局限性，自己觉得好的决定不一定是好决定
# 察觉自己很多事情是因为恐惧，一种不安全感
# 赚钱应该是轻松的自己做生意，
# 想想父母对你的影响吧。有其父必有其子。家庭影响很大！
# still prevails in the current film industry
# 虚妄。
# 品牌价值。
# 简明消费主义史，一段与传播学和女性主义发展交织的历史。
# 人对自身独特性和优越性的追求，以及通过消费具有符号意义的商品来建立和维护自己的身份、地位、独特性和优越感，就难逃消费主义的陷阱。
# 每代人有自己的《小时代》😂
# 广告不仅贩卖奢华和尊贵，还贩卖浪漫。
# 也很大程度上影响了日本
# 这种商业模式就是我小时候买文具去的那些小商品市场的买卖形态。和百货商场的消费形态形成很好的对比。这里把为什么讨价还价描述的很清晰。
# “品牌”一词的来源
# 广告的表现手法
# 期待着
# 多重动机
# 总结得太好了
# 让人可以依靠自己生活
# 阅读理解能力多么重要
# 很好的问题
# 保障营养均衡
# 社会究竟应当如何运转才能为每个人都幸福提供些许保障？
# 有一种乐观主义的行动力！
# 嗯？去搜一下居然是真实事件。
# 对比原理
# 人的一种自动反应模式-做事需要一个理由，不需要理由很合理
# 影响力这本书是由美国著名社会心理学家罗伯特·B·西奥迪尼所写，本书的内容主要从六大影响力原理进行阐述，分别是互惠、承诺与一致、社会认同、稀缺、权威与喜好。向我们解释为什么有些人讲的话具有说服力，以至于我们上当受骗，书中也向我们讲述了我们如何成为一个对别人具有影响力的人。
# 这本书所带给我的感受还是有很多的，他能让我从中学到如何远离别人设下的圈套与陷阱，不被别人pua，比如日常生活中，在我们购买商品时，他们的营销方式是先向你介绍一款他们家不好的产品然后再向我们展示一款没那么差的产品，以此提高他们的业绩，让我们购买，这也算是商家的一种营销圈套，如果我们不留神，就会被说服购买，不知不觉进入了圈套。我们通过日常别人的影响力会认为对于贵的东西更加信任，总觉得便宜的东西质量肯定不行，这也是别人无形中带给我们的影响。里面有很多的精华语句，我最喜欢其中一句是“我们在请别人帮忙的时候，要是能给出一个理由，成功的概率会更大”，我理解为我们想让别人购买我们的产品就要有说服别人的理由，这样就会大大增加我们的销售量。
# 我的答案 a b c c b a c a d c
# 1d 2b 3a 4b 5c 6c 7b 8a 9d 10c
# 只有自己认知里主动起来
# 是不是需要更先进、更让人期待、更有作为的团体组织
# 价格贵=东西好的前提是对产品的了解少
# 1
# 利益驱使他们在一起
# 未必
# 不贪不嗔不痴
# 恐慌不比狂热更理性
# 银行的周期不是经济周期也比周期更长，银行的周期是不良的处置周期。
# 2023年是3000点
# 2003-2004的五朵金花部分来自于市场认知不到位
# 这能帮助我们真正评估价值.
# 如果信心不够, 就应该主动去细化思考.
# 这是ENTP 应该反思的点, 很多时候人际关系是有必要去主动维持的.
# 别总是想着延迟满足
# 其实仍然是一个很难的练习.
# 接纳自己, 走神身体的自然反应, 帮助把大脑从不良状况中解脱出来. 当然也要抽离出来意识到自己在走神.
# 我会再看一遍 进行深思
# 果然，一切分析都要建立在数据之上。
# 中国古代的货币经济是真的不怎么发展
# 既不是西方纯粹的市场经济体制，又与“岁入经济”有差别，所以说是单独的一种经济体制
# 低成本创业
# 需要关注究竟是已启动的增长引擎带来的规律增长，还是产品创新带来的增长，有没有可能成为下一个增长来源
# 需要先快速走一遍整个流程，早日发现问题
# 所以需要快速的经历完整的失败，了解不足，调整方向
# 通过不停的验证假设，来调整产品策略，验证价值
# 初期对话是为了确认整个愿景是否具有价值，市场以及可行性。所以需要对未来的主流客户展开，而非早起使用者
# 信念飞跃是在已有的认知基础上，提出大胆的超出目前市场的假设，并确认其产品会带来价值
# 类推法是根据现有套路去说明可行性，而第二种方式是通过市场需求推理需要做什么。类推法的优点是能清楚的看到产品是可实现的，但从市场角度出发，则是推理，风险性在于需要去验证
# MVP产品会反映出产品和企业的核心价值是否能够撬动客户，是否是客户真正所需
# 早期的实验对象，初期产品面向的群里应该是企业设想里最核心的客群。他们是最容易抓住的初期客户，也是在早期最能给出准确反馈的客户。小范围在核心客群内取得成功后再推广向更大的人群
# 逆天
# 贵=好，250的货涨价到500，却告诉顾客原本750打折到500，利用促销
# 影响力武器
# 🌟
# 负面情况发生后
# 主动露出去缺点
# 身为社会生物的我们，在整个生命中，不仅会对他人产生影响，同时也会受到他人的影响。在社会中，每个人都有自己的位置和作用，但并非人人都是强者。我们都很羡慕那些拥有独特人格魅力的人，他们能轻易地触动我们的心，但我们却为如何赢得他人的喜欢、说服他们并避免被欺骗而感到困惑。其实，这一切都源于我们对自身影响力的重视。西奥迪尼作为一名心理学家，在他的《影响力》这本书中，为读者揭示了影响的七大秘诀：
# 1.互惠原则：当他人为我们带来利益时，我们总是希望尽可能地给予回报。
# 正是因为我们的祖先在“有债必还的信誉网”中掌握了分享食物和技能的方法，人类才得以成为如今这种效率极高的社会结构。互惠是人类社会普遍存在的现象，也是最基本的道德准则之一。在人类的文化传统中，深刻的互惠观念和由此产生的亏欠之感是非常常见的。在商业领域，这种互惠原则被广泛运用到各种商业活动之中。为了缓解我们的财务亏损，我们会给予更多的回报，而“拒绝——后撤”则是一种令人不得不服从的高级策略。
# 请牢记：免费提供的样本并不是免费的！商家可能会从我们的亏损中获利，而我们可能会购买很多我们并不真正需要的物品。
# 2.喜好：我们倾向于听从那些我们熟知并深爱的人。
# 长相出众，与我们有着相似的生活习惯和背景，那些曾在一个充满活力和欢乐的环境中与我们相处的人，更有可能赢得我们的喜爱，并使我们更加顺从。
# 要想避免陷入困境，首先需要说服那些对此有深入了解的专业人士。因此，要时刻警惕自己对请求者的过度喜爱，将“请求者”与他的“请求”区分开来，仔细思考这个“请求”是否对自己有益。
# 3.关于社会认同：当人们在特定情境下决定应该如何行动或如何行动时，他们往往会模仿他人的行为和言论。
# 特别是当情况变得复杂、信息不清晰、人数众多的时候，从众的心态会变得更加强烈。当一个人在群体中处于劣势地位时，他往往会采取不合作或反抗等非理性反应来维护自己的权益，这就是所谓的“逆反心理”.这种心理与行为被称为“群体极化”。我们也有一种倾向，那就是服从与我们有相似信仰和行为的人，这也是青少年最容易受到同龄人影响的一个原因。
# 现代社会中海量信息所产生的巨大影响将使得人的无意识顺从越来越常见。所以，好好看看这《影响力》这本书，了解什么叫无意识影响，提高应对纷繁复杂世界时的免疫力对于我们而言实在是太重要了！
# 这是极为重要的
# 学习
# 国家的外交或政治决策，可不是会轻易被同情心影响的，它涉及考量到方方面面，背后的利益交换，牵扯到国家的整体利益。  作者在这里仅仅是以心理学的角度来理解和分析。但如果以此作为影响事件发展的决定性因素，就未免显得太儿戏了。
# 风险总是不期而至，没发生的不代表没有可能，关键在于能否承受
# 我认为一定程度上这些努力可以提高一点敏锐的思维。
# 以内在价值和价格比较作为锚点
# 思维敏捷，赋有洞察
# 要在赔率胜率很大的时候买入是最好的
# 在牛市时，很多人会忘记风险溢价，在没有额外收益时，去追求更多风险
# 当价格离价值太近甚至高于价值，你的风险就会很高
# 只有用概率进行主观评估
# 重要的是对于价值的估算
# 风险就是损失的可能性
# no highlight sign, decreacement people`s anxous?
# 应该有长期目标和短期计划，长期计划往往不切实际
# 失败是接近成功者的垫脚石，不是起步者的敲门砖
# 总感觉这里怪怪的，拿结果否定起因？因为失败了，所以最开始就不要这样做。或者因为宗旨没能真正的落实，树立宗旨就是多余的行为？
# 这个逻辑不能说错，但是否树立宗旨，和是否能够贯彻并没有强因果关系。
# 就如作者强调的信念，无非就两种情况，成功的信念和失败的信念。如何让信念成功，这是否依然是个人的能力或者机遇问题？
# 自然决策
# 列计划时要有激励性 成就感
# 做重大决定也适用这一点，例如个人赛道转换
# 卷
# 专业化的流水线服务如何操作？
# 设计出好看的产品：不一定有用
# 在做一个实用的产品同时设计出好看的产品√
# 显微镜下的大明说的是不能全都抽象地写史，这个是说要有全球视野，枪炮细菌也有全球视野，但是就不那么具体了
# 过于冗长，条理性有待加强
# 有点东西但写的太啰嗦了，像是注了水的毕业论文。以棉花为例阐述了资本主义的发展历史，跟教科书比起码不那么抽象，读完还是有收获的。
# 弹棉花这一生产形式直到21世纪最初的十年仍然在中国大地上十分常见。
# 我们现在栽培的棉花，相对自然的棉花来说，是不折不扣的畸形种了。
# 真恶毒啊
# 真是太搞笑了，知道他们虚伪，没想到能这么离谱
# 作者用相当中性，甚至可以说是不带丝毫情感的分解、剖析了从棉花种植到棉布销售这条产业链条，催生资本主义这一贯穿百年的课题。
# 虽然字里行间可以感受到雪白黄金产业资本下的血腥，以及武力冲突下原住民的苦难。但作者的把资本积累与奴隶制的结合称之为新颖的创新，把武力殖民土地称之为跨越式发展，在面对工人的压榨时细致描写了工厂主的罪恶，却也是为了论证如何更有效的把失去土地的劳动力集中起来转化为商品，并称其为远非公正且不偏不倚的市场。笔触之中似乎有总那么一种资本主义原始积累下理所当然的残酷和冷血。
# 资本主义从战争中对棉花产业的资源重组到工业化过度的解读相当详实，有英国和欧洲对资源和技术结合的成功，有埃及被保护主义在竞争中拖垮的失败，有巴西统治者对工业化颠覆其统治地位的恐惧，也有印度被殖民带来国家管理失控而被去工业化的过程。更有美国资本主义工业化和种植业经济冲突引发的国内战争。过渡成功的国家得到了资本的反哺，促进国内基础建设，过渡失败的国家动荡，资本流失。
# 全球化的扩张中作者花大篇幅和人物事迹讲述了工业化让棉花产业链条更加稳定，从经销商到经纪人，市场标准被一步步的确立，从粗狂式发展到精细化运营，从规模到品质，从实体到期货，这是产品扩张的必经之路，再到棉花实业如何催生金融信贷，如何依赖信贷，信贷如何因信赖整合全球化市场信息。
# 美国南北战争之后，棉花的供需市场重组，期货投机把地方市场的供求全球化，他们不是为了取得实际的棉花，而是为了投机棉花未来的价格走势，棉花市场被工业资本和金融主宰。在此期间印度、巴西、墨西哥、奥斯曼帝国等本土工业化棉纺织业迅速被资本主义棉出口业务摧毁，失业人口达到百万。中国《南京条约》被迫开放市场，中国的纺织业产品大多是家庭生产，所以没有受到去工业化的强烈冲击。但国家财政和大量家庭的收入仍然受到了剧烈影响，
# 虽然被资本摧毁的国家和地区各有各的不幸，但像英美德法俄日等棉花帝国的的资本积累却大致相通，资本主义的社会关系促进商品生产爆炸式增长。直到后殖民时代和后资本主义社会，随着棉纺织工人们的政治觉醒，全球范围内的帝国主义壁垒被打破。中国恢复了1842年就失去的关税自主权，国家建设和工业化结合让中国的棉产业开始有效竞争，才重新夺回棉纱生产大国的头衔。印度、巴西等曾经的产棉大国用自己的方式重新塑造符合自身利益的棉花市场。
# 1963年，利物浦棉花交易所大楼被出售，欧洲对棉花帝国的统治悄然结束，曾经风潮一时的织机进入了博物馆，曾经笨重的棉纺织工厂被改造成了购物中心和工作室。但棉花的影响力和世界生产和消费量仍然比以往任何时候都在增长，新的棉花帝国已经悄然而立。
# 资产的虚拟化
# 从粗狂式拓展到精细化运营，从规模到品质。
# 区别
# 第十章 销售KPI
# 看见了
# 非常重要！
# 非常重要！
# 非常重要！
# 这个案例非常的经典，很多时候如果别人犯了错是被扣掉100分的，那我们被扣掉5分好像不算什么问题，但是如果我们是在一个团队一个公司，当别人已经犯错的时候，我们不仅不能分手，还应该想办法去弥补他们所犯下的错误，这才是一个团队。
# 我的理解是首先区分成果指标和绩效指标，成果指标呢，是一个结果性指标，而且是一个很多个团队努力达成了一个共同的结果性的指标，所以它是一个总的结果指标。而绩效指标有点像是一种行为性质的指标，但是也指向一个行为的结果，但是通常这个行为可以由单个的团队甚至单个的个体来完成，所以他有点像过程一类的资料。加上了关键两个字，是说这个指标非常的重要，能够反映最本质最核心的特点。比如说一个企业最本质核心的特点要赚取利润，要赢得客户，要让员工满意，这就是关键成果指标。对具体一个团队而已，那你就要去寻找这个团队它真正的关键的行为，结果或者说它要输出的价值是什么，那么这个就是他最关键的绩效指标。
# 关键绩效指标与成果指标的区别：可以理解为成果指标是一个结果性指标，它很重要，但是它并不能说明成功的原因；而关键绩效指标是影响结果的重要因素，是过程性指标。
# 一旦把绩效和薪酬挂钩，绩效指标就变成了政治指标，被考核人就会和考核人进行谈判、斗智斗勇。但如果不和薪酬挂钩，似乎又失去了激励的价值。该怎么办？
# 轻微的通货膨胀是可以的
# 目前的股票市场是存量财富分配，而真正要做到的是创造财富价值，是未来希望能做到的方向
# 2023年150%
# 那么占GDP高的经济部门又是什么呢？为什么融资的少呢！是需求少还是供＇给不足呢？那地产融资那么多为什么整体的经济贡献又那么少呢？
# 熊彼特
# “量化宽松”中的“量化”指将会创造指定金额的货币，而“宽松”则指减低银行的资金压力。[6]同时，之所以要通过“量化”是因为名义利率逼近或者达到0，利率政策失效。[7] 中央银行利用凭空创造出来的钱在公开市场购买国家债券、借钱给接受存款机构、从银行购买资产等。这些都会引起政府债券收益率的下降和银行同业拆借利率的降低，银行从而坐拥大量只能赚取极低利息的资产，央行期望银行会因此较愿意提供贷款以赚取回报，[8]以纾缓市场的资金压力。
# 直观看不到，但可以感知
# 倒果为因
# 前途是光明的，过程是曲折的：）一个意思
# 将滑向标准的囚徒困境
# 也是"外部秩序"的一根支柱
# 民族的概念或有文化分类诸多客观标准，但民族主义必定与政治边界相符。
# 对于被统治的民众，民族主义、意识形态、个人主义等都是其可采取的"日常政治策略"，只是未必总能在合适的时候选取合适的策略。
# 若将新教视为对已有的社会利益机制之否定，则在矛盾明面化后重新考虑现实的实力、利益关系，则为否定之否定。
# 借助宗教的形式，使有共同利益诉求的分散的主体得以成为一个共同体。
# 傻逼玩意，意识形态那么重干嘛？Ta mere de pute
# 这句话强调了在全球资源稀缺的今天，仅仅依赖传统的方法去创造财富可能导致财富的过度消耗和环境破坏，而不是真正的可持续发展。
#
# 1.资源有限
# 2.环境问题
# 3.经济的多样性
# 4.全球化和合作
# 任何潮流之下 独立思考很重要
# 未来的一种解释
# 苹果现在想想是真的牛啊！我为什么去读商科或者MBA也是希望可以做出些什么改变，一直认为管理和商业有其自身的客观规律，是一门系统的科学
# 这句话感觉说的有点决对
# 全球最大的支付平台
# 这样的跨跃，可以给举个案例吗？
# 所有的发明，要有商业模式闭环
# 现在是2023年，我29岁，作为创业者人教育行业，发现现在的学校已经偏离了！我念小学的目的是为上中学)上中学的目的是为了上高中，上高中是为了上一个好的大学！！！！！！！而不是真正为了学东西而去教育，只是小地方感受到的。
# 供应量增加，价格不是应该下降吗？有没有专业人士来解答一下
# ？
# 不
#
# 阿
#
# 以黄金作为本位货币的货币政策
# 以黄金作为货币的方式
# ？
# ？
# ？
# ？
# nice
# 驱动力1到2到3，跟公司的规模，发展时间，团队大小有很大的关系。初创公司要解决吃饭的问题，然后解决大家的利益分配问题，最后是实现个人价值。如果反过来，公司是没法发展的。而且，如果我们打乱顺序，去哪找那么多岗位的价值观和个人价值观刚好匹配的人，HR要累死。
# 自我管理也是最难的，对组织来讲也有很多不确定性。
# 驱动力1.0，2.0和3.0不是独立的关系，是同时存在的。有些工作就是要靠1.0和2.0来做，现在很多行业和地方还远没有实现单独靠驱动力3.0就能完成工作的。
# 人靠欲望驱动啊，欲望驱动是另一种利己行为。
# Open source
# 社交货币
# 马斯洛需求
# 之前也看到过类似观点 计划高质量的娱乐也是可遇而不可求的。
# 第二类越来越多 也更有价值
# 在第四次工业革命之前，当下十余年是发展中国家最后的发展机遇期？
# 经济基础决定上层建筑，男女平等不是说出来的，而是做出来的。
# 只掌握单一技能的人才越来越容易被替代，就业将会变得“逐水草而居，顺天时而动”
# 不是进行人与机器的对抗（@我爱发明），而是进行人机结合，提高人的能力（抗拒这种结合的人，才会面临人机对抗的窘境）。
# 劳动力取代的两条路径：1.自动化带来的效率提升，直接取代人工；2.数字化处理，简化工作，降低对人工的需要，同时工作任务流程的优化，也提高个体员工的工作效率。
# 这一点很关键。技术产品的创新如果没能产生新的需求，总的生产效率就不会产生质的变化。
# 现在有novelAI，chatgpt，即便是脑力劳动也表现出了被取代的趋势，并且可以快速生产出大量的作品，效率上完胜人工。如此这般，永远不会被机器取代的岗位似乎并不存在，真正留存的唯有不断创新
# 这只是基于过去观念归纳的推测，但是归纳法不具备必然的真理
# 问题不是解释世界，而是改变世界
# 老龄化的弊端：1.赡养比急剧下降；2.大件商品需求减少；3.社会保守化，创业减少
# ！
# 指数级，幂
# 家政行业的100个细微感知点
# 谈恋爱也是
# 浮存金是我们持有（hold）但不拥有（own）的钱。在保险业务中，之所以会出现浮存金，是因为在赔付损失之前就先收取了保费，这一间隔有时会延续多年。
# 如何衡量成功的价值和失败的代价？本人认为，价值应该是被满足的欲望可以来源于精神或者物质。而代价，则应该用是否能被自我接受和认同来作为为基础考量
# 一点也不枯燥
# 原本以为是很无奈严肃的科普
# 没想到是些有趣的小短故事串联起来
#
# 看到这
# 好讽刺啊
# 省流：做个体面人
# 仔细想想真的是, 虽然很反直觉
# 这不就是现在国内的基金市场吗
# 还能混的已经是相对的成功者了, 真的输家早被扫地出门了
# 但丁
# 为买而卖为卖而买
# 剥削无止境
# 活着就是为了打工
# 消灭剥削
# 代孕行为也存在着类似的不平等关系，看上去是平等的交易，本质上是购买者的剥削。
# B
# 剩余劳动
# 利润率与剩余价值的区别
# 买卖平衡
# 不能闭门造车，要关心核心市场的需求
# 这是基本
#
# 用户粘性
# 用户粘性
#
# 可了解
# 方法论
# 体系
# 技术大神
# 案例公司
# 国外的知乎
# 尝试着只说重点，不要害怕遗漏部分信息，只要自己知道就行。
# 结构构成世界，通过结构认识世界
# 理论原著，回头浏览
# 对于思维的结构性提升具有一定的指导作用，非企业工作的也可以用来迁移学习，有一定的收获。
# 结构思考力的四个基本特点：结论先行（先总后分、先框架后细节、先总结后具体、先结论后原因、先重要后次要）、以上统下、归类分组、逻辑递进
# 1、基于目标定主题
# 2、纵向结构分层次
# （1）自上而下-疑问回答做分解
# 第一步：设想问题，从对方的角度出发
# 第二步：回答问题，提前想好答案事半功倍
# 为了确保问题不遗漏，可以使用5W2H原则检查
# （2）自下而上-概括总结做聚合
# 第一步：收集信息
# 第二步：分类
# 第三步：概括总结
# 3、横向结构选顺序
# 4、形象表达做演示
# ppt演示也要遵循结论先行、以上统下、归类分组、逻辑递进
# 要适当结合图表形式，寻找内容之间的关系使用概念图展示关系
# 时刻注意排序
# 将原因分类后进行概括更有说服力
# 原因也是可以被分类的
# 分解和聚合两个思路方向
# 结构思考力，结论先行，以上统下，别人才能听懂你要表达什么，这本书教人如何运作自己的思维，控制自己，不要被控制。
#
# 可共享的资源高效整合，压缩成本、提高效能，同时激发作为各市场触角建立自身独特优势，强化正向激励与良性竞争。
# 😓😓
# 非常正确👍
# Important
# Take note
# 何为议程&边界?
# Take note
# 要hold得住，不能急，这很重要
# Very true
# Take note
# Take note
# 按照当前市场条件，重新取得同样一项资产所需支付的现金或现金等价物金额
# 投资组合三条准则
# 客户给我们信任的根本，是确认我们敬畏受托者责任。
# 大道至简，悟透及得道。
# 风险溢价是指？
# 对税负敏感是？
# 准则、目标、自我认知，其中我认为目标占据主导地位
# 重点是内容，技巧可以忽略不计
# 数字化转型路线图
# 这是一本信心十足的数字化转型书籍。为什么数字化转型失败率高？这是一个直击灵魂的好问题，因为这个问题可以把当前数字化转型书籍分为三类。第一类是悲观奋斗类，这一类书籍认为数字化转型就是革命，就是企业要接受环境巨变的选择，在这种大浪淘沙面前自然是亡者众生者渺，所以企业转型失败率高是一个时代宿命，企业能做的就是尽力而为，至于结果，小半靠努力，多半靠运气。第二类是拒绝回答类，这一类书籍直接回避这个问题，不回答并不是因为单纯的不愿意，更多是因为他们不知道，所以上来就基于作者的实践、观察和想象来提供转型的建议。第三类就是积极自信类，认为指出数字化转型没有那么悲观，也没有那么可怕，只要方法得当，企业就可以高概率生存，成功完成转型。这本书显然就属于第三类，而且还是第三类中的突出卓越者。具体看点如下：
# 第一、明确提出企业数字化转型不可怕，真正可怕的是转型没有章法。
# 这本书最大的看点就是旗帜鲜明，这种旗帜鲜明体现在三个方面。一是旗帜鲜明的说企业数字化转型可以行。在当期企业数字化转型失败率高的背景下，指出转型很难、转型前景很悲观显然不会有太多被打脸的风险和压力，而回避问题、默不作声也不会有任何违和感，因为大家都知道无法这个问题不好回答，对作者没必要过于苛责，但是敢于说出转型可以成功，那就需要相当的勇气和笃定。
# 二是旗帜鲜明的回答了为什么当前企业数字化转型成功率不高。为什么成功率不高？这个问题悲观奋斗类不用回答，拒绝回答类逃避回答，作为积极自信类的典型代表，作者指出原因很简单，失败的企业转型没有章法，没有找到并按照可靠的准则去推动企业数字化。
# 三是旗帜鲜明的回答了企业数字化转型怎么才能提高成功率，到底需要什么样的准则。作者没有原则性的大而化之，也没有技术性的点到为止，而是实实在在地把旗帜鲜明进行到底，给出了一份明确的企业数字化转型检查清单。
# 第二、提出了一套准则支持下的数字化转型路线图。
# 作者并没有将自己对企业数字化转型的建议停留在了一个碎片化的检查清单层面，而是提出了一个转型框架，将检查清单彻底融合在框架之中，形成一个转型工具的整体。
#      这个转型框架包括五个部分，分别是确实基础、单点突破、局部同步、全面同步和活力DNA。
# 一方面，作者的这个转型框架充分体现了充实感和结构化，为每个部分安排了不同的关键任务，并将检查清单事项挂接在关键任务之后，既实现了检查清单的系统化，也让关键任务有了衡量和管理抓手。这样的结构化设计使得框架具有了更强的可操作性。
# 另一方面，除了结构上的特色，这个转型框架内容具有很强的逻辑属性，既契合事物发展的一般规律，强调先基础后上层，先局部再全面的顺序，又符合当下的转型和未来转型相结合的理念，强调企业转型DNA的培育。
# 综上所述，这本书最大的特点是旗帜鲜明，以及对数字化转型的十足自信。
# 放之四海而皆准啊，辩证运动的观点
# 虽然喜欢看书，但是从来没有写过书评，最后还是因为这是一本关于投资方面最值得看的书。
# 他的意思是净利润应该把折旧和摊销加回来，因为实际上这部分在后面的资本支出中回找补回来，
# 巨大市场中的dominant player，且其业务性质具有较高转换成本
# 典型的逆向投资
# 巴菲特买在拐点发生后，一项长期有价值的业务，由于不妨管理层的经营不善遭受挫折，但业务基础仍扎实，在更换具备能力的管理层并发生改善时重注投资。
# 充分体现了集中持有核心资产的选择!
# 有价值（类特许经营权模式，且低成本）的公司陷入暂时的经营不善，但其内在价值未有大的折损
# 为何当时能以这么低的估值成交？有什么特殊的背景？市场很低迷？
# 普通商品型企业的成本领先战略。
# 量学经典
# 两连阴就买入
# 重点
# 通过量比来选股
# 基本比较详细，能给才入的人 有个了解
# 乖离率
# MACD与KDJ
# 简单易懂
# 抄底逃顶
# 简单介绍了一些指标和操作方法，小白可看
# 环球同此凉热
# 离开制造业也正是这个时候
# 这就是前面说的在中国投资的非对称性
# 非常危险
# 核心结论
# 降低利率是因为什么，提高私人部门盈余？
# 值得关注的思路与观点，书写于2019年新冠之前，我也认同后记中新冠是加速了的未来通胀的走势，目前各国的利率都趴在了地板上，债务的高企牵制利率进退两难。增长的乏力迫使当政者不得不转向更为激进的措施，与过往的宽松不同，这一次是直接给老百姓发钱，加上新冠对供给的冲击，供需错配，导致了此次的大通胀。至少目前还看不到回落的希望，新冠是黑天鹅事件，当下异常的通胀回落是必然事实，但很难说未来（正常的通胀）不会快于当下央行的治理目标。尤其是在人口和逆全球化的浪潮之下。
# 读起来不是很顺畅。
# 还行。人口对宏观经济的影响，之前见的不多。
# 日本更是如此，乡镇房子空荡荡
# 十几年前的书，从2001-2009年采访那些在高科技公司工作的白领，她们也经历蓝领的裁员、待业、再上岗、下岗的循环，她们把求职当做一人公司、个人品牌来经营，受社会思潮、公司与员工关系的变化，她们把裁员、失业当做个人的事，但这些明明是一整个社会的事，如今还在继续。
# 不大自在：）说得很准确
# 在现实中看到的就是如此，很多人去图书馆等地方，为了找到规律和工作的状态吧。
# me too
# 这句话感觉很像我。
# 同病相怜
# 《谁动了我的奶酪？》是一本寓言式管理书籍，主要探讨变化对于个人和企业的意义以及如何应对变化。
#
# 这本书通过四个角色：两只小老鼠“嗅嗅”和“匆匆”，以及两个小矮人“哼哼”和“唧唧”，在迷宫中寻找奶酪的故事来比喻现实生活中人们对变化的反应和适应。
#
# 变化的预兆：小老鼠“嗅嗅”能够敏锐地察觉到变化的迹象，而“匆匆”则是立刻行动起来寻找新的机会。
# 抵抗与否认：“哼哼”代表那些担心变化会使情况变糟而选择否认甚至抵制变化的人，而“唧唧”则是最终意识到变化可能带来更好的机会并学会适应的人。
# 面对现实与采取行动：当奶酪（即我们追求的目标或梦想）消失时，“嗅嗅”和“匆匆”迅速接受现实并去寻找新的奶酪，而“哼哼”和“唧唧”则分别代表了拒绝接受和最终接受现实的态度。
# 总的来说，书中的奶酪象征着我们生活中所追求的各种目标，如工作、关系、财富等，而迷宫代表着我们所处的环境或生活空间。通过这个故事，作者斯宾塞·约翰逊试图告诉读者，变化是不可避免的，我们应该学会预期变化、监测变化，并迅速适应变化，以便在不断变化的环境中找到自己的“奶酪”。
#
# 通过讯飞星火认知大模型而来
# 书的内容：20世纪90年代至21世纪初，美国高科技行业大规模裁员和失业的状态下，个人主义的职业生涯管理者（暂时失业者）的意识形态是怎样影响求职、生活、物质的方方面面。
# 感想：各行业变化越来越快，在经济、社会、文化、政治交织的影响下，每代人都有需要克服的命题。保持乐观，不断的成长迭代和认清没有“终身职业”的现实是必要的，努力过头不可避免会产生个人能力的影响大于社会所能施加的影响的错觉，让自己过多承担“失业”所造成的恶劣情绪。通过扩大现实的边界，可以一定程度对未知祛魅。终身学习，并接受职业生涯是一段段，或是高低起伏的波浪线，认识到个人的渺小和伟大，或许是应对短暂而漫长的生活的良药。
# 职业生涯管理的个人主义亲市场哲学强化了这两种直觉，把抗议的缺失上升成前瞻性实用主义和男儿自强的证明
# 情感、职业、物质
# 财富
# 双向对称公共关系是卡特利普与森特一起提出。
# 定义：在公关的目标上将组织和公众的利益置于同等重要的位置上；在方法上坚持组织与公众之间的双向传播和沟通。
# 目的：是使组织与公众结成一种和谐关系。
# 强调：双向沟通、双向平衡、公共交流。
#
#
# 其书《有效的公共关系》中提出公共关系工作中最重要的工作流程（“四步工作法”）：公共关系调查、公共关系策划、公共关系实施、公共关系评估。
# 相比而言，美国偏向于在自由发展中产生的一些公共关系。英国对公共关系的理解是有针对有目的性的。
# 思想核心：投公共所好（一个组织在决策之前，应先去了解公众的需求和兴趣，然后有针对性地展开有科学理论指导的说服性宣传，再在迎合公众要求中争取其支持）
# 贡献：把公共关系学理论从新闻传播领域中分离出来，并对公共关系的原理与方法进行较系统的研究，使之系统化、完整化，最终成为一门独立完整的新兴学科
# 核心思想：说真话、讲实情
# 口号：公众必须被告知
# 强调：凡是有益于公众事业，最终必将有益于企业或组织
# 贡献：1 、提出了关于工商业应把自己的利益同公众利益联系起来，                    而不是对立起来的观念
#            2、与最高决策者和管理人员打交道，并且只有在管理人员积极支持和亲自处理的情况下才实施计划
#            3、与新闻媒介保持公开的畅通的信息交流
#            4、强调使工商业具有人情味的重要性，并把公关工作做到雇员、顾客和邻居中去
# 这里
# 现阶段的中国，这种逻辑还成立吗
# 估值，估值，估值！
# 对国内外宏观经济政策、形势、数据要有专业的学习和观察。
# 表现好是因为牛市起点时，它的估值很低吗
# 比喻不太恰当，夏利的基本面可能不如奔驰，但奔驰的估值过高也确实不是个好的投资，去买比亚迪吧
# 行业第一，个股第二，仓位第三
#
# 信仰才能坚定持有
# 坚持就是胜利，长期投资知易行难，坚持不下去的时候，干点兴趣爱好的事，只要基本面没问题，套牢就套牢吧，不急。
# 价值投资，正和游戏，认准基本面和估值，不在估值过高时加入到零和游戏中，戏看大风大浪，在估值过低的超跌中坚持住，淡看小风小浪。
# 上升到哲学层面了
# 想起来《非诚勿扰》里面的“风险投资”，风险越大越要投资hhhhhh
# 资本收入＝收益率*(资本/收入）
# 技术增长率也是经济增长的重要参数
# 阿富汗
# 拉丁美洲
# 欧美日
# 中国
# 朴素加速主义
# 丘吉尔：贫穷是共产主义的温床
# 重要的观点和理论陈述其实篇幅有限，罗列了太多数据和事实去佐证。和马克思恩格斯的著作恰恰相反。
# 历史上伟大的人都有穿透现象看本质的能力，高度抽象提炼概括的能力是他们的特点 。数据只是工具，数据的准确会降低我们抽象的难度。但是不会代替这种能力。
# 现在社会的分工越来越复杂，社会结构日新月异。但是马克思对资本的划分还是基本可以囊括所有。希望真正的21世纪资本论能够要么在马克思著作上有所发展甚至更高一层面的分析，要么能够将理论转化为方法论去实践。
# 期待。
# eu4里就这个选不了
# 除非制定新的交易计划。
# 这类收购的结果是什么？
# 这个组合很有意思，bu期现如何实现此类操作，缩小基差并控制风险
# 同业价格指的是同一行业内不同企业或机构之间相互交易的价格水平
# 通常的想法也的确是想要第一，而忽视自我满足。我认为自己的自我满足就是能在股市上获得体面的收入。
# 提前花钱
# 盘感
# 主流舆论对金钱的评价是偏激的
# 完全看不懂
# 精辟
# 怎么去安排事情
# 与过程控制不同
# 书的前半部份讲了个故事，我以为会一直讲下去，因为我挺喜欢这个故事的。结果后半部份就开始特别干巴巴，又好像听懂了，又好像恍惚了。推荐是因为这个方法确实值得传播。
# 这里最精华最浓缩了
# Story value & 验收标准
# 会议分两部分：筛选目标 & 量化目标
# 我理解这个是用于辅助衡量目标足够有挑战，并不是定了目标再看信心，而是信心也是指定目标的一部份。
# 看起来是，目标只是概述，简短，鼓舞。
# KR则是对目标的严谨解释，即DoD。
# 还是前面说的不断强调重要的事儿
# 没太明白后面说的和这里的标题有什么联系…
# 大体可以，细节不够
# 恰好在这个时间点上，看到了这本书，是一种小幸运。
# 一系列环环相扣的“合约”，制定并实施方案、满足需求
# so，在现阶段，不同的县区，应该采取怎样的发展（竞争）策略？
# 这就对了
# 感觉任何形式主义，都是有话语权的人群所把控，最终形成是对大多数公民的接受度的一次次试探所形成的最终形式。
# 不想有异类的出现。
# 王莽改革的失败突出了激进式改革的一种后果；而东汉的结果又表明，吸取地方势力将带来王权旁落
# 突出了统一的中央帝国的重要性
# 要么是国家过分扩张压缩市场；要么是市场过分扩张，导致国家进而相关职能被压缩。一种情形走到极端就会朝着另一种情形演化
# 即专治、庞大的国家机器
# 也就是说西方的发展只是整个宏大历史上领先的一步
# 这原本就是这种扭曲
# 中国的政治经济体制是一种动态的平衡
# 中国的政治经济体制是一种动态的平衡
# 因为低工资意味着什么交换的物品减少，生存成本加大交换价值降低
# 作者希望能批判辩论性的去思考，产出有效信息，在于通一字的理解，通则是融会贯通，通畅之意。
# 没懂
# 为什么呢？没理解
# 这段话的意思是说增加社会财富的行为被认为是投资，所以投资和储蓄是一回事？
# 所以凯恩斯的通论里并没有区别储蓄和投资
# 像分支branch一样遍布
#
# 这一段抓住了许多事物的此消彼涨的规律背后的影响因素，说明很好理论的成立是有先决条件的，情况不同用同样的手段会得出不同的结果。
# 与人对话，辩论，是验证自我认知的方法。前提是，大家能够有效的沟通和对话
# 劳动力削减，货币工资下降，但边际效率提升，实际工资上升。
# 人们往往喜欢从成功者那里寻求经验，却忽略了失败者的经验其实也很重要
# 🤔
# 涉及数学计算的部分比较需要耐心
# 涉及数学思维的部分比较实用，在日常生活中要找机会练习
# 想起前老板总是觉得自己的娃stupid
# 哈哈哈有意思
# 看了一半，看不下去了。
# 先说内容，拿着已有的各种理论，再想法设法和数学关联起来，拼凑成了这么一本所谓的底层逻辑。但这个底层逻辑是用数学去解决了问题么？并没有看到这种思维的体现。说是底层，最终还是其他理论的表面描述，一锅大杂烩
# 如果说真的想证明数学是世界运转的底层逻辑，（哦不对，太广义了，作者主要是说商业的底层逻辑是数学)那应该说明所谓的底层逻辑是什么，怎么通过这种逻辑定位到影响问题的因素，怎么推导出对应的公式的，而不是拿着一些已有的经济学或者管理学的结论说这个就是数学。别的不说，就说所谓的加减乘除去对应各种财务指标，能不能告诉我资产负债率为什么用除？而不是用减？我是通过这个所谓的底层逻辑思考出的为什么用除法吗？
# 再说文笔，太多啰嗦无用的话了，根本不是为了证明某个论点而写，就好像只是在闲聊，把闲聊的话语音转文字就出了本书
# 事实不一定
# 规模
# 观角=行动=70%~80%有效成功率。
# Mental account
# 老九门 -10
# price earnings ratio
# 股价/每股税后利润
# 基于价格vs基本面
# 策略类型分类
# 到底在工三小
# 無法有目的的預測，又具有隨時改變收益的敞口，成為風險
# 不管風險，追求報酬率的模型
# 選擇投入多少資產、投資什麼樣的商品
#
# 是否可視為資金槓桿的決定？
# 投資人還有什麼其他的行為偏差？
# 如何證明他們是有正向關係的？read the paper
# 能够展现价值的人
# 类似于罗翔老师说的，你现在的成功很大一部分不是通过你努力就行的，更多的是命运的安排。
# 类固醇是哪方面的药
# 生理层和精神层都需要能量维持
# 《稀缺》提出的带宽变化导致
# 不管哪方面做事情，都可以用到这一理论
# 自己对自己期望值要拉高
# 历史遗留环境的影响的延续
# 很奇怪的是，疫苗也是送的
# 有时一些关键性小改变确实可以改变引起好的结果
# 没理解，支付出去的也是收入吗？
# 重要概念
# 重要概念
# 可回收标准的考量
# 风险和安全是第一位的
# 那印度呢？
# zi3（音同“紫”）议
# 首次公开募股（Initial Public Offering）是指一家企业第一次将它的股份向公众出售。
# 通常，上市公司的股份是根据相应证监会出具的招股书或登记声明中约定的条款通过经纪商或做市商进行销售。一般来说，一旦首次公开上市完成后，这家公司就可以申请到证券交易所或报价系统挂牌交易。 [1]有限责任公司在申请IPO之前，应先变更为股份有限公司。
# 你好
# 和银行一样，银行也靠这个利差活下去。
# 人贵在自知之明。
# 知足常乐
# 中美交好才有未来
# 真话不全讲，假话全不讲.记得是在哪本书里面看到的.
# 克制的力量往往在关键的时候体现，每一次的复盘都是对自己的重新认识.
# 忽视风险造成不良后果，呼吁政府来纾困....看来这么多年大家都没啥变化。
# 国内各种的五年计划。从效果来看，确实有用。
# 业务对象
# 一个环节出了问题，其实并非是某个环节本身的问题，也许是更前置的一个环节就出了问题，一环套一环
# 将营销的关注点从各项KPI挪到消费者本身，从办公室到楼面，从消费者角度出发考虑问题
# 营销，重在务实，能落地，可实施性。
# 有特殊意义的价格
# 低、高、等高组合
# 所以合适的促销是能够激起消费行为的
# 给消费的过程设计一个框架
# 设计产品的前期大量做一些测试与调研
# 情绪价值
# 过于复杂化
# 案例太旧了参考意义不大，再牛的企业也不行，但是有些通用原则值得记下来。他的书还是老样子，没有一个总结性的理论框架讲清楚题目。
# 一股清流，创新和创业管理，手把手教你做创新和创业管理，他成功的模式拿过来“模仿”，什么原则、方法，成功的经验等等
# 创新依赖于体制机制，是一种有章可循的能力，而非灵光乍现。
# 企业家🆚普通人  心态。思想不一样。
# 对这个系统的分析，然后选择的问题不优。
# 1 怎么能做到创造性得破坏，而又控制风险，需要用到下面章节说到得7中策略。  2 第10章专门讲到了，聪明得创新成功率反而不高 3 所以创新也有一些原则。   第二章  第一章节已经介绍了企业家精神得定义，以及如何做，第二章节介绍企业家精神在管理企业中应该如何实践。 第三章讲 具备企业家精神得企业得对外，对市场的战略应该是什么样的。 明天在这个框架下面再细化一下内容，以及我们应该怎么做的思考。     1 我们的测试创新，的一些建议。    2 测试组织的创新的文化应该如何开展    3   创新注意机遇，找问题比解决问题还要重要，看到一个问题和解决问题的机会价值更重要，我们内部的活动也可以向找问题多倾斜一点，组织找问题。
# 拍脑袋得创新，反而成功率更低，我们应该着眼数据收集，着眼现实遇到得问题，或者意外得收获来创新。
# To the point 重点
# 想的是很好的，可惜企业家社会没有来，资本主义说不定也。。。
# 直到今日，文中的实践经验和理论仍然适用。其中的教训仍在被各种企业实施并一如既往地错误着。大师，不得不服
# 科技可行性➡️经济可行性
# 消费者福利
# 不理解
# 关键词：快速增长
# 好主意。
# 我就是这样的
# 市场的净空不足，就要停止扩张，精耕细作。
# 注意看得财务指标
# 技术产品尤其如此。
# 颠覆性创新，价值是对社会的放大。
# 醪 láo
# 榷 què
# 糵 niè
# 秫 shú
# 牂zāng
# 猿猱 yuán náo
# 枸酱，拼音是jǔjiàng
# 不读枸杞的gǒu
# 偈 jì
# hè
# xiāo
# hù
# kǎo
# 傩 nuó
# solution
# 宏观
# 技术的概念
# 正在成功着，也正在失败着
# 嗯，这个预测已经应验，满大街滴滴车都是电动车
# 战略1：向高端市场“撤退”
# 战略2: 在特定竞争基础上最大限度满足客户需求
# 战略3: 营销推广，改变市场需求，使其跟上技术改进步伐
# 比如，某个奶茶品味研发出30种以上的口味，超出人们对口味切换的一般期待时，差异化的奶茶也就变的没有意义，不如提升拳头产品质量来得高效
# 营销4P之价格因素只有在匹配的成本结构基础上才能发挥作用。
# 原以为是“进击”高端市场，但其实是成熟企业面对新兴市场不得已而为之的“撤退”
# 重要的中层
# 一定要有个相信
# 这个例子，也挺好，突破性技术，要当突破性技术看，是新市场视角。
# 扩大视野，找各种机会，要可以自己真正去选择
# 抓住关键
# 如果做的不是最重要的事，意思就是你在浪费你的时间精力，本来就要更好的事情，现在只是普通了，和其他所有人都是差不多的状态了。
# 因为国家的税收靠烟草，褚时健也是摸到了国家的脉搏。
# 所以被拿下岗位的人，都是给予了一些支持，反正也不是自己出钱
# 专业上看这个段，法国人能进行系统化管理是因为社会制度的原因，社会制度形成组织的边界团体概念。早起中国社会是农村社会体系，没有团体、组织概念，大多数都是以家庭为单位的集体组织
# 褚老不变应万变的企业经营理念，让我想起了今日头条张一提到过的“本自具足”
# 经历过的，在后面的人生都有可能会用到。
# 种储橙也不是完全没有经验，经验来自于烟叶的种植，触类旁通。
# 种善因，得善果
# 销售团队可以与任何其他部门都产生冲突，包括产品，运营，甚至设计团队，平台业绩好功劳是产品或运营的好，平台业绩不好就是你销售的不好，看过太多各部门领导扯皮场面，下面的人真的心累
# 解决各部门老板间的互相打架，自上而下形成一套体系 （开个玩笑
# 这个计算方法极有可能业务间互相打架，只为让自己部门表象良好，苦的是分析师，哪边都不能的罪
# 核心中的核心
# 后端决策让前端花钱又快又准
# AARRR acquisition，activation，revenue，retention，referral
# 非业务部门直属数据分析师的困境：后面几个部门是不能自己分析吗？如果能自己分析不就是部门内部招聘几位取数，算数，外加听产品或运营的话，外加自己有些思考的分析师吗？为什么要单拎出一个BI部门呢？通过产品或运营分发项目给BI部门，中间的沟通，和对业务的不熟悉又损耗了多少时间和能量？
# 不合理，且高的吓人。但受环境和自身品牌影响，没有办法压下来。所谓赶羊式方法已经受限了，人口红利的消失，领域各种细分进攻，已经没有多少羊可以赶了。外加品牌型广告受长期品牌影响，已经不能教育消费者了，ROI根本压不下来
# fission裂变
# 这就是被人厌烦的洗脑重复广告？
# 那么未来几十年内油价是否会飙升？
# 错字
# 比牛排的多
# 为什么塑料的碳排放量会比水泥高？
# energy storage
# 理解能源行业
#
# 制造业转型和能源转型之间的关系＂
# 微波炉是不是也是这个原理？🤔
# 马克一下
# 核能发电在碳中和之中也是非常非常的重要
# 存款利率上限导致利率双轨制的结果是数量型手段
# 交易场景画像核贷
# 银监会于2017年3月末启动轰轰烈烈的“三违反、三套利、四不当、十乱象”收官，查出问题34.13万个，涉及金额17.56万亿元。
# 所谓“三违反”，是指违反金融法律、违反监管规则、违反内部规章；“三套利”，是指 监管套利、空转套利、关联套利；“四不当”，是指不当创新、不当交易、不当激励、不当收费。银监会从3月末陆续下发这些内容的专项治理工作的通知（45号文、46号文及53号文），开展银行业全系统大检查，被称作“三三四”。
# “十大乱象”则来自于《关于集中开展银行业市场乱象整治工作的通知》（5号文），包括股权和对外投资、机构及高管、规章制度、业务、产品、人员、廉政风险、监管行为、内外勾结违法、非法金融活动这十大乱象。
# 2021.10.29，人民银行、银保监会、财政部联合发布《全球系统重要性银行总损失吸收能力管理办法》（下称《办法》）。《办法》明确，我国全球系统重要性银行的风险加权比率应于2025年初达到16%、2028年初达到18%，杠杆比率应于2025年初达到6%、2028年初达到6.75%。
# 理财收益为负的起点
# 逻辑起点
# 通常情况下会增加授信机构，同时交易对手D
# 本身与A存在一定关联关系
# “三档”是指根据银行规模大小来划分三档存款准备金率，其中工农中建交和邮政储蓄银行六大商业银行、股份制商业银行和城市商业银行及部分规模较大的农村商业银行、县域农商行等农村金融机构分布实行13.5%、11.5%和8%的基准存款准备金率；所谓“两优”是指普惠金融定向降准政策和贷款比例考核政策。
# 定价能力缺失
# 多重约束下次优选择
# 基本通畅
# 重质不重量
#
# 今天的生成式大模型已经实现了语言智能和想象智能。
# 是我们对人性、智能过于神秘化和神圣化。
# 监督
# 以下内容是一名极好家长能写下的文字
# 太精辟了！
# 对比人类后者属于有意识创造，前者属于无意识创造。而无意识创造可能不知道创造出什么，岂不是更可怕？！
# 想象力
# 就像科学的终极理论一样，这注定是一个遥不可及的梦😌
# 我相信它一定能做的更好，但只是在它的层面。
# 也许永远都不会有答案😁
# 为啥是交割制度导致的
# l意义不大，适合小白看
# 第一句话存疑
# 不错
# 上周我分析到铁矿石为back结构下的政策性打压，导致暴跌，企稳后有向上修复基差的可能，但严重的主观投机心理使我做空，最终周尾损失惨重。
# 这里没明白是为什么
# 非常合理
# 精辟
# 赞
# 效率重启！！！
# 一般
# 👍
# 🤔
# 一概不能除外。指都在所指的范围以内。
# K线、分时、价格均在及价位几点共振买点
# 按我自己的策略来
# 长周期周线 中周期日线 短周期小时线
# 想不到的
# 和傻子同行，高贵的精灵融入矮人中，就要表现得像一个地精
# 广告宣传不要叫出愿望
# 窗口，向上 向下  阻挡 支撑 跳空，案例很好
# 提前发出信号，帮助研判买卖时机。
# 接连出现类似的高点，表明牛在发力，但后续乏力？
# 从8/28到10月3，一个多月时间都在徘徊，此时该买，卖，还是观望？
# 向上突破阻力，但有能力坚守新高阵地？待谨慎
# 收市价，创新高，超越此前阻力线
# 在趋势之后，出现锤子线（实体很小，下影很长）、十字线（O=C牛熊角力？）、吞没形态（2根，异色，后包前）。。在反转日上下影线处，可画出支撑线和阻力线，构成通道。之后一段时间在此通道线内波动，直至突破，新趋势出现……2/22初学
# 一批长影线，信号，市场有高价但收市价回落，到此高点受阻--阻力线？阻挡水平？
# 上吊线出现，还要等验证信号。比如，之后时段收市价低于前一时段上吊线实体。。如果高于，说明在涨……此上吊线就不会是市场全历史最高，或某一轮重大行情最高位，，
# 复读
# 特意戳穿别人是不是一种傲慢
# Apple？
# 税后利润扣除资本成本
# 很快读完的简易科普
# 618订金原来如此啊
# 原来这么早就进入老龄化社会了，出乎意料
# 那完蛋了，中国步入老龄化，00后开始躺平，90后老了完蛋了哈哈哈
# 这里真的看得生理不适，半小时团队里没有女人吗？
# 大可不必
# 好书
# 中国春秋战国时期
# 累吗？
# 哈哈，一口气看完了这本书。对于经济学专业而且从事金融行业的我来说，这本书还是太简单啦！就是很简单的通识读本。经济学的来由，五险一金，人口问题，买房问题，借贷问题，传销问题。
# 1-多元化发展-品牌延伸 2-
# 容易造成市场垄断
# bayer药业
# 重塑一个新品牌
# 然而这样的成功并不能作为品牌延伸一定会成功的依据
# 想化某事;做出假设;分步实施
# 恋战不追求完美找到当下可做的最优方案
#
# 需要搞清楚手上有哪些资源，如何运转起来，避免做独行侠
# 这是目标
# 具体 衡量 行动导向 切身相关 及时
# 具体 可衡量 行动
# 具体，可衡量，可行动，
# 建模 统计
# 小布迭代
# 审题力，逻辑力，分析力，行动力，沟通力，团队力，内核力，
# 具体操作方法
# 提供动力
# 每一段旅程的终点，都是下一个旅程的新起点，永远不要满足于当前得到的荣誉和成功，也不要总提“当年勇”，因为那代表着你还没有超越从前的那个自己。
# 如今部分外企，在一段时间开放专利，是否也是在迫使自己创新发明；反观国内的企业拿着别人开放专利后制造的产品，便开始宣称自己宇宙第一了。这可能是我自己的片面认知，但觉得还是要正视差距，或者说纵使遥遥领先，也要时刻保持谦逊，不满足于现状。
# 真我。这似乎也是一场寻找真我的修行之旅。
# 首先要抓住自己真正相信的东西，由心而生，找到属于自己的道。
# 一个贯彻到底的核心理念，一群对这个理念深信不疑、并坚定向前的人，一种不断进取、不断实践创新稳步向前的精神，加上能不断培养意念合一的有识之士的组织；传承与进步，犹如信仰。
# 读着读着我就在想，这本书可能不适合身在中国的人。因为怀揣如此胸怀的公司，迟早会被那些人撕成碎片，或者被碾碎在萌芽期，又或者被污染腐坏，这样的土壤根本无法生长出这种果实。
# 读着读着我就在想，这本书可能不适合身在中国的人。因为怀揣如此胸怀的公司，迟早会被那些人撕成碎片，或者被碾碎在萌芽期，又或者被污染腐坏，这样的土壤根本无法生长出这种果实。
# 一个注重和相信“钟表”的运转能力，一个注重“钟表”的华丽程度。
# 周期的来源原来是借货／信用
# 应该是借款产生的“收入”被用来还债
# 结论性的说法，并没有具体说明
# 结论性的说法
# 还有第一个降低利率
# 1. 债务减记 2. 紧缩政策 3. 财产转移 4. 债务货币化
# 其实正常情况下应该是正常波动是不会导致问题的，但如果强行将波动一直保持增长如使用量化宽松政策，尽管在政策延续时能够保持经济增长，但其实对其依赖很大，并且部分行业不景气，而另部分行业人满为患，将经济拔得越高摔得越惨，所以国家不可能冒险去使其摔下来。
# 细微的差别会导致更大的变化
# 历史是相似的不错，但历史之所以是历史，意味着过去的一切不会再同样的发生，只会有着相对变化。所以我们研究历史的同时也要面对事实的变化。
# 然后进一步导致流动性问题。即高通胀导致资本外流，导致流动性问题，促使央行印钞，进一步推高通胀。
# 张所强调企业家精神实质上是认为企业家作为一个团体在社会及国家上应该拥有更大的权力和影响力，而政府则从利维坦后退至公共服务的提供商，以较低的效率和二流的人才来提供一些当下企业还无法提供的服务。企业家在不掌握暴力的情况下真的能够担任社会的核心吗？他们又足够的能力和意志去为整个社会提供秩序及安全保障吗？在中国企业家这个阶层和对欧美开放有着不可分割的联系，正如最后一章所担心了，没有了和美国的特殊关系，中国企业家所面临的并不是企业活动或受到何种的负面影响，而且其自身是否还能够存在
# 人家马云可能想要的是垄断，不是企业家精神
# 于是我们就看到了这样的现象，当人们相互产生不认同时，往往争论都是徒劳的。因为每个人所认为的利益所在，跟他持有的观念有莫大的关系。 那么我们也可以从他所认知到的利益，来看到这个人背后的观念。 如果几个人在一起合作创业，其中一个人总是持有他的利益受损的观念，而从来没有考虑过其他的人的利益是否得到过保证，那么这个人一定持有很自私的利己的观念。因为在他的观念里面，不存在公平，和利他的想法。其他人提出的公平和公开，在他的观念里，是在损害他的利益。
# 还真是尖锐
# 满足某种需求购买商品花掉的钱，以及赚钱索要付出的劳动
# 文中提出把人类作为自然界的对立面的观点。这观点让人很不舒适。事实也证明了，地球在把自然作为对手的西方世界的主导下，产生了很多问题，打着为人类更好地生存的旗号做出的种种自利行为、生产的种种有害且不易被自然所消化物品，破坏了人类上百万年赖以生存的自然生态，产生了种种而不利于人类及地球其它生物的长久发展的种种恶果。
# 西方世界始终是强盗思想，和大自然——我们的母亲的合作是零和博弈。
# 而我们中国才是真正的合作共赢、长治久安的和平发展思想。
# 只是清朝晚期和近代时期的经济落后，让大部分中国民众对自己的文化理念产生了怀疑，看到西方经济好，便认为西方理念有用就盲目跟从，对自己文化全然摒弃。
# 但现在随着中国经济在世界上的地位的提高，中国人开始有了自信，并且也看到了西方理念对人类生存环境的破坏，从而开始对西方文化产生怀疑、开始批判西方的强盗理念，也渐渐正视自己的古老的文明。我们也开始用自己的思想理念去纠正、去改变世界，新能源的运用就是一个很好的例子。
# 中国越强，世界会越好。
#          再一次提出把人类作为自然界的对立面的观点。这观点让人很不舒适。事实也证明了，地球在把自然作为对手的西方世界的主导下，产生了很多问题，打着为人类更好地生存的旗号做出的种种自利行为、生产的种种有害且不易被自然所消化物品，破坏了人类上百万年赖以生存的自然生态，产生了种种而不利于人类及地球其它生物的长久发展的种种恶果。
#           西方世界始终是强盗思想，和大自然——我们的母亲的合作是零和博弈。
#           而我们中国才是真正的合作共赢、长治久安的和平发展思想。
#          只是清朝晚期和近代时期的经济落后，让大部分中国民众对自己的文化理念产生了怀疑，看到西方经济好，便认为西方理念有用就盲目跟从，对自己文化全然摒弃。
#         但现在随着中国经济在世界上的地位的提高，中国人开始有了自信，并且也看到了西方理念对人类生存环境的破坏，从而开始对西方文化产生怀疑、开始批判西方的强盗理念，也渐渐正视自己的古老的文明。我们也开始用自己的思想理念去纠正、去改变世界，新能源的运用就是一个很好的例子。
#          中国越强，世界才会更好。
#          再一次提出把人类作为自然界的对立面的观点。这观点让人很不舒适。事实也证明了，地球在把自然作为对手的西方世界的主导下，产生了很多问题，打着为人类更好地生存的旗号做出的种种自利行为、生产的种种有害且不易被自然所消化物品，破坏了人类上百万年赖以生存的自然生态，产生了种种而不利于人类及地球其它生物的长久发展的种种恶果。
#           西方世界始终是强盗思想，和大自然——我们的母亲的合作是零和博弈。
#           而我们中国才是真正的合作共赢、长治久安的和平发展思想。
#          只是清朝晚期和近代时期的经济落后，让大部分中国民众对自己的文化理念产生了怀疑，看到西方经济好，便认为西方理念有用就盲目跟从，对自己文化全然摒弃。
#         但现在随着中国经济在世界上的地位的提高，中国人开始有了自信，并且也看到了西方理念对人类生存环境的破坏，从而开始对西方文化产生怀疑、开始批判西方的强盗理念，也渐渐正视自己的古老的文明。我们也开始用自己的思想理念去纠正、去改变世界，新能源的运用就是一个很好的例子。
#          中国越强，世界才会更好。
# 未免武断了吧。
# 此处排版有错误
# 共同富裕了解一下
# 因果倒置
# 直播……？
# 根据趋势理论，股票价格运动有三种趋势，其中最主要的是股票的基本趋势，即股价广泛或全面性上升或下降的变动形势。这种变动持续时间通常为一年或一年以上，股价总升（降）的幅度超过20%。对投资者来说，基本趋势持续上升就形成了多头市场，持续下降，就形成了空头市场。
#
# 股价运动的第二种趋势称为股价的次级趋势。因为次级趋势经常与基本趋势的运动方向相反， 并对其产生一定的牵制作用，因而也称为股价的修正趋势。持续时间，从三周到数月不等，其股价上升或下降的幅度一般为股价基本趋势的1/3或2/3.
#
# 第三种趋势：短期趋势，反映了股价在几天之内的变动情况。修正趋势通常由3个或3个以上的短期趋势所组成。
#
# 在三种趋势中，长期投资者最关心的是股价的基本趋势，其目的是想静可能的在多头市场买入股票，在空头市场形成前卖出股票。
# 以四五年为标尺 要求自己，不要急于求成，不要追求快速盈利
# 看长做短，首先期货里没有一种趋势能一直不变，即使在确定的大趋势中，波动也可能把你三振出局
# 家族信托
# 可以和《集合资金信托管理办法》对照着看看
# 讲的不错，归类整理有助理解！
# 扶贫就是现代化
# 精准识别动态变化的贫困对象
#
# 精准判断脱贫的多样性需求。
# 精准帮扶最后一公里断层
# 可持续脱贫；
# 脱贫兜底；
# 科学脱贫；
# 脱贫最后一公里；
# 动员贫困主体的自主性
# 个人和国家的体制结构。扶贫最难就是要改变大家的“贫困来自个人失败和懒惰”的认识
# 正是局限于贫困文化，所以即使是很年轻的勤劳的人，也没有办法脱离贫困文化下的思想体系、生产关系和物质基础，因此无法脱贫。
# 所以要把贫困人民脱离贫困陷阱就需要资金投入（国家给河边村每户10万元建房）和人力资本（作者团队的高投入）；同时说明河边村的脱贫是不可持续发展的。
#
# 过渡期贫困或叫短期性贫困——由于社会转型时期遇到的经济损失而出现的贫困；长期处于贫苦状态，没有受到经济发展的带动同时没有社会福利保障的长期性贫困。
# 社会对于个人或某个群体的排斥导致了社会的不公平，同时这一排斥或者是不公平也造成了贫困。
# 扶贫使村民脱离了贫困的生活，但是在产业扶贫中，如果团队带来了与当地文化氛围和文化程度不匹配的制度体系，一旦团队离开，这个体系就会崩溃，这种扶贫是无法长久的。更别说致富。
# 教育是阻断贫穷代际传递的最好手段
# 高素质人口，决定国家的未来。
# 我30了才看到这本书，大梦初醒啊
# 他的投资是只赚不亏嘛
# 本书很多观点都很有启发性。
# 跟投
# 买入时股息率高
# 适合估值止盈的指基
# 方法
# 支付宝
# 不建议
# 小结
# 评估的角度
# 何其虚伪！！
# 太便宜了！！12.5美分 4000+平方米！
# 真是残忍
# 除了二元对立且支持者力量相当这种情况外，民主在意见多且分散时也会失效
# 个人参考
# 参考
# ？？？
# 可查阅一些相关案例
# 可做记录
# ？？？
# 人才识别和定位
# 绩效考核设置关键点
# ？？
# 竞争对手
# 不同意，这是内政的问题
# 太让人震惊了
# 哦莫这还是第一次知道，关于中国移民的历史还是一无所知
# 香港九龙寨？
# 政府对人工设置最低工资或对产品设置最低价格后产生的负面影响
# 落后群体需要好好反思😊
# 煽动族群对立的四部曲
# 有的专业毕业🎓即失业
# 腐败危害国家
# 激发族群意识
# 这个地方没懂，六个月后的价格确实由期货锁定了，但中间能赚多少这个不该有市场说了算吗？而且一旦套利者足够多，又谈什么利润呢？
# 隐含的条件是这些国家可能资本不足以及缺乏销售手段
# 卖家和买家数量增加其实是有利于贸易商的
# 三桶油对市场的控制力也在日渐减小，对应的事件就是国内地炼在市场上的话语权更重
# 强调社会主义国家，是因为冷战使得市场失灵，产生了供需的错配
# 废金属也不错，废塑料同上
# 战争带来了结构性的需求，我这里可以关注下新能源大基建需要些啥原材料
# 这说明谷物市场在那个时期有着巨大的供需不匹配，当今世界有什么东西供大于求或者是供不应求？俄乌战争发生后欧洲的天然气供给不足，covid期间的需求不足。但上述两点其实都属于短期的扰动，带来的影响只会存在一两年，结构性的增长动力来自哪里？绿色转型似乎算一个点，可以想办法先对接下相关的资源，绿氢、绿氨、绿甲醇，而且这中间可能会产生些衍生品交易的机会；此外可以琢磨下中国、印度以及亚洲其他国家发展的重心在哪里，什么市场最活跃，同样的，研究下欧美的国家最近在干些啥，有无转型的动作？
# 其实还是基于科技进步而产生的一种新的生意模式；对应的，今天的新的基建上的创新为人工智能和新能源，前者将会如何优化我们的决策？更高效的信息处理能力意味着可以做更小的散货生意，可以同时服务更多的客户？（这里思考一下为啥大宗不能做电商），后者其实并不能在生意模式上有创新，只是开辟了数种新的商品品类
# 利基市场是在较大的细分市场中具有相似兴趣或需求的一小群顾客所占有的市场空间
# 这说的是哪个国家已经很清楚了。#LaLaLand #Call Me By Your Name
# 工业革命的兴起大大促进了社会变革，经济的极速发展，工厂的兴起也改变了原来的社会模式，经济变革促进政治变革，旧的政治权利逐渐解体，掌握着新生力量的资产阶级登上政治舞台。
# 家庭的权利结构逐渐单一化，像中国传统社会，家庭是经济和文化教育的中心，所有的社会活动基本上围绕家庭所展开，学校的成立使得教育从家庭中逐渐分离出来。
# 近代西方资本主义的入侵使得中国传统以家庭为单位的的自给自足的自然经济逐步解体
# 元首回来了这片原来还是有出处的
# Home office
# 深以为然
# 川普，原来这本书不光预言我要参选总统。
# 果然，今天中国经历的。都是美国人早就经历过，玩剩下的
# 很有意思的认知
# 短小精干的小书
#
# 稍贵 5毛钱一页 LOL
# 关键因素是什么？
# 以客户为中心，以市场为导向
# 不一样的声音
# 如果一个市场营销方案不能产生自然销售，那么它的设计就是失败的。
# 不太懂什么叫“传递和沟通顾客价值”。不知道原文是怎么写的。
# 重点
# 平衡 的重要性
# 更高的性价比
# 可考虑差异化的方面
# 一个人做的过来么。。。
# 新产品原客户的产品开发策略
# 通用或定制
# 可以看，但不需要过于在乎
# 创意与效率的平衡
# 如何让下属说实话
# 下棋多看几步，太厉害了
# 敖志平心中也有，我心中也有，我想想一个具体的目标
# 这观点在2023年可能行不通，大家只想看自己想看的东西（别人不会想看）hyper individuallism
# ironic
# 最应该做的是乘胜追击
# 太对了，先交流再汇报
# 舍弃与放空
# 朝代的延续并不依靠明君还是昏君，大部分时候，官僚系统自身具有针对皇权强大的纠错能力（甚至直接架空皇权），以保证帝国的正常运行。
# 民为贵，社稷次之，君为轻。
# 不错，有启发。
# 任何人的任何观点基本都是屁股决定脑袋
# 重复观看
# 重复观看
# 重复观看
# 我们想掩盖，但是结果不会陪你演戏。
# 非常重要的原则
# 幸运纬度带地区
# 在开玩笑？销售汽车这个商品还钻法律空子？？？不需要通过碰撞测试？？出了事故也不打算赔钱是吧 真的离谱
# 然而马上就被 DJI 打得找不到北，现在已经淡出市场
# 创客也是对模块化生产方式的应用
# 数字劳动、数字剥削又怎么理解？
# 技术的创新与改革对人们实际的影响在于，了解一个高效率的工作就不必再去做低效率的工作。因为高效率工作收入多。节省出更多时间与精力幸福生活。
# 工业革命的意义在于让高效率的生产力取代人力或提高效率，任何事的效率都可以被提升，比如，人们不需要再花时间人力耕种，机器就可以。于是人们在家纺织，出现了纺织机代替人劳动。于是人们又钻研编织，又出现了编织机。节省出来的时间用来给人们思考学习。
# 现实捕捉，把现实世界的各个物件进行数字化和模型化，然后对这些数字化的模型进行更多个性化的创作，衍生。。。
# seeed和dji都是同样的思路，要做到这点，公司管理层就有觉悟，你的网站和产品应该双语呈现。你的产品英文版功能要和中文版一样好
# 这种放大效应的结果是有些人在20岁自己你做出了30岁都不可能做到的事情
# 创客是关于硬件的未来, 翻译的一般
# 知音体？
#
# 所以到底为什么设那么多领导
#
# 呵呵 汇丰真是 狗屎运护体
# 都是风险厌恶者
# ？？
# 这条件 新桥横竖不吃亏啊
# 这不还是不公平么，渣打没那么多资金，可以在报盘敲定后约定付款节奏和期限，这不能算作风险吧
# 原来不是律师提出的每一个要求都是合理的，不是都要照单接受的，即使是自己的律师
# 无论新桥用不用一方向另一方压价，两个出价者之间的竞买格局已经形成，买卖格局已经转为卖方市场，新桥甚至不需要有意无意的泄露双方的报盘，他们各自也会想尽办法打听对手的出价底线，果然是鹬蚌相争渔翁得利。
# 哈哈哈哈真有意思
# 本书对提高学习型组织的效能有较全面的启发，其中的五项修炼是：1、系统思考，注意事物的整体性及内在互通性；2、自我超越，保持创造性张力和生成力；3、心智模式，热爱真相，保持开放性；4、建立共同愿景，分享个人愿景，聆听他人，伙伴关系；5、团队学习，深度汇谈与商讨相结合，协同校正。
# 书中以“小舵板”来说明“高效杠杆作用”，十分贴切。小舵板是船上的“舵中舵”，它的尺寸只有船舵的很小一部分，作用是让转舵更容易，也就是让船转向更容易。船越大，小舵板就越重要，因为大量的水流会使船舵很难转动。
# 小舵板是高效杠杆作用的绝妙说明：微小的变革尽管很不起眼，却可能产生重大的成果！
# 现在都是在完成领导的愿景
# 当大家都是被工资和工作内容招进公司的，这样的组织就很难出现。
# 无为而治
# 勇于试错
# 反思目标与实际之间的距离
# 深度汇谈
# 换位思考
# 超越个人愿景，吸收发展创造共同愿景
# 开放的心态，共参
# 为塞缪尔·亨廷顿认为腐败可以和经济增长并存的理论提供了活生生的例子
# 「自由化改革以前，印度的民主并不昂贵，技术含量也很低。但1991年以来，金钱开始源源不断地涌入政治，2005年前后印度经济进入繁荣期后，这一趋势更为明显。表面上，各大政党囿于开销的严苛限制，好像没有花多少钱，但实际上，人人都心知肚明，这些热闹非凡的盛事每一次都可以烧掉数十亿美元。有学者估计，仅2014年的大选就耗费五十亿美元。这意味着印度和美国相比差不了多远，都靠大把钞票维系民主，唯一的区别是印度很多钱不写在账面上。要根治印度的腐败问题和裙带关系，普遍的共识是要先切掉政治黑金的毒瘤。不过，很少有政客愿意谈这个话题，这让亚达夫坦率说出“选举中人人都在用黑钱”显得尤为难得。」
#
# 摘自：《新镀金时代》 — [英] 詹姆斯·克拉布特里
# 在豆瓣阅读查看：https://read.douban.com/ebook/454911476/
#
# 本作品由新经典文化授权豆瓣阅读中国大陆范围内电子版制作与发行。
# © 版权所有，侵权必究。
# 「，印度过去的这个世纪由三种宏大叙事定义。第一种是尼赫鲁和甘地倡导的世俗民族主义，官方上这仍是印度政府的信条。」
#
# 第二种是「印度人民党和RSS倡导的印度教民族主义，是对第一种理念的回应。第三种是“基于种姓的社会正义”，如今代表低种姓群体的政党也开始在政治上崭露头角。不过，你如果有几分愤世嫉俗的话，可能会加上第四种：金钱。」
#
# 摘自：《新镀金时代》 — [英] 詹姆斯·克拉布特里
# 在豆瓣阅读查看：https://read.douban.com/ebook/454911476/
#
# 本作品由新经典文化授权豆瓣阅读中国大陆范围内电子版制作与发行。
# © 版权所有，侵权必究。
#
# 摘自：《新镀金时代》 — [英] 詹姆斯·克拉布特里
# 在豆瓣阅读查看：https://read.douban.com/ebook/454911476/
#
# 本作品由新经典文化授权豆瓣阅读中国大陆范围内电子版制作与发行。
# © 版权所有，侵权必究。
# 「这背后隐藏着棘手的政治难题。大多数丑闻细究起来都牵涉政党资金问题，以及政党所依赖的商界政治献金的收受方式」
#
# 摘自：《新镀金时代》 — [英] 詹姆斯·克拉布特里
# 在豆瓣阅读查看：https://read.douban.com/ebook/454911476/
#
# 本作品由新经典文化授权豆瓣阅读中国大陆范围内电子版制作与发行。
# © 版权所有，侵权必究。
# 即贪腐并非仅仅由人们的贪欲造成，还牵扯到政府执政能力不足这一更复杂的现实情况。
# 印度政府看似凶猛，但其实更像一头异常虚弱的野兽，随国情日渐复杂而在治理国家上越来越力不从心
# 「哈佛大学学者兰特·普利切特谈到印度政府的表现时，并没有用失败这个词，他的原话是“失控”：印度政府也有能力，主要集中在上层，但越往下问题越多。他写道：“警察、税收、教育、医疗、供水供电，这些和民生息息相关的领域基本上都是旷工、服务态度差、履职不力和腐败的重灾区。”」
#
# 摘自：《新镀金时代》 — [英] 詹姆斯·克拉布特里
# 在豆瓣阅读查看：https://read.douban.com/ebook/454911476/
#
# 本作品由新经典文化授权豆瓣阅读中国大陆范围内电子版制作与发行。
# © 版权所有，侵权必究。
# 「我们国家有这样一种传统：除明确可以做的事情以外，别的事都禁止。这可以一路追溯到英属印度时期。”几十年以来，印度都是从经济角度理解改革，很少关注政府采购这样的基本问题。中国政府非常高效，相比之下，印度政府有的领域插手过多，有的领域又管理偏松偏软。萨哈瓦尔简要地将印度的问题形容为“官僚主义的胆固醇”，认为这个低效且腐败横行的体制从内部堵塞了。」
#
# 摘自：《新镀金时代》 — [英] 詹姆斯·克拉布特里
# 在豆瓣阅读查看：https://read.douban.com/ebook/454911476/
#
# 本作品由新经典文化授权豆瓣阅读中国大陆范围内电子版制作与发行。
# © 版权所有，侵权必究。
# 「腐败背后隐藏着一个长期困扰印度的问题，即政府不够强势。高速发展的经济一直在试图追求外界更具活力的商业环境，同时也对政府提出新要求。不过，印度的国家机器有许多问题，常常无法满足经济发展的需要」
#
# 摘自：《新镀金时代》 — [英] 詹姆斯·克拉布特里
# 在豆瓣阅读查看：https://read.douban.com/ebook/454911476/
#
# 本作品由新经典文化授权豆瓣阅读中国大陆范围内电子版制作与发行。
# © 版权所有，侵权必究。
# 「从亨廷顿的观点出发，印度的问题与其说是腐败，不如说是未能有效利用腐败促进经济发展。尽管如此，印度陈旧的腐败系统还是为拉动投资做出了贡献，欺诈季过后连续数年的低迷经济形势就是明证。莫迪大力反腐，加强审计员、法官、媒体的监察力度，裙带关系在这一背景下确实低调不少。不过，陈旧的腐败系统停止工作的同时，并没有更为廉洁的新系统取而代之。官员害怕承担违反规定的风险，没有人敢做决策，新德里就此瘫痪。商人不再投资新项目，产业投资也大幅萎缩。」
#
# 摘自：《新镀金时代》 — [英] 詹姆斯·克拉布特里
# 在豆瓣阅读查看：https://read.douban.com/ebook/454911476/
#
# 本作品由新经典文化授权豆瓣阅读中国大陆范围内电子版制作与发行。
# © 版权所有，侵权必究。
# 尊重经济的周期性，西方的经济遭遇有很多值得现在警醒与借鉴，还有就是头脑要清醒～沉醉于迷梦中是不能长久的～对于个人就更要顺应经济形势规划好自己的人生
# 疫情后国内的景象
# 石油危机
# 我国才刚刚开始
# 经济增长及全球化果然是个复杂的故事，没有全球的视野是无法讲好这个故事。
# 黄金时代过去了，我们或许此生再难见到它
# 撒切尔的思想导师
# 有种王阳明的感觉。 花因为你看见而存在。
# 熟悉的情节
# 追求廉洁政治，坚持福利优先政治
# 如果指洛克希德案，应该是航空公司有关的现金受贿，地产交易指什么？
# 这已经是一个梗了
# 广告人哭泣……
# PayPal思想的源起
# wang
# 信念的力量
# 后发优势
# 保护主义(protectionism)，即以维护本国利益作为是否适用本国法律的依据；任何侵害了本国利益的人，不论其国籍和所在地域，都要受该国法律的追究， 使其得到该国认为其应有的惩罚。在国际贸易中以保护国内产业为目的的经济政策。
# 保护主义(protectionism)，即以维护本国利益作为是否适用本国法律的依据；任何侵害了本国利益的人，不论其国籍和所在地域，都要受该国法律的追究， 使其得到该国认为其应有的惩罚。在国际贸易中以保护国内产业为目的的经济政策。
# 哎…
# 多少有些理解和感同身受
# 有差距就有机会。
# monky first
# 自己革自己的命
# 计划本身并不是来源于持续跟进的客户需求
# 胜任感，自由度，自主权
# 这些指挥官首先需要做的是价值观上的认同，然后才是自主性。相当于授权前提是价值认同
# 因为工作需要而阅读，针对现在的工作环境了解精益的方式如何在大企业应用和渗透
# 一年后需要再次回顾
# 似成相识
# 怎么感觉大王卡就是学的这一套
# 保护企业的行业领导地位
#  立足当下，再展望未来
# 1.线上无门店管理成本
# 2.去中间化，去库存，商品贬值以及管理成本下降
# 3.更大空间让利消费者，降价的幅度也更大，更有竞争优势。
# 店网结合，线下门店脱离传统的营销模式，如苹果采用店门课堂、天才吧的形式，亚马逊以及现在国内比较普遍的自动结账服务等等，实现“0接触购物”、“用户体验优先”等服务
# 线上线下提供的购物体验，服务各不相同，此处举例。
# 还行吧‘提高了眼界
# 对数字化转型这个话题很感兴趣，所以在尽可能的了解数字化转型到底意味着什么的阶段。 对比BCG在Coursea上面的课程内容设置，这本书不是在讲述技术本身， 而是领导者或者决策者如何从战略布局出发拥有前瞻性的视野来准备和接受数字化转型的挑战，并且最终受益。
# 重视一线
# 视野
# 重点工作
# 创新，更快更好
# 目标和动力
# 三个属性的解释
# 供应链
# 人人共认
# 复杂性
# 成功原因
# 第一个问题
# 雅皮士
# 这些障碍不太容易突破
# 背景经历的互通很重要，生活经历而非成功经历
# 效率以及效果，核心问题需要明确解决
# 问题突出的人，会快速浮现出来，成为解决问题的契机
# 目标，顺带减少猜忌
# 引出真正意图，才能解决问题
# 说的容易做的难，打破障碍互相坦诚信任是最难的地方
# 我怀疑你在pua但我没有证据
# 同一棵苹果树上不同大小质量的苹果，它们的社会必要劳动量是不是一样的？平均样品是谁和谁平均，不同产地的红富士要不要平均？李宁品牌的运动鞋要不要和耐克运动鞋平均？
# 商品独特的使用价值，能够创造出比自身价值大的价值，消费者正是看中这个价值差额，才去购买商品。
# 工资定价基础衡量尺度？
# 因为提高了工作效率，工人生产单个商品的时间缩短，但不意味着工人可以有多余的时间休息，而是有固定或更长的工作时间
# 奢侈品，使用价值能不能跟价值画等号。我想，如果它带来的羡慕的目光与使用者的自信和心情也算使用价值的情况下。才算可以.
# 在劳动过程中，劳动不断由运动形式转为物质形式
# 每个商品的价值都是由物化在其使用价值中的劳动量决定的，是由生产该商品的社会必要劳动时间决定的。
# 加工？
# 消耗？
# 消费你的时间？
# 我是不喜欢沟通的人，未来要把沟通计划放在我的plan里面
# 保持局外人的清醒
# 好的jtbd案例，可以整理下来作为案例。
# 回归本质：
# 1.外包装的本质是什么？
# 2.因此它是需要符合的原则与要素是？
# 点睛之笔
# 标记
# ？really
# 一个坚定的假设或者
# 雇佣关系
# 好
# 对
# 奢侈品，医美，总裁班，心灵疗愈
# 一鱼多吃
# 人狠话不多，都是干货。
# 不要读想赚钱的人写的书——看似工具书，实则全是技巧和术层面的固定套路，泯灭灵性,广告行业真实抹杀聪明人。
# 非常喜欢金枪大叔，但这本书败好感。
# 非常自我的写作，想表达的意思全靠猜
# 2036—2050
# 进出口优势分析？
# 国情
# 正确提问的前提是：自己要懂。如果自己都不懂，没有进行深入的研究，提出的问题也只是很浅显的问题。
# 三个引擎
# 成为管理者的必经之路
# 工作内容与意愿度的最大转变
# 对于二级经理非常有效
# 全局思维的一个标志性观点
# 容易犯的错误
# 领导阶段三大能力
# 目标管理就是自己成功的关键
# 管理，管的事价值观，工作方式，流程制度，理的事业务团队 技术在正确的道路
# 很棒的一本书，这本书最早来自于2020年，集团总经理王军总的一次工作报告的时候，提到了长期主义，而后来在办公室的年度工作会议的时候，集团崔总分享说自己学的少，在军总分享这本书的时候，没有读过， 后来读了之后才明白很多东西，而这是一个过两年就要退休的领导说的话，于是买来这本书，开始看，放了快半年，最近一个月陆陆续续才看完，里面很多东西有触动，对我自己的岗位，以及我来看待公司的整体运营，和自己去分析事物有很多帮助，也是我会推荐职场其他人看的书，也是会推荐给自己总经理看的书。感谢那么多人的努力，让这本书在市面上得以传播，也感谢我自己，沉浸在这本书里面，去学习和分享。在本书的引申阅读里面有《罗伯特·鲁宾 在不确定的世界》《CEO接班方略：寻找具有外部眼光的接班人》这两本书已经买回来，后续计划看完，在这种延伸阅读的过程中会认识很多很好的书以及很优秀的作者，luckey
# 这个关于作者的故事也太令我惊讶了，这是爽文照进了现实？可是这种也从侧面说明，再完全认知清晰目标，然后分析学习之后，人的可能性真的是太丰富了，任何时候，任何开始都不晚，而且永远要自己看重自己，不管什么结果，没有自己看重自己，根本不可能有好结果。而好结果需要天时地利人和，但是都来自于一个大基础，自己看重自己。
# 终极的价值判断标准
# 好诚实以及坦诚的交流，在国内会不会比较罕见
# 每一个继任者最害怕的其实都是这个，每一个有想法的继任者最厌恶的也是这个。
# 哇塞，真的在尽自己最大的可能，避开自己的虚荣心，为了公司和集体的长远来做所有决策，太令人肃然起敬了。
# read这个工具简直要终身使用
# 其实人生的应对方式，何不是如此？短期的问题，尽量想办法解决，同步一定要每天花时间做重要和长远的事情，比如学习，健身和提升，都是殊途同归的事情。
# 这需要格局、见识、和敏锐度，而不仅仅是勤奋就能做到的
# 哈哈哈哈哈哈
# 牛哇
# 不侵犯隐私吗？
# 交付和交易
# 跨境財富管理的渠道，應該改變了
# 闭门盘点可以使用什么工具？
# 怎么执行差异化培养？
# 实际是将人才库以数据和报告形式，统筹到公司组织层面。
# 应该进一步提供组织表现或组织能力的数据。
# 需要考虑生产力生产方式半个世纪以来的变化，行业差异对企业规模和收入的影响不能忽略。
# 赫茨伯格双因素理论
# 管理者，试用期管理
# 招聘=buy
# 稳健:现金流，客户忠诚度，员工敬业度
# 胜任力定义
# 资源利用的理论框架
# 作为从农村中走出来的学者，刘守英老师又回到农村中去，探索中国的土地制度改革问题。本书从一个政策实践者和一线观察者的角度分析了中国的土地制度改革的制度约束和可能路径，认为中国过去四十多年的经济高速增长离不开土地制度安排与变革，从某种程度上说，土地以及土地之上的农民为中国的经济发展做出了极大的贡献。作者对“以地谋发展”模式进行了探讨，并指出了农民土地权利的残缺，最后提出了面向“城乡中国”阶段的土地改革方向。
# 可爹考
# 对乡村振兴的最大障碍
# 生猪，22.5一斤？
# 这就是“双循环”的精妙所在，既要以内循环为主，也要有外循环这支有力的督促之手。
# 3：基础产业提升效率+消费结构和产业结构升级+加强基础研发
# 这个名词要记牢
# 六稳是指稳就业、稳金融、稳外贸、稳外资、稳投资、稳预期工作，六保是保居民就业、保基本民生、保市场主体、保粮食能源安全、保产业链供应链稳定、保基层运转。六稳六保是2020年两会的重要知识点，它们两者的关系在于六保是今年六稳工作的着力点。
# 重点是“高质量发展”
# 资本开支又称 资本性支出 ，是指企业购置固定资产、无形资产的支出以及与之相关的贷款利息 支出。
# 四大支柱
# 这段话表述的是质量的根本问题
# 到时提一下
# 重要章节
#
# 质量是检验出来的，也是制造出来的，更是设计出来的！
# 有更多企业及咨询单位在花大精力及大手笔的讨论如何提升执行力，其实抱怨执行力不足的时候更应检讨的是管理能力的缺失！
# 大多数企业的质量部门的无奈
# 质量的好坏是可以衡量的，衡量的最基础的标准，就是金钱_既质量成本
# 该部分可以使用来演讲
# 获利能力并不是很容易，方法也不多，所以，在进项并不是很多的情况下，节省成本就成了重要的事。
# 我
# 我
# 庞姐
# 站在用户的需求，急用户所需，才能立于不败之地
# 做感动人心的教育，一直都是斗半匠研发初心
# 和我们企业一直宣导：不要给自己设限，努力无限可能
# 知人善用
# 正如斗半匠一样，让大家阅读打卡，保持良好的学习习惯.。
# 成功背后的人都有一个不平凡的经历
# 人的聪明才智基本都一样，输在坚持。
# 自学的意义就在这里。从阅读中突破自己！
# ⭐重点汇总
# 一般中国人每天会刷4小时短视频，也是浪费了9年；如果每天用这4个小时干点有意义的事情，相当于高质量多活了9年。
# 结识优秀的人，加入他们的圈子。
# 重中之重
# 贫穷的原因汇总。
# 经商必须要考虑的问题。
# 扩大客户基数更容易致富。
# 慢车道秘密出口二：企业高管
# 慢车道秘密出口一：名气
# 招聘并留住，这是两个核心能力
# 醍醐灌顶。这本书并不是陈词滥调
# 选择大于努力
# 做什么，不做什么；有清晰的判断
# 「持久卓越的公司在恪守它们的核心价值观和核心目标的同时，不断转换商业策略和运营方式以适应这个变幻莫测的世界。这就是发扬核心和促进发展的奇妙结合。」
#
# 摘自：《从优秀到卓越》 - [美] 吉姆·柯林斯
# 在豆瓣阅读查看： https://read.douban.com/ebook/18877375
#
# 本作品由中信出版社授权豆瓣阅读全球范围内电子版制作与发行。
# 版权所有，侵权必究。
# 「对照公司，常常通过大量误入歧途的收购行为来设法创造突破。与此相反，那些卓越公司基本上只有在突破实现以后才开始大量收购，为原本已经旋转得很快的飞轮加速积累动量。
# 意外发现
# 实现跨越的公司的决策者们通常在转变过程之中并不能意识到转变的伟大意义；只有事后回顾时，转变的伟大之处才变得明显起来。人们没有赋予转变任何名称，没有标签，没有剪彩活动，也没有方案去表明他们到底在做什么。」
#
# 摘自：《从优秀到卓越》 - [美] 吉姆·柯林斯
# 在豆瓣阅读查看： https://read.douban.com/ebook/18877375
#
# 本作品由中信出版社授权豆瓣阅读全球范围内电子版制作与发行。
# 版权所有，侵权必究。
# 「要点
# 从优秀到卓越的转变对于那些局外人来说，既像是戏剧性的又像是革命性的事件，但是对于那些执行者来说感觉像是一个有机的累积过程。很长时间以来，把最终结果（戏剧化的结果）同过程（有机的累积过程）混淆在一起的做法，一直影响我们洞察真正起作用的力量。」
#
# 摘自：《从优秀到卓越》 - [美] 吉姆·柯林斯
# 在豆瓣阅读查看： https://read.douban.com/ebook/18877375
#
# 本作品由中信出版社授权豆瓣阅读全球范围内电子版制作与发行。
# 版权所有，侵权必究。
# 最有效的投资战略是相当集中适合投资于适合你的领域。听
# 「实现跨越的公司懂得，做你擅长的只是使你变得不错；一心专注于你有潜能比其他公司做得更好的事，才是通向卓越的惟一途径。
# 每个实现跨越的公司最终深刻地理解了这条原则，而且把未来寄托在它们有潜力做到最好的为数不多的几个领域，对这些领域进行资源分配」
#
# 摘自：《从优秀到卓越》 - [美] 吉姆·柯林斯
# 在豆瓣阅读查看： https://read.douban.com/ebook/18877375
#
# 本作品由中信出版社授权豆瓣阅读全球范围内电子版制作与发行。
# 版权所有，侵权必究。
# 「1.你能够在什么方面成为世界上最优秀的。同样重要的是，你不能在什么方面成为世界上最优秀的。
# 这个富有洞察力的标准远远超越了核心竞争力。仅仅拥有一项核心竞争力，决不意味着你能成为世界上最好的。相反，你能做到最好的，可能不是你现在从事的。
# 2.是什么驱动你的经济引擎。所有实现跨越的公司都拥有穿透性的洞察力，对如何最有效地创造持久、强劲的现金流和利润率了如指掌。它们特别注意到一个标准——每“X”所获利润——对它们的经济产生的最大影响（在社会部门是每“X”的现金流量）。
# 3.你对什么充满热情。实现跨越的公司对引发它们热情的活动全力以赴。这里的问题不是刺激热情，而是发现什么使你热情洋溢。
# 为了迅速掌握 ...」
#
# 摘自：《从优秀到卓越》 - [美] 吉姆·柯林斯
# 在豆瓣阅读查看： https://read.douban.com/ebook/18877375
#
# 本作品由中信出版社授权豆瓣阅读全球范围内电子版制作与发行。
# 版权所有，侵权必究。
# 大致浏览了一下电子书，应该是写给中学生的参考书：阳光、主体（或主流）、积极，中学生看了比较振奋。当然，如果你不习惯官方语境，你希望客观地看待现实问题，你大致看看就行了，人民大学的书吗，不必当真。
# 七大支柱产业
# 开头
# 日报只需要突出重点
# 也许大部分工作都是千篇一律，但每个人都想法却会有与众不同
# 为自己做事情
# 共生式的信任关系
# 人才培养5步
# 说的太对了
# 隐含了交换的两个层次：熟人交换，服务于发展一种关系。陌生人，利益最大化
# 作者的观点。但我觉得在儒家当时的思想观念中并没有所谓的“资本主义”概念。
# 就连汪曾祺的小说《受戒》当中，中国农村的寺庙也擅长利用信用、租赁和记账。
# 这位作者你是亲自看过佛经的了。这位被提到的印度国王被记载在佛经当中，具有当时朴素的科学精神，活体解剖了许多当时的死囚，想要通过解剖的手段来发现人的灵魂。终归是一无所获，并宣布了灵魂并不存在。这个看似具有科学精神但残忍且愚昧的活动和认识遭到了佛陀的斥责。
# 佛教是最早期的，系统的无神论么？
# 这个说法不确切，只能说，中国在那个历史阶段没有铸造金币或银币。但是铸造过类似于金币的马蹄金、麟趾金。
# 人类仅仅是在大部分地区消除了正式的奴隶制度，但并没有消除奴隶这件事本身。
# 粪虫至秽变为蝉，而饮露于秋风；腐草无光化为荧，而耀采于夏月。 摘自《 菜根谭·概论 》
# 原来柏拉图也险些沦为奴隶，被人赎身。
# 罐子在古希腊的文化和意象中有女性和雌性的含义。
# 交互闻口气
#
# 找到4到5个细节服务！
# 让每一位顾客受欢迎！
# 需要去读
# 总结：在服务的过程当中送去情感会使顾客对你的感觉好很多
# 太过一般，没有新意，太落后。
# 优秀的企业都有其共有的特质。
# 自豪感
# 加入ppt
# 带操的，团体训练专家
# 企业应该给到员工成长的时间与空间
# 利率上行，债券价格低可能出现损失
# 做好防御，普通人会愿意指有现金应对经济危机
# Mr
# 股价／每股净利润=市值／净利润
# 股票指数期货：未来按照某固定的股价指数大小进行买卖
# 通俗易懂，收获颇丰！
# 设计符合企业的人力资源管理体系
# 花都火车站，好师傅
# 3
# 2
# 好句子
# 自我定位其实需要强烈的欲望和思考能力
# 科技行业和大多数行业品类都不太相同....拥有非常强的外部吸睛能力，本身很容易成为PR热点。因为人们都关注新科技的发展，媒体引以为自己的news能力，消费者以为装B能力...所以可以PR闪电战，近几年已经成为标配。
# 原来是迷你面包车，五菱宏光的前身；婴儿潮诞生了大量年轻父母，未必富裕
# 在新品类开创上，特劳特里斯等也是闪电战的观点
# 反复冲浪的人就更容易踩中点
# 嗯
# 表扬下翻译，信达雅。
# 即然是这样，我就很纳闷，中国为何不考虑以GNP为考核标准呢？
# 即是说，人民币若走国际化道路，必然要让外国企业和私人手中有人民币可以使用，即外国部门为正值。而中国老百姓又要进一步提升生活水平，意味着更高的可支配收入，即本国私人部门为正值。那么0=外国部门（正值）+本国私人（正值）+本国政府（？），所以本国政府必然为负值，即财政赤字。
# 这是理论上的说教，是处于真空的封闭经济
# 当人口老龄化后，是不是就可以不保外贸了？
# 必要劳动的定义，商品价值的定价规章
# 相应的，云设施的一些基本理论、设施也是与其它企业、组织共同研发的
# 这个书真的受益良多，我发现有个叫“帛马"的网站，可以直接生成和编辑商业模式画布，大家可以试试，挺方便的。
# 画布那个真的蛮不错的
# 这个点很对，现在内卷严重，寻求多方位，多维度合作很重要
# 商业闭环
# 需要再继续学习
# 商业模式的顶层设计是否也是按照画布的九个模块的思维来设计？
# 如果开放的直接是产生成果和专利的基础设施使用权
# 先讲清楚背景和目的
# 先讲清楚背景和目的
# 参考过去的经验永远更不上时代变迁带来的新挑战。
# 惟贤惟德，能服于人
# 没看懂诶
# 为什么要激励客户？
# 小学毕业，想要带领更多的人小学毕业
# 我们当前执行这项工作的点典型特点
# 这个应用在我们公司里面，就是人员的升降与调动，这是最后的结果，但是“讨论“和“行动”的板块是没有的
# 如果可以做到这个程度，基本上也就做到了前文所说的“坦诚”。这样做的企业有哪些，很想学习了解，我们企业目前几乎没有做到这一点
# 注意定义的重点
# 战略，怎么赢得客户的心，怎么打败竞争对手
# 目标分解
# 未富先老   延迟退休  如我这一代人  建议  65岁退休
# 背后的因果官西存在吗？  也即人口红利助推经济增长继而超越日本   也将推动增长继而超越美国   正如书重逻辑推演  如果2023人口即将负增长 人口红利开始慢慢消失  往后会成为一个巨大 的枷锁  那么2030年超越美国的预测能够实现吗  且还需要叠加更多层面的因素来分析此问题  如国际贸易  经济结构改革的成果   科技驱动的动力   等等   其实到目前为止  私以为关于中国人民能干 苦干 是无无需置疑的   但 制度方面的问题  却愈来愈凸显了   我们常说  人多力量大  的确如此  但人多力量大  隐含了 盲目
# i是企业文化，和p结合起来短期内响应
# 责权对等，平衡
# 关注过程
# 信息的流转是授权的前置条件
# 面临的挑战已屡露端倪，保持好奇心和外界敏锐感知，通过专业的方法应对不确定性或突发事件，新型确定性，而非不确定性。
# 每个阶段有特定的目标和任务，面临的挑战也各不相同，因此解决方法和重心也完全有着各自的特征
# 对于创业公司来说，正确价值观尤为重要。
# 销售前的准备：稳定的产品，销售制度和流程，产品资料
# 我之所见，中国距离欧美日的差距：科技差距，管理差距，美的差距，艺术的差距，体育的差距，教育的差距
# 投资回报是公司存活的必要条件
# 这本杂志现在还有吗？
# 这是一家什么样的半导体公司
# 这本书应该是霄霄启蒙阅读本之一
# 创业或者做产品，亦或是做IP应当专注客户需求，把握发展趋势，做出正确的战略。
# 好奇心是什么？好奇心就是不停地问为什么？我需要怎么做？
# 懂业务的确重要，一款真正好卖的产品一定要解决用户的需求痛点，我们做产品的要比用户还要懂他们的需求，你想想一个贴心的好帮手，谁不喜欢呢。
# 曾经有一段时间看不起业务，觉得做C++业务开发不够高级，不如做算法研究高级。
# 这两年进了EDA开发，发现懂业务的重要，业务是战略，战略不明确，光有技术也没有用武之地。
# 如果市场有需求，技术迟早都会解决的。挖掘出市场需求似乎就有些玄学，必须要足够专注足够深入，还要纷繁复杂中找住事物的本质，找出最核心的问题。
# 马云也是随需求改变组织结构，灵活性超强，不死板
# 又一次，大量的阅读，这是手段，不是成功的原因
# 可能草根也都因此愁苦
# 有没有目标，对当下事情的理解情绪完全不一样了，角色背景挑战
# 国内能上好经济学三高的学校并不多
# ？？？ 详细讲一讲呢
# 也是经验
# 更过的部分是提成..  用户的钱在证券产生盈利了最好, 以后会有更多的用户, 带来更多的钱; 用户在证券亏钱了呢? 用户会归结于市场,大环境? 提成总之有的.
# 程序员的面试, 也是如此. 或者说, 面试或许就是这个样子?
# 这..
# 大话骰
# 作者就是那批抱着老观念不放的人之一。
# 这应该也是一位优秀的交易师所应具备的素质。
# 好操作
# 这不就是操纵证券价格吗？自身筹码足够多，自然能掌控市场价格
# 读书清单
# 这个人是谁？
# 股票市场的平均收益率怎么得到
# 在哪里可以找到分析师前几年的报告
# 书籍推荐
# 好，终于看完了
# 好好记住
# 1. 初始投资时刻的股息率
# 2. 随后的盈利增长率
# 3. 投资期内市盈率的变化
# 哈哈哈
# 从基金管理人角度，短期梭哈不是好选择
# 和马斯洛需求模型有关
# 和转基因有关。
# 资源魔咒
# 资源越多，科技越发展，发现更多的资源
# 有效需求和资本回报
# 平均主义大锅饭
# 阻挡效应
# mark,2036
# 深刻
# 前面说的阻挡效应
# 信息流和决策流
# 初创/中小规模企业能这么做，不知道现在的google还是这样吗？
# 计划赶不上变化，还有根据领头玩家制订的计划，是一个好计划吗？
# 那是不是会错过因为找照片而重新回忆其他照片事件的乐趣呢？
# 怪不得看国外机构的报告，每年都会有5年计划，虽然可能大方向变动不大，但有些细节却有变动
# 从小处着手，完成小目标
# 风险因公司而异，有时候风险=机遇，不能一概而论除去，也要评估和考量
# 从另一个角度来看，这不就是导致上瘾的原因吗？
# 很正常，船小好调头呗
# 平台的含义在连接
# 这就是为什么组织之间需要高频开放信息流动，高频开放的信息流动会促使两个组织合成一个组织，从而节省基础设施的成本。
# 这才是城市最大的作用
# 好像我也是这样，喜欢复杂有机性的人天生讨厌编程，但也天生适合编程
# 得好好学习下这个技巧
# 这里只能感叹生命的过程的复杂
# 想要更长寿，单位消耗反而要更少
# 非线性的现象，自然要采用非线性的尺度测量
# 我想分成体感事实和量化事实
# 有道理
# 这个问题也出现在现代制造业上。
#
# Is the logic really so?
# 波特五力分析，杜邦分析，估值分析，找到好行业好公司在好价格时购买
# 学习市盈率、市净率、市销率、企业估值倍数等一系列的指标的计算
# A股中不缺少傻瓜，正因有傻瓜才会有低估，对于价值投资者来说，才会出现好的投资机会
# 无法从后视镜中看到未来。
# 警惕差点就赢的场景，合理怀疑是否经过刻意设计
# 正如食品饮料行业所曝光的添加违规成分事件，要先搞清楚是主动添加还是被添加
# 证实偏差，寻找和强调支持自己观点的证据，忽略与自己观点相反的证据。
# 人的普遍偏见
# 所以，对待国家大力补贴的新兴行业一定要谨慎
# 我对此深信不疑
# 事情的成败可能和精神力无关，但事情的完成绝对是有精神力的帮助。而完成是事情成功的必要条件，即精神力是事情成功的必要非充分条件。
# 决策的质量
# 内容比较单一，想节省时间的读者只需要读完前言就可以了，前言其实就是全书内容的浓缩，后面的内容翻来覆去都是对前言的说明和补充。
# 蠢人变有钱了，聪明人都在给他们打工。。。
# 这本书是偶然看到的，因为书名。😝总体来说还可以，浅略了解了亚马逊的创立、发展、愿景。因为是杰夫贝佐斯本人写的，所以基本正面、褒奖、宣传的成分较多。不过，也还是有所收获。比如，看到了亚马逊成功的背后，既有大公司的愿景和能力，也有小公司的活力和热情。比如，“内驱力”对一个公司的重要性，其实对于个体也是一样，当做一件事情是自愿发起，而非因为必要时，完成效果肯定不同。比如，在服务行业甚至很多其他行业，专注于用户比专注于竞争者更重要，专注于用户想要更低的价格、更快的物流、更丰富的选择，并以此创新、可持续发展。京东的很多作法，可能都是从亚马逊学习的，亚马逊创于1994年，京东创于1998年。亚马逊Prime服务、预购价格保护、超级免费寄、亚马逊借贷，在京东都有类似的营销策略。另外，一个企业发展到后期，都会更多地回馈社会，在企业家追求个人社会价值最大化的同时，也使得公司获取社会公众的认可，提升品牌价值，如收购《华盛顿邮报》、微笑计划、蓝色起源、亚马逊能源承诺等等。
# 人均5件商品，推动了客单价
# 同一个人的优秀与投入时间有关系吗？
# 2002年/39亿美元，后续年份没有提到销售额
# 怎么不再提供销售额数据了？
# 例子
# 对企业数字化转型来说是一本很有借鉴意义的工具书
# 数字化在改变每个行业，这是一场由使命驱动的，融合前沿科技和人文精神的变革。沙莎和她的数字化麦肯锡团队结合各行业的大量典型案例，为企业管理者勾勒出清晰的赛道和全新的能力。——滴滴出行总裁 柳青
#
# 互联网、移动互联网、人工智能正在深刻地影响和改变我们这个时代。《从1到N》为企业管理者打开心态去了解数字化趋势，让传统企业的CEO放下身段去拥抱变革。——著名天使投资人 张泉灵
#
# 自动驾驶、用户体验、硬件和软件文化的深度融合正在改变汽车工业，互联网和实体产业的边界已经逐步消失。《从1到N》启发你如何释放全产业链上数字化的价值。——易车、摩拜单车、蔚来汽车创始人及董事长 李斌
# 现在这个社会绝对不会有客户自己找上门来，再好的产品如果没有人知道也不可能做得起来。
# 戴森表示不服
# 订阅制和广告分发平台
# 按以下类型整理和熟练讲述自己的故事集
# 一家以鸡尾酒命名的公司
# 北欧帅哥
# 哈哈哈哈好像广告上刊报告
# 东北澡堂子味儿出来了哈哈哈哈
# 原文应该是 you scratch his back, he scratches yours.
# 真实了
#
# 沮丧的时候换个脑子
# 理想的角度去思考问题
# 主动决策，成功的必要条件。
# o
# pr
# 为什么
# 避免重复建设和打通数据共享是很多大型企业遇到的通病
# 说的很实在
# ng何一
# 《战略解码》--组织变革的推动者，战略落地的助产士
#
# 第一部分：实践企业案例的收获与困惑
# 2012年底，我时任一家光伏企业（简称：A公司）的人力资源负责人。那一年光伏行业欧美双反已经进入白热化，行业进入至暗时刻。为了应对危机、寻求突破，A公司决定由“光伏制造商向微笑曲线终端的光伏电站开发商”转型，并为此开展了组织变革，招兵买马、组建新团队。
# 2013年底，公司新团队组建完毕，核心班子对公司中长期目标具备基本清晰的共识，但A公司战略执行管理体系却难以保证战略落地。所以，公司委任我配合时任CEO、结合外部咨询机构共同推动“战略规划项目”。项目结束，公司向管理干部宣贯了3年战略目标，咨询顾问带着管理团队共同勾画了公司战略地图，形成了对应的平衡计分卡与行动计划，并由此导出各总部职能部门及区域公司的行动计划。管理层非常兴奋，大家清晰了公司未来的方向，明晰了3年目标，共创了通往目标的路径。董事长也感慨道：“公司的战略从来没有这么清晰过”。
# ...
# 啊！？
# 难道是通过计划生育政策和东南沿海开放发展战略打破的马尔萨斯陷阱？
# 这个问题也能在现在的河南省发现。如何既保障粮食安全又提高河南人的生活水平？这是一个值得思考的问题。河南能不能开展大规模机械化粮食生产呢？
# 提出观点了！
# 竟思是需求带动了生产而非科技带动生产力。
# 垃圾书 一点干货没有  我是做微商的 感觉一点用也没有 大家别买
# AA
# AA
# A
# A
# 什
# A
# 什
# A
# A
# 国家权力
# 基础元素
# 虽然在华为做过多年研发，直到自己开启一段创业生涯，才体会到ToB 业务的不易。读完本书，把过去只言片语、耳濡目染的经验体系化建设起来了。收获很大！
# 干货满满，和华为一样值得相信！
# 在客户界面形成一个稳定的铁三角结构，是在VUCA时代，以确定性应对外部不确定性的最有效方式。
# 销售不是简单的拿订单，而是从线索直至合同关闭的全流程，甚至合同关闭之后，不断的、持续的维护并提升客户满意度，做好客户关系工作。才能为既有合作划下完美句号，并为持续长期合作打下良好基础。
# 其关键是能准确定位客户核心痛点，并持续提升客户服务体验，要让客户体验到产品与服务的价值，甚至感受是超值的。
# 销售是跨部门、跨领域的团队协同作战，不仅仅是面对客户界面的前台，中台及后台的能力和高质量有力支撑是必不可少的支援保障。
# 充分授权，扁平化高效运作的组织，良好的激励和细化公平的考核方式是充分发挥铁三角能力的制度支撑。从而行成＂人→制度→文化＂的良性循环机制。
# 在数字化时代，建立一个从战略到执行的强有力的数字化体系，并将公司的政策、制度、规则，包括标准、考核指标都融入一个自动化的系统中之后，形成一个有效反馈，可视化的系统，如华为建立的数字化风控平台，通过建立有效的KRⅠ指标和模型，能够通过探针有效的量化内外风险，及时预警，加快了企业对风险的反应速度及应对能力。不仅仅是企业的数字化风控，数字化营销、数字化交易，数字化采购与供应，都会加快企业的运营效率，同时有效的规避风险，实现快赢。
# 本书不仅仅从华为的铁三角运作这个点来诠释华为销售的底层逻辑，并将华为在销售界面LTC流程相关的端到端的管理逻辑都进行了详细的说明，是难得的学习华为的管理的一本好书。
# 不懂
# 新能源汽车
# 垃圾分类就必须得做好
# 非制造业还依赖外部市场，印度化。
# 所有制是权力施现的重要主体，最高所有权即主权对应着国家的最高权力。在主权之下若干大小的所有权由最高权力进行划分，这种为众人共遵的制度即所有制。如，西欧的贵族封建制及中国的土地私人所有制。
# 天降吗？
# 中国国内最大的生产力就在农村，20世纪改革开放以来，城乡一体化的脚步就从未停过，为何现如今中国还有如此多的贫困人口？城市的发展太快，太多的人挤入城市，却忽略了农村的发展。
# 如果目标或结果无法衡量，就无法改进
# 核心结果，驱动因子，且驱动因子必须可控
# 识别绩效的结果和驱动因子
# 分享该案例
# 确定结果目标：核心目标和关键结果
# 文化是核心。可不可以齐心去做事情。
# 拒绝自恋，拒绝什么是我们可控的。而是站到客户的角度出发。交付不是从公司离开，而是到达客户手中。
# 避免陷入次优化的困局。只解决局部部门优化，而非全局优化。
# 切记评价系统只是让我们“看起来很优秀”但却不创造价值
# 理解客户的抱怨
# 对私域流量运营有了整体概念，蛮好的
# 大陆法系：固定法条制 英美法系：common law，判例制
# Mortgage Lending Value
# loan to value, 是指贷款金额和抵押品价值的比例
# equity withdrawal
# 不做第一做唯一 心占率的商业模式 把产品做的独特 差异 把控好市场定位做出好产品获得客户的认可
# 超大的宠物卖场 宠物大全用品 自行挑选
# 可以做高品质 中价位 同样的品质我价格低 同样的价格我品质好
# 无人干扰 客户主动选择 如优衣库等
# 特许经营模式 加盟者赚取利益 公司自己运营把控好品牌和形象价格市场地位 扩充规模 不压资金
# 一开始的企业模式决定了未来一段时期内反应的结果，不同的模式结果必然不同
# 正所谓幸福的人都是相似的，不幸的人各有各的不幸
# 真的太像大多数家长对孩子地激励了
# 大多数家长只有在确保孩子持续的努力而取得好成绩的时候才会觉得孩子是好的，可控的，一旦孩子有任何突发情况，他们就崩溃地像世界末日来临一样
# 大部分人都有个人成就需要，如何激发个人的成就感荣誉感，在现如今不缺吃喝的年轻员工占绝大多数的公司场景中尤为重要
# 疫情还没开始全国爆发的时候，稳健医疗嗅到了一丝可能的爆发之势，决定增加当年的口罩产量，为当时不太充足的救援物资起到一定的调节作用。
# 银行通过对储户负债创造货币，负债的原因是储户将来会还款，实质的发行依据是工资➡️劳务
# 那种激励机制
# 了解现代中央银行-商业银行双层货币创造体系以及英国货币银行体系不错的一本书，既介绍了货币史相关的内容，还重点介绍了ZLB下的量化宽松政策操作与效果评估
# 我也要当一堵墙!
# 这就是我一直想成为的状态；社会责任感
# 企业是靠实在的项目支撑的，要想改变请务实
# 没有人才的成长，就没有企业的成长；企业的成长不仅仅是做项目的数量和利润，往长远来看，更需要通过人才的成长来帮助企业成长。
# 在评价员工时要以客观、结果导向的去评判，不要参杂个人情绪
# 思想需要开发、多元，勇于面对世界的不同
# 从实践中培养
# 与自己意见一致的人为伍很简单，也很有效，但是却会造成观念单一，见识狭隘的局面，所以也要学会与自己意见不一致的人相处
# 管理重实践，管理能力要想提升，还需将重心放在实践上
# 领导力可以让团队前进，管理力可以让团队找对方向并和谐的前进
# 这是一本需要我反复看的书，要做成一件事，就需要付出不亚于任何人的努力！
# 如果是大学时读这书，或许更容易和作者产生共鸣。
# 然而现在读这书时，已经历社会三年了。想法也不像大学时那般奋进（亦或是冒进）。
# 我的观念想法已经和作者相去甚远，我想的是，自己如何更舒服，内心最舒适以及最少的心灵内耗，同时我也希望在我自得的同时，不要太影响他人。
# 尊重他人躺平也尊重自己选择躺平。
# 正如罗翔老师所说“当你相信天道酬勤时，你往往会变得自负，你会觉得他人过的不好是不努力所致”，人生的不确定因素太多，我们不能太拿努力来苛责自己更不能拿此来苛责他人。
# 在我看来，作者的很多语言已经颇带苛责，尽管可能是他的肺腑之言，但已现在职场人的眼观看来，这可能很像PUA。
# 读这书时，我保持着很深的警惕，来防止自己被轻易的同化，书中讲述了太多的观点，而较少对事情的客观描述。里面涉及了很多作者观点背后隐藏假设，且我都没能与之达成共识。细细推敲下去，感觉作者过于主观了。或许这种强烈的主观思维也就是优秀的企业家所该拥有的，所谓的“现实扭曲立场”？
# 但无论如何，这书读下来还较有收获的，他帮助了我了解企业家们对工作和事业的看法，了解了他们的幸福感来源。虽然对书中作者的很多观点，我都没能太接受，但这种不一样的思维视角，对于我来说也是有很大帮助的，起码会对些企业家多些理解少些苛责。但我是绝对不让自己这样去对待他人的，这太刻薄了。
# 希望企业家朋友们也还是多些love and peace 少些苛责下属哈。
# 事情其实不会因为你们的苛责变好，我们都别太看重自己了。
# 值得一看
# 就是要有干劲和热情
# 日本人是真擅长写议论文。
# 其实说到底，所谓“干法”一个词和一句话就可以总结，一个词是“以身作则”，一句话是“为万世开太平”。个人认为这已经是一种信仰了。工作无论高低，真正做到顶尖的人一定是将这种信仰化为行动、知行合一，愿意牺牲自己的私欲。
# 稻盛和夫先生真是一位哲学家。脚踏实地，一步一个脚印
# 第一遍刷干发
# 给我最大的感悟就是很直面的教我在工作中遇到的问题。
# 以一种几乎变态发疯的执着和努力完成想要完成的目标；我是做招商工作，每个节点的任务与时间挂钩，自己压力大，比较迷茫，但是在阅读及思考的过程中，渐渐对自己工作规划有了一个清晰的思路。接下来会再刷一遍本书，应该会有更多的收获。
# 改变了我的人生观和工作观
# really？
# 错别字
#
# 下次继续
# 7个维度
# 在重庆2018年底看的
# 这里可能是一个关键 diff，即使反观国内的部分技术出生的创始人，他们也是从一开始就有商业头脑的。
# 一种是少犯错、方面。一种是多创新，不惧怕犯错。
# 这里的关键点在于，相比与工业时代，互联网时代的试错成本，实在是大大大的下降了。
# 比较喜欢创意那一章，但是今天回看就。。。反正就，有点过气了。
# 创意精英
# 产品才是核心
#
# 自我激励，使命感是很重要的
# 直觉，举一反三的能力，是人类比机器优势的地方
# 作者是在自己提及自己吗？
# 美国共和党支持持枪，而民主党则不支持
# 难怪美国的民主党是大政府，而共和党是小政府；左派右派也要看国家，西方和美国可以按照这个分法
# 故事对于人类来说很重要
# 意味着所有的结果是系统选择和社会选择
# 因为进化的本质是因为资源有限吗，其他物种是基于生态平衡的整体进化，人类单独的进化破坏了生态的平衡，本质上资源问题无法解决
# 通过物理和社会技术的发展，还有价值交换的评估，提升整体价值的创造，然而提升是为了啥？
# 市场的选择
# 换言之，文化处于从属地位，为自身利益最大化所决定。
# 政治学领域的二分法。
# 有可行的想法，有足够的资金。（有想法，又有钱）
# 7
# 6 ＇
# 5
# 4
# 3
# 开头z
# 开头
# 实施奖惩与优点5
# 跟踪检查
# 如果书上的话不多，可以引用，作为引入
# 好友裂变
# 放到现在会被封号吧😄
# 华为手机这个例子，没有那么恰当，很多人买他的手机，是因为拍照。在手机的购买上，第一看颜值，第二看拍照
# 刷新了我的思维。
# 一本视角与众不同的书籍，在外国教授眼里很有趣很值得深思。被要求阅读的材料，中文翻译救我于水火！！整个发达国家发迹的过程被分析的形象易懂又客观，有体会到弱国一步迟步步迟的艰辛。
# P.S.原著的书名短更有趣
# 在当前政策研究的所谓“国别研究”“案例研究”方法中太常见。
# “发达国家的经济政策发展史强调自由贸易和自由放任的产业政策的重要性。发达国家希望发展中国家借鉴它们的经验，也实行自由贸易，采取自由放任的产业政策，但事实上发达国家并不是因为实施这些政策而获得成功的”啧啧啧啧确实真讨厌
# 哈哈
# 领导者和管理者的区别
# What if 想象力的“链接”
# Why 激发洞察力
# What if 放飞想象力
# How 强化执行力
# Repost.
# 调研题
# 好了，完美后悔买的这本书，十分浅显
# 思维指南，很有收获。
#
# 通过概念。细节。手段论述了数据化在企业管理中所起到的作用。很有价值
#
# 利率传导机制是指央行通过调整以国债为核心的基准利率进而影响银行间同业拆借利率最终实现对社会资金总量的调控。
# 风险定价（Risk pricing）是指对风险资产的价格确定，它所反映的是资本资产所带来的未来收益与风险的一种函数关系。建立风险定价体系需考虑经营成本、目标利润率、资金供求关系、市场利率水平、客户风险等因素。
# 银行采用精密的信用评估程序，将可更有效就贷款进行风险定价，即质素好的客户应能以较优惠的利率借款。随着银行更有效就贷款进行风险定价，而不是仅依赖于诸如房地产等抵押物，中小企业将较容易获取贷款。
# 二元悖论是由伦敦政治经济学院教授Rey在2013年提出的经济学观点，即资本自由流动与货币政策独立性不可兼得，而与该国采取何种汇率制度无关。
# 其政策含义具有颠覆性，意味着除非对资本账户进行直接或间接的管制，否则一国难以保持货币政策独立性。
# 黑天鹅事件（英文："Black swan" incidents)指非常难以预测，且不寻常的事件，通常会引起市场连锁负面反应甚至颠覆。
# 一般来说，“黑天鹅”事件是指满足以下三个特点的事件：它具有意外性；它产生重大影响；虽然它具有意外性，但人的本性促使我们在事后为它的发生编造理由，并且或多或少认为它是可解释和可预测的。
# 黑天鹅存在于各个领域，无论金融市场、商业、经济还是个人生活，都逃不过它的控制。“灰犀牛”是与“黑天鹅”相互补足的概念，“灰犀牛事件”是太过于常见以至于人们习以为常的风险，“黑天鹅事件”则是极其罕见的、出乎人们意料的风险。
# 香港人把粤式点心的概念挪用到金融市场上，创造出“点心债”这一可爱的专有名词，用来指称近年兴起的香港离岸人民币债券。
# 熊猫债是指境外和多边金融机构等在华发行的人民币债券。根据国际惯例，在一个国家的国内市场发行本币债券时，一般以该国最具特征的吉祥物命名。
# 商业性金融是指在国家产业政策指导下，运用市场法则，引导资源合理配置和货币资金合理流动等经济行为而产生的一系列货币商业性金融活动的总称。
# 商业性金融的主要特点：
# (1)商业性金融的决策主体是各国有商业银行而非国家政府；
# (2)商业性金融追逐利润最大化；
# (3)商业性金融活动是在国家产业政策引导下，通过自主决策来实现的；
# (4)充当信用中介，实行有偿借贷是其基本原则；
# (5)商业性金融以资金的盈利性、安全性和流动性为主要经营原则。
# 政策性金融，是指在一国政府支持下，以国家信用为基础，运用各种特殊的融资手段，严格按照国家法规限定的业务范围、经营对象，以优惠性存贷利率，直接或间接为贯彻、配合国家特定的经济和社会发展政策，而进行的一种特殊性资金融通行为。
# 开发性金融是政策性金融的深化和发展。开发性金融是实现政府发展目标、弥补体制落后和市场失灵，有助于维护国家经济金融安全、增强竞争力的一种金融形式。开发性金融一般为政府拥有、赋权经营，具有国家信用，体现政府意志，把国家信用与市场原理特别是与资本市场原理有机结合起来。
# 软预算约束就是指当一个经济组织遇到财务上的困境时，借助外部组织的救助得以继续生存这样一种经济现象。其基本特征是： 企业生存不仅仅取决于它的投入成本和销售盈利；企业技术进步和发展不仅仅依赖于内部资金的积累；企业在任何情况下都用不着去适应价格，对价格的反应极弱；企业自己不承担风险，可将外部环境和自己行为的不利后果转嫁给购买者和国家；企业对投入品的需求几乎是不可满足的。
# 所谓硬预算约束就是我们平常说的优胜劣汰的市场机制，即经济组织的一切活动都以自身拥有的资源约束为限。
# QQ是1999年2月由腾讯自主开发的基于Internet的即时通信网络工具。QQ以前是模仿ICQ的，是国际的一个聊天工具，是I seek you（我寻找你）的意思，OICQ模仿ICQ它在ICQ前加了一个字母O，意为opening I seek you，意思是“开放的ICQ”。但被指出侵权行为，2000年11月腾讯推出QQ2000版本，OICQ正式更名为QQ。[5] 除了名字变化，腾讯QQ的标志却一直没有改，一直是小企鹅。因为标志中的小企鹅很可爱迷人而且很受女生的肯定，用英语来说就是cute，因为cute和Q是谐音的，所以小企鹅配QQ也是一个很好的名字。
#
# 有再精炼的空间。简单却难执行的道理：真诚、坦诚、不卑不亢、善、创造产品、尊重人。
# 这里的“使命”指的是柯林斯《卓越基因》一书中的“目标”
# 如果能在凝练一些就好了
# 2021年港股继续下跌20%多，远超很多人的意料，虽然估值低，但市场短期无法预测，长期看港股还是会价值修复的。
# okr
# 还不错哦。最近开始关注勇气，看到哪都是勇气。。。
# 沟通的方式，便于拉进距离。
# 会议前的闲聊不能流于表面，不能只是为了给工作开展做铺垫。而应该是真心得关心对方生活，让对方觉得闲聊的内容也是很有收获的
# 一对一会议，自己需要提前想好要讨论的关键五件事儿。不过交流时，率先让对方来提出，也让对方更好的分配精力和关注的侧重点
# 会议从出差报告开始，活跃，开心
# 团队之间互相感谢作为一种制度和习惯
# 团队成员彼此看做普通人，更平等和活跃
# 优秀的团队，也意味着更多个性和想法的人。
# 对比尔的赞誉
# 裕廊集团（裕廊镇管理局）（Jurong Town Corporation,JTC）
# 1968
# 功能配比
# 從資本、技術密集
# 到
# 創新研發
# 工業與生活融合
# 產業依託港口
# 動態治理系統
# 书不全，没有附录。
# 核心原因
# 早期依托生产要素挖掘，发展制造业（物流优势为核心要素）
# ？
# 就好比中国现在搞的内循环
# 三餐不保，天下大乱
# 得为孩子多积累点东西，至少房子要有吧
# 生产过剩，存量竞争，打价格战
# 要有新的科技革命扩大需求、提供岗位、带动就业
# 互联网分的是实体经济的蛋糕
# 第一个五年计划、改革开放、加入世贸
# 资产规模越来越大，把猪养肥了再宰
# 债务危机
# 不对，芯片生产是全球产业链，国内确实没有技术生产芯片，问题不在市场，在于技术瓶颈无法突破
# 歪歪歪星人，癫癫癫癫截肢
# 那曾国藩一定是系统2达人
#
# 始于迷惑，陷于套路，终于习惯，传于印记。最初、最高、最终，消费体验，分享出去。
# 看这本书 也是我人生的关键时刻
# 与新古典增长理论不同，内生增长理论用规模收益递增和内生技术进步来说明一个国家长期经济增长和各国增长率的差异。其重要特征就是试图使增长率内生化。根据其依赖的基本假定条件的差异可以将内生增长理论分为完全竞争条件下的内生增长模型和垄断竞争条件下的内生增长模型。
# 自强不息，抵抗熵增。是非封闭环境，通过一些改变，维持进步
# 泡沫的本质是什么。资本如何才能健康助力资源分配
# 原因应该是复杂多变的
# 闭环
# 柏拉图
# 到如今这个时候资本无孔不入
# 耗散结构可以这么理解以西欧为中心与世界上其他国家进行贸易(贸易顺差)，而获取了利益后不断的推动资本的发展
# 熵增定律，熵永远在增加，总是从有序变为无序，除非获取能量才能变有序状态。
# 奋斗最根本的目的是获得更加美好的未来。
# 哈哈哈哈哈怎么好好笑啊
# 哈哈哈哈哈哈哈哈哈草率
# 😧，不会吧，真的假的？
# 不禁想到了恒大
# 都失落了三十年，举债那么巨量，为何还那么发达那么有钱人民那么幸福？这不矛盾么？谁来解释一下。
# 哈哈哈哈哈哈哈哈救命啊
# 原来活得太久对经济不利
# 哈哈哈哈哈啊哈要笑死
# 特需景气
# 小作农→自作农
# 比如哪些软件呢
# 已经挽回了10亿元损失，就这作者还赔了1100万吧（我记得是）
# 怎么标准化啊？
# 说到底这其实本质上还是和工作差不多。并没有形成自己的商业系统。初始资金影响不大吗？
# 风险过大的实际弊端
# 是投资的选择性更少吗？期货能投资的种类相比股票更少吗？
# 太可怕了太可怕了。那可是自己的真金白银吶，在毫无征兆间瞬间蒸发了！ 这种通过投入本金买入倒卖赚取差价的生意，不就是要承担、面对这个风险嘛！你风险控制的再好，严格按照止损点执行，但是人算不如天算，市场突然崩盘，根本不给你退出的机会，你能怎么办！所谓常在河边走哪有不湿鞋啊。
# 适当降低回报预期，海滩身材不是一天练成的。找到自己的舒适点慢慢加压，别好高骛远！！！
# 怎么理解这段话？
# 个人想法，处置效应对支撑和阻力的影响：当人们感觉利润够了时，害怕无法出手，集体大量卖出，会导致价格在一段涨幅后出现一小段下跌（反弹和回调？）。
# 基本概念：
# 我应该是这部分人其中之一
# ？
# 覆巢之下，也有完卵🤣
# 经典
# 牛
# 🐮
# 其实想给三星的，但是还是给偶像多一星
# 他认为 资本化开支就是为折旧买单，所以不应双重计算
# 金融资产公允价值变动计入当期损益这个就很容易误导尤其是熊市
# 比喻很好
# 实话实说，真的有人觉得工作不痛苦，是福分吗
# 是个清奇的角度，也确实不该被遗忘….
#
# 奥派是不是对人性和企业家有什么误解？？
# 另外金本位时期的经验能不能套到无锚货币时期也是个问题…
# 而且好多描述。。。真的，就烘托一些气氛吧，没啥用。。。就不能干净的把事情梳理出来讲清楚嘛。。。但至少有一点儿苦劳
# 是大量收购，储存商品或市场上稀缺的物资，等待时机，高价出售的暴力投机行为。
# 长期稳定增长的，大型的，传统工业股及金融股。
# 证券市场上将经营业绩较好，具有稳定且较高的现金股利支付的公司股票成为“蓝筹股”。
# “蓝筹”源于西方赌场，三种颜色的筹码中（蓝，白，红），蓝色筹码最为值钱。
# 内部的技术和业务团队之间的关系也一样。往往在前期的推广用力很多，忽略了后面的服务。
# 运营效率指的是工作任务和技能水平的匹配程度。
# 专家型服务依赖员工的创造力和智力来解决问题，因此有必要更民主的分配利益来刺激员工创造更多价值。经验型服务是在一个行业有一定成熟度后，大部分工作可以被程序化，但要使用哪种程序、程序上是否要做一些小修小补依然依赖员工，这种情况下利润的分配主要由员工的职级决定。而程序型服务，最典型的就是外包、工厂等，这种工作可以高度标准化和程序化，人的智力和经验在这类工作中不再重要，因此利润分配仅由薪酬和加班费构成。
# 这本书对“服务定价”这个更基本的问题缺乏探讨
# 重复博弈
# 最后一句应该翻译错了。此处强调战略的一致性。
#
# 需要仔细研究不同战略组件为什么不能兼容，或者说一套组合拳的合理性、synergy、优于混合战略的地方，到底来自何处
# 创意热店
# 感觉像“电算化”时代，技术作为辅助工具……但可能不符合今天数字化时代的技术投资规律（分散化导致数据孤岛、技术不兼容、开发力量薄弱……）
# 有点像早期的design sprint
# （行业普遍采取）合伙制背景下可能是对的。广告公司从创意主导变为媒介主导，并购、上市、控股后就不是这样了。
# 我大感惊讶，二十年前亚马逊就拥有这么先进的产品研发和管理理念。 两年前在字节工作时，字节也有类似的经验和理念。  单线程团队，去ppt，长期主义等等都是我们在实际团队管理，产品定义和开发中学习和借鉴的
# 很有看点的企业管理类书籍，深受启发的两点：
# 1、亚马逊会议禁用PPT，改用六页纸备忘录叙述体。信息密集，不适合PPT陈述，只凭借幻灯片，往往不足以完整地传达或记录所谈的问题。书面的叙述体文本的信息密度，是常见PPT的7~9倍。在相同的时间内，阅读叙述体文本所获得的信息，要比听PPT陈述多得多。六页纸备忘录中第一部分是提议所依据的信条——它是论证提议的基本出发点，给出一个锚点，让与会者关注重点，借此评估备忘录的其余内容，以利高效达成共识。
# 2、关注管理投入类而非产出类指标。飞轮概念：对某个或所有要素注入能量，飞轮就会加速转动。亚马逊的投入类指标，就是注入能量，通常都是客户关心的事情，比如价格低、产品种类多、配送速度快、客户投诉少、网站或应用程序速度快。营收、自由现金流等一般只会见于公司的财务报告，属于产出类指标。
# 不想读
# 到底是什么
# 增强凝聚力
# 看状况
# 做决策
# 希望…………是没有用的，只会停在空想状态。
# 要求…………也是没用的，拿出实际行动来。
# 已存在的，提炼加强。能够存在，很大程度也说明了老板是这样的风格。
# 本书推广大使来了，第一个抢沙发～
# 敢想敢干敢担责
# 形成新的利益集团，改革阻力巨大，贫富差距悬殊，权力寻租严重。
# 人治
# 权力寻租
# 5000年文明屹立不倒
# 光绪皇帝“戊戌变法”
# 生产力决定生产关系，经济基础决定上层建筑
# 。。。掩盖真相的城墙
# 经济改革政治制度停滞不前的不协调感
# 产权改革和全球化始于市场经济的确立
# 对我很有帮助
# 饮食品位很高但道德标准很低？
# yes
# yes. 特拉维斯肯定也是一个有自律潜质的人
# 必须相信会好起来! 然后真的会好起来!
# 信, 信you
# 改变之前, 我们都不知道.....就这样"命中注定"发生了
# 以前认为习惯很强大 想养成一个好的新的习惯很难，但从未意识到习惯本身很脆弱，改变也并非无迹可寻。
# 泪目
# 自律和勇气，最重要
# 比如买东西到咸鱼，既能确保客户付款，也可以确保买家发货
# 微信公众号是个好想法
# 不适合就不要硬推，会引发反感，比如卖房中介
#
# 《我是微商6：用服务营销引爆成交》作为微商、社交电商领域第一本专注于服务的图书，从4个大的方面系统总结了构建服务体系、实践服务方法，以及用服务引领营销成功、团队裂变的方法论。无论是个人从业者、小微团队还是大中型品牌商，都能从本书中收益。
#
# 微商从诞生至今，竞争的核心从粉丝数量到沟通方法，到运营策略，再到现在的服务质量，经历了多次变化。在微商和社交电商运作模式和国家相关监管政策日益成熟的情况下，服务将成为构建竞争壁垒的最佳方式，同时也将成为继内容之后能真正触达客户内心，引发感性消费、持久消费从而实现批量成交的最佳方法。
#
# 《我是微商6：用服务营销引爆成交》是一本帮助微商、社交电商从业者全方位构建服务营销体系的实践指导书。
#
# 6个服务客户的关键时刻
#
# 6个建立信赖感的关键点
#
# 5种放大客户价值的途径
#
# 6种避免代理流失的策略
#
# 3大加快团队裂变的方法
#
# 4种在售中环节提高成交率和满意度的服务形式
#
# 6大在售后环节通过服务提升复购率的关键步骤
# 特种部队的做法
# 公司的最开始应该具备的东西
# 不知道如何做计划的时候要经常问问自己这句话
# 很强的实践指导意义
# 绩效的重点是产出，内耗的原因是过多关注活动
# 活动是动作，产出是结果
# 指标可以很好的管理团队
# 定义okr的精髓
# 虽然我是名普通的基层员工，但是还是选择了看这本书，因为在公司中，普通员工不相信他们的主管。而无论主管怎么说，基层员工都会去想，主管肯定隐瞒了什么，主管在画大饼，主管做的这些事情是画蛇添足。基于更加了解自己主管的目的，阅读了这本书。
# 总结了以下5点思考。
# 1，主管的产出并不止于主管自己的产出，而是主管自己和它管理部门的产出。才是他真正的产出。不过这点谁都知道。
# 2，关于培训作者的一个重要观点是，员工的低级错误应该培训的时候得到解决。而不是在客户的层面把问题暴露出来。这点其实指出了很多公司都存在这个。因为在很多人的主张中。都要让员工在实干中增长才智。但实际上这种想法往往会跑偏。会让新员工在没有经过初始培训直接做客户的需求。会让客户感受到很大的问题。让客户产生不信任感。而正确的做法应该是对员工培训好。让他们做的工作内容。也基本涵盖在培训中了。让新员工能够按照一定质量完成他们的工作，而不是边做边试。
# 3，关于员工自己的话，应该把自己的工作岗位当成自己经营的企业一样好好经营自己的工作。这实际很重要的。而员工也不能把自己看做一个打工人。离职就说是自己经营的企业破产了。因为如果说创立一个企业也要遵守国家建立的规则，也要给国家交税。而你自己入职企业的，其实也是自己赚钱，然后要交税给企业。
# 4，关于作者管理企业的逻辑而言。他也给职工的性格进行了划分。关于性格的划分。
# 信息交流为主
# 会议的效率 一定去涉及两人以上的问题
# 一对一会议的杠杆率
# 很好
# 从企业资产的分布比例，分析企业母公司及合并报表实施的资源配置战略，从而反向验证相关资产负债的比例分配。
# 四张基本财务报表：资产负债表、利润表、现金流量表、股东权益变动表
# 不错的，中心思想有点像《重新定义创新》，创新的商业模式需要开发“未消费者”，并带动贫穷地区上下游的发展，比如基础建设。
# 注意⚠️是开辟式且特定类型的创新（必需持续地加大投入，乃至有能力影响整个国家的经济）其实在中国电商平台也属于一种开辟式创新，发展了许多农村种植业经济。
# 6年, Mo Ibrahim可以说是功德无量，拯救了许多挨饿受冻的非洲贫民，创造了就业机会和经济发展，尊重佩服。他不仅仅是企业家还是慈善家。
# 是个人才👍🏻 佩服这样的人，有问题解决问题才是关键，而这也是企业家每天都在做的事，每天醒来都有堆积如山等待解决的问题。
# 未消费群体是一门很深的学问，对症下药能得到不少潜在客户，如今的大数据已经能精准锁定各种潜在消费群体购物的原因，并且会三番四次把商品相关的信息通过不同的社交平台展现在消费者面前，点击率也会形成一种数据，记录在商家后台，形成一个引诱消费者消费的庞大数据库。
# 迫切想要改善自己的生活，却没有在当前阶层和社会地位接触得到的解决办法。
# 重点：创造长久性的繁荣 根除问题本质
# 主要问题：粮食 水 卫生 就业机会 经济机会
# 美国是反过来的，先生产汽车，再普及公路
# 这不就是拼多多正在做的事情吗？利用信息技术，下沉到农村，与农村的人、货在一起。在国家修了这么多公路、全面的覆盖电网、网络以后，一切成为可能
# 对于1-2年计划和3-5年计划关注的太少、对宏大主题关注的太多。
# 将自己当成一个信息处理中心。第一步就是需要过滤信息，对信息进行分类、加工。
# 这句话让我笑出了声。
# 将来、也许清单也需要经常回顾。
# 每周回顾的重要性。
# 建立项目清单的意义。
# 即使应对紧急情况，也不能将清单的关注点完全抛之脑后，而应该将清单的内容和紧急事件的重要性进行快速的评估，再做决定和执行。其实最好的状态是随时掌握清单的内容及下一步工作，动态平衡重要性，才能及时响应推进，不陷自己于被动。
# 简直就是在说我！
# 场景 可理解为场所
# 唯一不变的是变化
# 那明星的这些娱乐新闻似的事件说事就没意思了吧
# 2022.2.22 北京冬奥会刚闭幕，俄承认乌东两地区独立，命令部队维和。
# 蓄水池作用，防止睡流入居民部门
# 硬核
# 勇士
# 尊重自己的劳动
# 思考
# 🤔
# 领导力是让人追随你的能力
# 此句有深意
# 学到了很多
# 很好看。收获很大，差距也很大。
# 创业也要把每一天当最后一天来做，就会有足够的focus
# 这段对创新者要解决客户需求，继续创新的定义非常好，创新者就是要善于忽略客户需求和限制等事实，做出最后的产品
# 成本加乘定价法
# 把垄断性企业纳入分类管理
# 国企“三会”确实不伦不类
# 国企改革基本思路
# 国企改革中存在的的缺陷
# 国有企业改革的大体经历
# 三桶油的寡头垄断
# 「某种意义上说，国企高管的行为方式更多基于政治逻辑而非商业逻辑。在此情况下，对于国企高管的个人监管，就更多纳入到政府官员监管体系。」
#
# 「未来，石油行业应只保留开采的国家控制权，而在石油进出口以及下游领域，全面开放竞争。按照这个思路，很多垄断国有企业都应该实现业务收缩。」
# 竞争性国企的退出，俩个条路径：举例油气行业企业写入论文。
# 英国在国企改革分类管理上做得非常好。
# 折腾自己
# 关键是一直向前
# 两个都要
# 要有意识的培养可以求助的专家，干脆利落的提问，坦诚直接的感谢非常重要。
# 这段话提供给我一个新的思路，不要局限在当前team的小团队内，要去看世界的规则。更广大的职业场景有好的经理人存在，他们重视项目对于职业发展的增益、重视人才引力的存在。因为这点认知，所以要意识到，当前不好的环境内的责备和思想植入，不是客观的归因，也不能因此影响自我认知。
# 作者布莱恩.费瑟斯通豪这位世界级首席执行官通过有价值的课程和可实践的练习，帮助我们在职业生涯的每个阶段发挥最大的潜力。作为职场妈妈，我们常常为现实所迫，为不能平衡家庭与工作的关系而苦恼，但是读了这本书你会发现其实如何早早规划，就能在未来很好应对职称和生活的冲突。这本书不仅适用于职场人士，尤其对于职场妈妈们来说，更是一本不可错过的好书。
# 🎯 读后反思：
# 在职场和工作的平衡中，需要掌握“有条件地接受”的技能，永不拒绝最终会招致灾难。。
# 👉 边工作边当父母是磨练时间管理技能的终极方法，这时候就需要职场妈妈们最对三件事：睡眠、饮食和锻炼，这样才能管理好压力，过好生活。
#
# 🎯 书中精华摘录
# 书中这些文字让我深有感触
# 👉 职业生涯不止于一份工作，而是生活的一大部分。职业规划不仅可以用来甄选工作，而且是一种让执业生涯融入更广阔的人生追求里的整体方法，那些人生追求包括你的亲子关系、跨国工作、未来发展以及终极幸福。
# 👉 职业生涯前15年的唯一目标就是加添燃料，强势开局。这是初出茅庐的时候，是找到自己的长板和热情所在的时候。
# 👉职业生涯第二阶段是职业生涯中段的15年，是锚定甜蜜区，确定更高追求、投资职场燃料以拓展长板的时候。
# 👉职业生涯最后几年的标志就是明显的衰退或者随波逐流。但其实却可能异乎寻常地充实和持久。这就需要恰当的思维方式、预期与准备。
# 👉有了技能和规划，才有资格碰到好运气。
# memo
# 黑话：方法论
# 个人财富
# 雇主
# 如何量化由此节约下来的成本呢？
# 正解
# 好👌🏻
# 有用的思维
# 古时觉得有剧毒，大家都畏食之。直到16世纪，有厨师将其带到餐桌，被人们熟知。
# 个人感情问题
# 作者积极探索共赢解决方案的思想可以使普通人的生活变得更好。但在涉及政治问题时思维流于表面，没有看到深层次的问题。
# 这句话很有意思，值得好好思考。
# 打开了新的思想维度，值得一个的书！
# 协同是改变世界的力量
# 组织前端的岗位更多考核以扩展市场机会为产品提供价值输入
#
# 组织后端岗位更多考核以研发问题解决和项目有序进站为核心kpi
#
# 或者温水煮青蛙
# 所谓奴隶
# 文不对题，文不对题。我干嘛要看这么长一本书去加深离经叛道四个字的理解，浪费时间。
# 这个翻译就很模糊了，他是谁，谁又是他？
# 这结论感觉有些牵强，我就是单纯喜欢Chrome浏览器的人，仅仅是因为习惯不了其他浏览器。
# 我很庆幸 遇见你
# ？
# ？
# 确实 朋友 氛围 很重要很重要 但不是必要
# 拖延症患者的宽慰
# 资本家怎么那么可怕呢
# 什么是愉悦 什么是清醒但痛苦
# 可能那些账户里的也不是真人
# 何苦为那些网上的声音影响到自己的精神状态
# 虚拟，恐惧
# 可怕
# 定人设。是不是就是标签化一个人
# 而我自己也在僵死的被标签化的过程中
# 自我标签化和对身边人进行标签化的过程里了
# 精准的个性化定制
# 个性，是不是真的有个性？
# 消费狂欢，但为什么行业不永续，大企业甩锅到小企业担责，但小企业为了分得一杯羹，所以无法给个体工作者以合法权益，这个事情变成了弱者之间的打架，你可以是消费者，也有可能是一个被消费的人。一进入这个谎言和大饼里，这些钱都变得转瞬即逝，大到薇娅雪梨，小到网约车司机和快递员…
# 因为整体存活率上升，以及对缺陷后代的包容能力提升？
# 没有考虑效率进化？
# 需要总量支撑而非百分比
# 临近出现的新心理类型？
# why？或者只是统计偏差？
# key message
# 变革型领导力-2
# 收获颇多
# 真有魄力！！！！
# 真是绝棒的广告，与品牌价值欢和消费者心理如此契合！
# 确实是
# 是的，学到了，舒先生
# 是一两家“门店”，还是“公司”，或是“企业”？
# 自己对自己的定位，决定客体头脑中自己的形象。
# 我们告诉别人自己是什么样子、并大力宣传这幅样子、并且花资源维持这个样子，那么自己就是自我塑造的那个样子。
# 每当我看到很漂亮的女生从眼前飘过，无论她仍单身一人，还是已名花有主，我都要思考，我认识不到颜值高身材棒的女生的原因。
# 看一半先放下来，看其他后再继续，偏激是一点，没有条理是一点，好的是看懂了发行量，基建，房价的关系，但这点也深深怀疑是被guo忽悠了还是被作者忽悠了？
# 会不会跟现在的脱贫致富政策有关？
# 看不懂
# 以后多关注这个会议经济工作会议
# 看不懂
# 国企如何赚钱
# 国企央企的发展
# 真的要理解小老板，隐形成本太高，企业是承担就业率得中坚力量，但被充分刁难也是他们。所以科长的刁难又变成了劣根性的问题。
# 菜菜好人呀
# 太他妈真实了
# 做事是有成本的，对标前人经验，是成本最低的
# 找对标
# 目前能做的事情
# 先“他人”，后“自我”
# 先做“猎人”，再做种植大户，其实都是在说积累，在说行动
# 读到浅显的地方有金句，读到专业的知识解释的也没啥毛病。感觉作者本人和书有差距。
# 人是渴望线下接触的
# 人性
# 互联网是工具
# 怎么解决社会困境
# 怎么解决社会困境
# 怎么解决社会困境
# 内容贡献者的驱动力3
# 内容贡献者的驱动力2
# 内容贡献者的驱动力1
# 绩效为战略而生
# 双向匹配，双向思考。需要怎样的人，不需要怎样的人，公司要有取舍。根据公司变化，自己需要如何改变去迎合，个人需要有取舍
# 助理锻造营类似模拟考试
# 前厅关键动作:笑、跑、答、有礼貌
# 应知
# 文本+视频
# 制度流程，操作流程
# 锻造营
# 与企业愿景价值观一致
# 质量的标准很重要！询问人才需求方，萃取标杆的关键能力
# 关键岗位的关键能力是什么？
# 还可以
# 招人的方向
# 扣帽子可了不得
# HAHA
# 硬币或人的两面性。计划+市场亦或市场+计划。
# 中医&西医：价格是表象，机制才是实质。
# 叛徒
# 反复无常是小人
# HAHA
# 鬼
# 腊月十三
# 没看明白
# 共享！
# 国家统计局数据显示，2021我国牛奶总产量3683万吨。
#
# 为什么下降了？
# 能坚持这一点，非常伟大。
# 2021年1-12月中国奶粉进口数量为154万吨，进口金额为89.21亿美元。
# 伟大的想法
# 不愧是百年企业！
# 有人天生喜欢田间。
# 百年树人
# 不对
# 需要有耐心，需要要资本。
# OKR制定原则
# OKR制定原则
# 惊艳
# 初期关键是质量
# 化繁为简
# 挑重点
# 回归用户
# 这其中成本不是更高吗？
# 1st principle, mission driven
# 这个水军厉害
# 早期团队应该小心但这样是不是太“浪费时间”了？
# how? 难道靠便宜劳动力？
# 什么是互联网思维？
# 犹豫、狐疑
# ？
# x
# 标注
# 除了名字好听，一无是处。作者如果你自己是个读者和操盘手，碰到这样的书。你会不会骂娘？写了跟没写一样，垃圾中的战斗机
# 最后一部分这么像小说，不是太好
# 这方面比道家，儒家先进
# 实践的方法
# 我的
# mark
# 互为因果？
# 不错
# 再一次从第三方的角度验证了某些心里所想，当然好多醍醐灌顶，原来如此，打开一本书，进入一种认知维度，拓宽了我们的思维，真好
# 指令
# 认真努力，坚持不懈，静待花开🙏
# 场景化营销
# 好哦
# 挺不错的，有启蒙指导作用
# 还有很多隐形成本
# 现金流量表呢
# 人性的底层逻辑是什么
# 对于暖通行业来说三分产品七分安装，必须死磕安装质量，不仅要按照厂家的安装标准来实行甚至要超过厂家的安装标准，竭力为客户着想。现在回过头来想想上海集美楼宇设备 上海匡迪楼宇设备这两家公司在安装质量上面的要求标准都是非常高的，再想想漳州的鼎臻大金空调也是死磕安装质量，短期内也许看不到成效，从长期来看业主们都是很精明的他们是能够从中看出来公司确实是站在他们的角度来考虑的 是真的在为他们创造其他公司不具备的价值的，再反观那些成效一般的表现一般的公司，他们的老板还是在秉持老套的拉关系接生意，以为有了关系就万事大吉了，在安装质量上从来不去重视。没有站在用户的角度去为他们着想，最终他们的市场占有率低用户满意度差，转介绍率也低，公司的美誉度也很差。
# 对 关系就是服务 这句话的理解不是很通透
# 会不会出现吃大锅饭的情况？
# 成就用户 成就员工，用户获取了实实在在的价值才会选择购买你的产品服务，员工获取了实实在在的好处才会踏踏实实在公司上班而不不是选择跳槽到别的公司。
# 要实行末尾淘汰制度，将混子 态度不好业绩不行的淘汰掉，使公司的血液鲜活起来
# 这种模式的沟通层级太多，信息传达上打折扣太多 扁平化管理是不错的选择
# 集中优势兵力资源在一个点上打破，创业初期精细化打磨产品服务竭力为用户创造独特的价值，然后在一个城市迅速打破到处开花在这个城市形成极高的知名度同时要休息美誉度。当占领一个城市后再突破下一个城市
# 不要把谈判看成是辩论
# 要想清楚风险，并愿意接受。才能集中精力导向谈判
# 同理心和语言表达的技巧，谈判的很多思路。虽然看了不代表会用，但莫名觉得很积极，每章还梳理要点，可以多回顾。
# 把他们的情绪重复出来给他们听
# 具体的实施办法
# 对于理性的问题可以如此解决
# 对于理性的问题可以如此解决
# 比较对胃口，其实文章主旨是当别人想要你干你不想干的事时(本文中所用的恐怖勒索、商业谈判想谈出比理想价格还要好的结果等等事情)，反复用几个工具(校准问题(即将对方的要求分解为安步骤的行动"几个怎么做"反馈回去，这样有利于使对方第一套思考系统影响第二套思想系统)标注问题，同理心)，可以用于说服教育，个人影响力等用途
# 道理游戏与情绪游戏
# 道理游戏和情绪游戏
# ！

# %%
pandas.DataFrame(L).to_excel(index=False,excel_writer='豆瓣读书.xlsx')
